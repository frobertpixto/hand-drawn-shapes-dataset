# %% [markdown]
# # Intro
# Predict Vertices position for Ellipses.

# %%
### Load packages
from IPython.display import display, Image
import PIL
import imageio
from scipy import ndimage, misc
from skimage.transform import resize
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.image as mpimg
# %matplotlib inline

import seaborn as sns
sns.set(style='white', context='notebook', palette='deep')

import os
import sys
from pathlib import Path

from six.moves import cPickle as pickle

import numpy as np
import imageio

# %%
# More packages
from shapely.geometry import Polygon
from sklearn.metrics import confusion_matrix

import tensorflow as tf

from tensorflow.keras.utils import to_categorical, Sequence 
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, SeparableConv2D, BatchNormalization, Input, Activation
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint


# Our modules
from mix_module.shape_utils import find_nearest_index, select_first_vertice_index2, find_lefmost_index_in_subrect, select_first_vertice_index, sort_vertices_clockwize, cart2pol, pol2cart, calculate_Dice, PixtoDataGenerator  
from mix_module.utils import ShowBestEpochResult

import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 5, 1, 20, 49, 34, 316455)

# %%
# GPU Setting
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
from platform import python_version
print(python_version())
# Out:
# 3.8.5

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.1

# %%
seed1=127
np.random.seed(seed1)

# %% [markdown]
# ## Define environment variables

# %%
BASEDIR = ".."

DATADIR = os.path.join(BASEDIR, "pickles")

TRAIN_DATAFILE = os.path.join(DATADIR, 'train_ell.pickle')
VAL_DATAFILE   = os.path.join(DATADIR, 'val_ell.pickle')
TEST_DATAFILE  = os.path.join(DATADIR, 'test_ell.pickle')

MODEL_DIR      = os.path.join(BASEDIR, "saved_models")
model_name     = os.path.join(MODEL_DIR, "ellipse1.model")

# %%
# Set image properties
image_size  = 70     # Pixel width and height
pixel_depth = 255.0  # Number of levels per pixel

# %%
# Create model directory
Path(MODEL_DIR).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Load train, validation and test datasets from Pickles

# %%
with open(TRAIN_DATAFILE, 'rb') as f:
    train_dict = pickle.load(f)
with open(VAL_DATAFILE, 'rb') as f:
    val_dict = pickle.load(f)
with open(TEST_DATAFILE, 'rb') as f:
    test_dict = pickle.load(f)

# %%
## Construct train set
train_X = train_dict['train_data']
train_y = train_dict['train_labels']

# %%
## Construct validation set
val_X = val_dict['val_data']
val_y = val_dict['val_labels']

# %%
print("train_X shape: ", train_X.shape)
print("train_y shape: ", train_y.shape)
# Out:
# train_X shape:  (4828, 70, 70)
# train_y shape:  (4828, 8)

# %%
print("val_X shape: ", val_X.shape)
print("val_y shape: ", val_y.shape)
# Out:
# val_X shape:  (1446, 70, 70)
# val_y shape:  (1446, 8)

# %%
# Reshape image in 3 dimensions (height = 70px, width = 70px , canal = 1)
X_train = train_X.reshape(-1, image_size,image_size, 1)
X_val   = val_X.reshape(-1, image_size,image_size, 1)

# %%
Y_train = train_y
Y_val = val_y

# %%
X_train.shape
# Out:
# (4828, 70, 70, 1)

# %%
X_val.shape
# Out:
# (1446, 70, 70, 1)

# %%
Y_train.shape
# Out:
# (4828, 8)

# %%
Y_val.shape
# Out:
# (1446, 8)

# %%
# Labels are vertices: x1, y1, x2, y2, x3, y3, x4, y4
# Where:
# - (0, 0) is the top left corner of the image
# - (1, 1) is the bottom right corner of the image
print("Real Label example: ", Y_val[0])
# Out:
# Real Label example:  [0.42 0.49 0.51 0.12 0.58 0.5  0.48 0.87]

# %%
# TODO Show the corresponding image with superimposed vertices.

# %%
def plot_loss(hist,name,plt,RMSE_TF=False):
    '''
    RMSE_TF: if True, then RMSE is plotted with original scale 
    '''
    loss = hist['loss']
    val_loss = hist['val_loss']
    if RMSE_TF:
        loss = np.sqrt(np.array(loss))*48 
        val_loss = np.sqrt(np.array(val_loss))*48 
        
    plt.plot(loss,"--",linewidth=3,label="train:"+name)
    plt.plot(val_loss,linewidth=3,label="val:"+name)

# %%
def plot_sample(X, y, axs):
    axs.imshow(X.reshape(image_size, image_size), cmap="gray") # Put the Image
    y = y.ravel()
    axs.scatter(image_size * y[0::2], image_size * y[1::2], c='orange') # Add the labels as orange dots

# %%
# This function shows images with their real vertices
# Presentation is 5 rows of 10 images
def display_50_images_with_vertices(X, Y):

    fig = plt.figure(figsize=(13, 9))
    fig.subplots_adjust(hspace=0.2,wspace=0.2,
                        left=0, right=1, bottom=0, top=1.5)

    nb_pictures = 50
    for i_pic in range(nb_pictures):
        x = X[i_pic]
        y = Y[i_pic]

        ax  = fig.add_subplot(nb_pictures//5, 10, i_pic + 1, xticks=[], yticks=[])
        plot_sample(x, y, ax)
    plt.show()

# %%
# Show random images from the Train Set + superimposed vertices
indexes = np.arange(len(Y_train))
np.random.shuffle(indexes)
first_random_indexes = indexes[:50]

display_50_images_with_vertices(X_train[first_random_indexes], Y_train[first_random_indexes])

# %%
# Show random images from the Validation Set + superimposed vertices
indexes = np.arange(len(Y_val))
np.random.shuffle(indexes)
first_random_indexes = indexes[:50]

display_50_images_with_vertices(X_val[first_random_indexes], Y_val[first_random_indexes])

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Define Deep Learning Model

# %%
def get_model_cnn():
    # Set the CNN model using Keras functional API
    input_img = Input(shape=(image_size,image_size,1))

    x = Conv2D(32, (5, 5), padding='same')(input_img)  # Conv2D 1
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Conv2D(32, (5, 5), padding='same')(x)          # Conv2D 2
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(64, (3, 3))(x)                          # Conv2D 3
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Conv2D(64, (3, 3))(x)                          # Conv2D 4
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Conv2D(128, (3, 3))(x)                         # Conv2D 5
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3))(x)                         # Conv2D 6
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.05)(x)

    x = Flatten()(x)
    x = Dense(200)(x)  
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    output = Dense(8)(x)

    model = Model(inputs=input_img, outputs=output)
    
    return model

# %%
# select a model
model = get_model_cnn()

model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 70, 70, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 70, 70, 32)        832
# _________________________________________________________________
# batch_normalization (BatchNo (None, 70, 70, 32)        128
# _________________________________________________________________
# activation (Activation)      (None, 70, 70, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 35, 35, 32)        25632
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 35, 35, 32)        128
# _________________________________________________________________
# activation_1 (Activation)    (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 33, 33, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 33, 33, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 33, 33, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# activation_3 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5, 5, 128)         512
# _________________________________________________________________
# activation_4 (Activation)    (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 128)         147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# activation_5 (Activation)    (None, 3, 3, 128)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 200)               230600
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 200)               800
# _________________________________________________________________
# activation_6 (Activation)    (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 1608
# =================================================================
# Total params: 538,128
# Trainable params: 536,832
# Non-trainable params: 1,296
# _________________________________________________________________

# %% [markdown]
# ## Data augmentation: Full rotation, Flip vert. and Horiz with Targets modified

# %%
# Partition for the Generator
partition = []

nb_samples = X_train.shape[0]
print("nb_samples: ", nb_samples)

for i in range(nb_samples):
    partition.append(i)
# Out:
# nb_samples:  4828

# %%
batch_size = 128
pixto_gen = PixtoDataGenerator(partition, X_train, Y_train, batch_size=batch_size, n_vertices=4, x_pos=0.0, y_pos=0.65)
# TODO:
# - Explain PixtoDataGenerator. This is improved and more complex version of my generator
#   described at: https://github.com/frobertpixto/tf_keras_generator_with_targets
# - Explain x_pos=0.0, y_pos=0.65 that must match ETL

# %% [markdown]
# ## Define the optimizer

# %%
optimizer = Adam(lr=4e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0, amsgrad=False)

# %% [markdown]
# # Compile the model

# %%
model.compile(optimizer = optimizer , loss = "mean_squared_error")

# %% [markdown]
# # Set a learning rate callback

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss',
                                            patience=25,
                                            verbose=1,
                                            factor=0.90, 
                                            mode='min',
                                            min_delta=0.0000001,
                                            min_lr=0.000000001)

# %% [markdown]
# # Fit the model with data Augmentation

# %%
# I like to start a few epoch with a small batch size because:
# - This basically makes the learning rate larger. https://openreview.net/pdf?id=B1Yy1BxCZ#:~:text=Increasing%20the%20batch%20size%20during%20training%20achieves%20similar%20results%20to,twice%20to%20illustrate%20the%20variance.
# - This covers to 0 to 80% of the accuracy/loss curve, cleaning the graphs
epochs = 6
history = model.fit(x=pixto_gen,
                              epochs = epochs, validation_data = (X_val,Y_val),
                              verbose = 1, steps_per_epoch=X_train.shape[0] // batch_size)
# Out:
# Epoch 1/6
# 37/37 [==============================] - 6s 156ms/step - loss: 0.2331 - val_loss: 0.1954
# Epoch 2/6
# 37/37 [==============================] - 6s 161ms/step - loss: 0.0392 - val_loss: 0.1504
# Epoch 3/6
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0242 - val_loss: 0.0988
# Epoch 4/6
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0190 - val_loss: 0.0869
# Epoch 5/6
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0154 - val_loss: 0.0599
# Epoch 6/6
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0131 - val_loss: 0.0383

# %%
# Fit and Save the Best model
h5_path    = model_name + ".h5"
checkpoint = ModelCheckpoint(h5_path, monitor='val_loss', verbose=1, save_best_only=True)

best_epoch_results = ShowBestEpochResult(on_param='val_loss', show_params=['val_loss', 'loss'], mode='min')

callbacks_list = [learning_rate_reduction, checkpoint, best_epoch_results]

epochs  = 200 #1100
history = model.fit(x=pixto_gen,
                              epochs = epochs, validation_data = (X_val,Y_val),
                              verbose = 1, steps_per_epoch=X_train.shape[0] // batch_size,
                              callbacks=callbacks_list)
# Out:
# Epoch 1/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0123
# Epoch 00001: val_loss improved from inf to 0.03647, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0123 - val_loss: 0.0365
# Epoch 2/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0110
# Epoch 00002: val_loss improved from 0.03647 to 0.03003, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0110 - val_loss: 0.0300
# Epoch 3/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0106
# Epoch 00003: val_loss improved from 0.03003 to 0.02602, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0106 - val_loss: 0.0260
# Epoch 4/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0093
# Epoch 00004: val_loss improved from 0.02602 to 0.01877, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0093 - val_loss: 0.0188
# Epoch 5/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 00005: val_loss improved from 0.01877 to 0.01462, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0092 - val_loss: 0.0146
# Epoch 6/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 00006: val_loss improved from 0.01462 to 0.01270, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0084 - val_loss: 0.0127
# Epoch 7/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 00007: val_loss improved from 0.01270 to 0.00985, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0082 - val_loss: 0.0098
# Epoch 8/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 00008: val_loss improved from 0.00985 to 0.00739, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0081 - val_loss: 0.0074
# Epoch 9/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 00009: val_loss improved from 0.00739 to 0.00600, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0075 - val_loss: 0.0060
# Epoch 10/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 00010: val_loss improved from 0.00600 to 0.00407, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0075 - val_loss: 0.0041
# Epoch 11/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 00011: val_loss improved from 0.00407 to 0.00328, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0073 - val_loss: 0.0033
# Epoch 12/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 00012: val_loss improved from 0.00328 to 0.00316, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0070 - val_loss: 0.0032
# Epoch 13/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 00013: val_loss improved from 0.00316 to 0.00285, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0071 - val_loss: 0.0028
# Epoch 14/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 00014: val_loss did not improve from 0.00285
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0066 - val_loss: 0.0030
# Epoch 15/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 00015: val_loss did not improve from 0.00285
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0068 - val_loss: 0.0031
# Epoch 16/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 00016: val_loss did not improve from 0.00285
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0065 - val_loss: 0.0030
# Epoch 17/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 00017: val_loss did not improve from 0.00285
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0066 - val_loss: 0.0030
# Epoch 18/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 00018: val_loss did not improve from 0.00285
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0060 - val_loss: 0.0032
# Epoch 19/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 00019: val_loss did not improve from 0.00285
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0066 - val_loss: 0.0031
# Epoch 20/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 00020: val_loss improved from 0.00285 to 0.00282, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0057 - val_loss: 0.0028
# Epoch 21/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 00021: val_loss improved from 0.00282 to 0.00273, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0062 - val_loss: 0.0027
# Epoch 22/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 00022: val_loss did not improve from 0.00273
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0056 - val_loss: 0.0028
# Epoch 23/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 00023: val_loss improved from 0.00273 to 0.00269, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0060 - val_loss: 0.0027
# Epoch 24/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 00024: val_loss did not improve from 0.00269
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0056 - val_loss: 0.0029
# Epoch 25/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 00025: val_loss did not improve from 0.00269
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0054 - val_loss: 0.0028
# Epoch 26/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 00026: val_loss did not improve from 0.00269
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0055 - val_loss: 0.0028
# Epoch 27/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 00027: val_loss improved from 0.00269 to 0.00257, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0055 - val_loss: 0.0026
# Epoch 28/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 00028: val_loss did not improve from 0.00257
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0053 - val_loss: 0.0026
# Epoch 29/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 00029: val_loss improved from 0.00257 to 0.00247, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0054 - val_loss: 0.0025
# Epoch 30/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 00030: val_loss improved from 0.00247 to 0.00241, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0053 - val_loss: 0.0024
# Epoch 31/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 00031: val_loss did not improve from 0.00241
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0050 - val_loss: 0.0032
# Epoch 32/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 00032: val_loss did not improve from 0.00241
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0054 - val_loss: 0.0025
# Epoch 33/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 00033: val_loss did not improve from 0.00241
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0051 - val_loss: 0.0026
# Epoch 34/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 00034: val_loss did not improve from 0.00241
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0049 - val_loss: 0.0025
# Epoch 35/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 00035: val_loss did not improve from 0.00241
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0050 - val_loss: 0.0027
# Epoch 36/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 00036: val_loss improved from 0.00241 to 0.00240, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0051 - val_loss: 0.0024
# Epoch 37/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 00037: val_loss did not improve from 0.00240
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0048 - val_loss: 0.0032
# Epoch 38/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 00038: val_loss did not improve from 0.00240
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0052 - val_loss: 0.0027
# Epoch 39/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 00039: val_loss did not improve from 0.00240
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0047 - val_loss: 0.0025
# Epoch 40/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 00040: val_loss improved from 0.00240 to 0.00236, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0046 - val_loss: 0.0024
# Epoch 41/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 00041: val_loss did not improve from 0.00236
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0045 - val_loss: 0.0024
# Epoch 42/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 00042: val_loss did not improve from 0.00236
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0046 - val_loss: 0.0026
# Epoch 43/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 00043: val_loss improved from 0.00236 to 0.00235, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0048 - val_loss: 0.0023
# Epoch 44/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 00044: val_loss improved from 0.00235 to 0.00226, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0046 - val_loss: 0.0023
# Epoch 45/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 00045: val_loss did not improve from 0.00226
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0043 - val_loss: 0.0023
# Epoch 46/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 00046: val_loss did not improve from 0.00226
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0044 - val_loss: 0.0026
# Epoch 47/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 00047: val_loss did not improve from 0.00226
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0046 - val_loss: 0.0024
# Epoch 48/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 00048: val_loss improved from 0.00226 to 0.00206, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 49/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 00049: val_loss did not improve from 0.00206
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0045 - val_loss: 0.0025
# Epoch 50/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 00050: val_loss did not improve from 0.00206
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0045 - val_loss: 0.0024
# Epoch 51/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 00051: val_loss did not improve from 0.00206
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 52/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 00052: val_loss did not improve from 0.00206
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0045 - val_loss: 0.0022
# Epoch 53/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 00053: val_loss did not improve from 0.00206
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0047 - val_loss: 0.0022
# Epoch 54/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 00054: val_loss did not improve from 0.00206
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0046 - val_loss: 0.0023
# Epoch 55/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 00055: val_loss did not improve from 0.00206
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0043 - val_loss: 0.0025
# Epoch 56/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00056: val_loss did not improve from 0.00206
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0041 - val_loss: 0.0023
# Epoch 57/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 00057: val_loss did not improve from 0.00206
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0042 - val_loss: 0.0022
# Epoch 58/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 00058: val_loss improved from 0.00206 to 0.00197, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0044 - val_loss: 0.0020
# Epoch 59/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 00059: val_loss did not improve from 0.00197
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0043 - val_loss: 0.0028
# Epoch 60/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 00060: val_loss did not improve from 0.00197
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0043 - val_loss: 0.0022
# Epoch 61/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00061: val_loss did not improve from 0.00197
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0041 - val_loss: 0.0023
# Epoch 62/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 00062: val_loss did not improve from 0.00197
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0042 - val_loss: 0.0025
# Epoch 63/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00063: val_loss did not improve from 0.00197
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0041 - val_loss: 0.0022
# Epoch 64/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00064: val_loss did not improve from 0.00197
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 65/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 00065: val_loss did not improve from 0.00197
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 66/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 00066: val_loss improved from 0.00197 to 0.00195, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 161ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 67/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00067: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 68/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00068: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0041 - val_loss: 0.0023
# Epoch 69/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 00069: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 70/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00070: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0039 - val_loss: 0.0023
# Epoch 71/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00071: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0041 - val_loss: 0.0021
# Epoch 72/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 00072: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 73/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00073: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 74/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00074: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0039 - val_loss: 0.0022
# Epoch 75/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00075: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0039 - val_loss: 0.0023
# Epoch 76/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 00076: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0040 - val_loss: 0.0023
# Epoch 77/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00077: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0039 - val_loss: 0.0022
# Epoch 78/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 00078: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 79/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00079: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 80/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00080: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 81/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 00081: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 82/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00082: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 83/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 00083: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0038 - val_loss: 0.0020
# Epoch 84/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00084: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 85/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 00085: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 86/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 00086: val_loss did not improve from 0.00195
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 87/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00087: val_loss improved from 0.00195 to 0.00179, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 88/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00088: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0036 - val_loss: 0.0020
# Epoch 89/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00089: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 90/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00090: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 91/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00091: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0037 - val_loss: 0.0028
# Epoch 92/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00092: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 93/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 00093: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0038 - val_loss: 0.0025
# Epoch 94/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00094: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0036 - val_loss: 0.0023
# Epoch 95/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 00095: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0038 - val_loss: 0.0024
# Epoch 96/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00096: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 97/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 00097: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0038 - val_loss: 0.0019
# Epoch 98/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00098: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 99/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00099: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 100/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00100: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 101/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00101: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 102/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00102: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 103/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00103: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 104/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00104: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 105/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00105: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 106/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00106: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0037 - val_loss: 0.0027
# Epoch 107/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00107: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 108/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00108: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 109/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00109: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0035 - val_loss: 0.0020
# Epoch 110/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00110: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 111/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00111: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 112/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00112: ReduceLROnPlateau reducing learning rate to 0.00035999999090563506.
#
# Epoch 00112: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 113/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00113: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 114/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00114: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 115/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00115: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 116/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00116: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 117/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00117: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 118/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00118: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 119/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00119: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 120/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00120: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 121/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00121: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 122/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00122: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 123/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00123: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0034 - val_loss: 0.0023
# Epoch 124/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00124: val_loss improved from 0.00179 to 0.00179, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 125/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00125: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 126/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00126: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 127/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00127: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 128/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00128: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 129/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00129: val_loss did not improve from 0.00179
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 130/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00130: val_loss improved from 0.00179 to 0.00174, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 131/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00131: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 132/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00132: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 133/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00133: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 134/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00134: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0030 - val_loss: 0.0020
# Epoch 135/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00135: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 136/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00136: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 137/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00137: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 138/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00138: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 139/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00139: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0032 - val_loss: 0.0022
# Epoch 140/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00140: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 141/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00141: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 142/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00142: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 143/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00143: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 144/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00144: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 145/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00145: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 146/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00146: val_loss did not improve from 0.00174
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 147/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00147: val_loss improved from 0.00174 to 0.00165, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 148/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00148: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 149/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00149: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 150/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00150: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 151/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00151: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 152/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00152: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 153/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00153: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 154/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00154: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 155/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00155: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 156/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00156: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 157/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00157: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 158/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00158: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 159/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00159: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 160/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00160: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 161/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00161: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 162/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00162: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0031 - val_loss: 0.0020
# Epoch 163/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00163: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 164/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00164: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 165/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00165: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 166/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00166: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 167/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00167: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 168/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00168: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 169/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00169: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 170/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00170: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 171/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00171: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 172/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00172: ReduceLROnPlateau reducing learning rate to 0.00032400000491179527.
#
# Epoch 00172: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 173/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00173: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 174/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00174: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 175/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00175: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 176/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00176: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 177/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00177: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 178/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00178: val_loss improved from 0.00165 to 0.00165, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 179/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00179: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 180/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00180: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 181/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00181: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 182/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00182: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 183/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00183: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 184/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00184: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 185/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00185: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 186/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00186: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 187/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00187: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 188/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00188: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 189/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00189: val_loss did not improve from 0.00165
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 190/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00190: val_loss improved from 0.00165 to 0.00161, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 191/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00191: val_loss did not improve from 0.00161
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 192/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00192: val_loss improved from 0.00161 to 0.00159, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 193/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00193: val_loss did not improve from 0.00159
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 194/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00194: val_loss did not improve from 0.00159
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 195/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00195: val_loss did not improve from 0.00159
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 196/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00196: val_loss did not improve from 0.00159
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 197/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00197: val_loss did not improve from 0.00159
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 198/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00198: val_loss did not improve from 0.00159
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 199/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00199: val_loss did not improve from 0.00159
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 200/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00200: val_loss did not improve from 0.00159
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0028 - val_loss: 0.0017
# BestEpochResult. Epoch: 192, val_loss: 0.00159, loss: 0.00283,

# %% [markdown]
# ## Plot the loss curves for training and validation

# %%
plt.figure(figsize=(15,10))
plot_loss(history.history,"model",plt)
plt.legend()
plt.grid()
plt.yscale("log")
plt.xlabel("epoch")
plt.ylabel("log loss")
plt.show()

# %% [markdown]
# ## Delete the existing model + Load the best one

# %%
# deletes the existing model
del model

# Load last saved model
model = load_model(model_name + ".h5")

# %%
Y_val_pred = model.predict(X_val)

# %%
# Labels are vertices: x1, y1, x2, y2, x3, y3, y4, y4
# Where:
# - (0, 0) is the top left corner of the image
# - (1, 1) is the bottom right corner of the image
print("Y_val shape: ", Y_val.shape)
print("Y_val_pred shape: ", Y_val_pred.shape)
print("Real Label example: ", Y_val[0])
print("Prediction example: ", Y_val_pred[0])
# Out:
# Y_val shape:  (1446, 8)
# Y_val_pred shape:  (1446, 8)
# Real Label example:  [0.42 0.49 0.51 0.12 0.58 0.5  0.48 0.87]
# Prediction example:  [0.40389118 0.47491255 0.5042391  0.11077122 0.59255886 0.5285092
#  0.47770455 0.8949884 ]

# %% [markdown]
# # Calculate Dice accuracy for the whole Validation set

# %%
nb_samples = Y_val.shape[0]
dice_sum = 0.0
for i in range(nb_samples):
    dice = calculate_Dice(Y_val[i], Y_val_pred[i], nb_vertices=4)
    dice_sum += dice
    
dice_val = dice_sum / nb_samples
print(f"Validation Accuracy(Dice): {dice_val}.")
# Out:
# Validation Accuracy(Dice): 0.8937295342919955.

# %%
def plot_sample_with_pred(X, y, pred,axs):
   
    axs.imshow(X.reshape(image_size, image_size),cmap="gray") # Shape
    axs.scatter(image_size*y[0::2], image_size*y[1::2],c='orange') # Real Vertices
    axs.scatter(image_size*pred[0::2], image_size*pred[1::2],c='green') # Predicted Vertices

# %% [markdown]
# # Validation set predictions - Visualization

# %%
fig = plt.figure(figsize=(13, 21))
fig.subplots_adjust(hspace=0.13, wspace=0.01,
                    left=0, right=1, bottom=0, top=1.2)
nb_pictures = 32
count = 1
for irow in range(nb_pictures):
    ipic = np.random.choice(X_val.shape[0])
    ax = fig.add_subplot(nb_pictures/4 , 4, count,xticks=[],yticks=[])        
    plot_sample_with_pred(X_val[ipic], Y_val[ipic], Y_val_pred[ipic], ax)

    dice = calculate_Dice(Y_val[ipic], Y_val_pred[ipic], nb_vertices=4)
    ax.set_title("dice {:5.3f}".format(dice))
    count += 1
plt.show()
# Out:
# <ipython-input-44-58e9a55e90ba>:8: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax = fig.add_subplot(nb_pictures/4 , 4, count,xticks=[],yticks=[])

# %%
#TODO Display the 32 worst RMSE images

# %% [markdown]
# ## Predict for the test set

# %%
## Prepare the Test set
test_X = test_dict['test_data']
test_y = test_dict['test_labels']
print("test_X shape: ", test_X.shape)
print("test_y shape: ", test_y.shape)

X_test    = test_X.reshape(-1, image_size,image_size, 1)
Y_test    = test_y 
print("X_test shape: ", X_test.shape)
print("Y_test shape: ", Y_test.shape)
# Out:
# test_X shape:  (180, 70, 70)
# test_y shape:  (180, 8)
# X_test shape:  (180, 70, 70, 1)
# Y_test shape:  (180, 8)

# %%
# Show random images from the Test Set + superimposed vertices
indexes = np.arange(len(Y_test))
np.random.shuffle(indexes)
first_random_indexes = indexes[:50]

display_50_images_with_vertices(X_test[first_random_indexes], Y_test[first_random_indexes])

# %%
test_loss = model.evaluate(X_test, Y_test)
print("test_loss: ", test_loss)
# Out:
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0020
# test_loss:  0.0019511673599481583

# %%
Y_test_pred = model.predict(X_test)

# %%
print("Y_pred shape: ", Y_test_pred.shape)
Y_test_pred[0:2, :]
# Out:
# Y_pred shape:  (180, 8)
# array([[0.3046041 , 0.76828563, 0.34420872, 0.313267  , 0.7058518 ,
#         0.20475833, 0.671328  , 0.67315364],
#        [0.10502812, 0.6100571 , 0.41857904, 0.3028559 , 0.870185  ,
#         0.37758106, 0.5410248 , 0.69796824]], dtype=float32)

# %% [markdown]
# # Calculate Dice accuracy for the whole Test set

# %%
nb_samples = Y_test.shape[0]
dice_sum = 0.0
for i in range(nb_samples):
    dice = calculate_Dice(Y_test[i], Y_test_pred[i], nb_vertices=4)
    dice_sum += dice
    
dice_val = dice_sum / nb_samples
print(f"Validation Accuracy(Dice): {dice_val}.")
# Out:
# Validation Accuracy(Dice): 0.8909205322307261.

# %% [markdown]
# # Test set predictions - Visualization

# %%
fig = plt.figure(figsize=(13, 21))
fig.subplots_adjust(hspace=0.13, wspace=0.01,
                    left=0, right=1, bottom=0, top=1.2)
nb_pictures = 32
count = 1
for irow in range(nb_pictures):
    ipic = np.random.choice(X_test.shape[0])
    ax = fig.add_subplot(nb_pictures/4 , 4, count,xticks=[],yticks=[])        
    plot_sample_with_pred(X_test[ipic], Y_test[ipic], Y_test_pred[ipic], ax)

    dice = calculate_Dice(Y_test[ipic], Y_test_pred[ipic], nb_vertices=4)
    ax.set_title("dice {:5.3f}".format(dice))
    count += 1
plt.show()
# Out:
# <ipython-input-52-a19916c816e7>:8: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax = fig.add_subplot(nb_pictures/4 , 4, count,xticks=[],yticks=[])

# %% [markdown]
# # Conclusion
# - TODO
# - Indicate the accuracy with around 1000 epochs for Mix on Pix

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 5, 1, 21, 10, 2, 707162)
