# %% [markdown]
# # Train a model to estimate the vertices in an image
#
# Predict Vertices position for Triangles.
# Using Supervised Learning with Tensorflow
#
# Data is received in 3 pickles that contains:
# - Train images and labels (vertices)
# - Validation images and labels (vertices)
# - Test images and labels (vertices)
#
# ---
# Francois Robert

# %%
# This notebook estimates the vertices for 1 shape
shape = "triangle"

# %%
### Load packages
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

import seaborn as sns
sns.set(style='white', context='notebook', palette='deep')

import os
from pathlib import Path

from six.moves import cPickle as pickle

# %%
# More packages
import tensorflow as tf

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Input, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# Our modules
from hds_module.shape_utils import HdsDataGenerator, calculate_Dice, calculate_Dice_for_set  
from hds_module.utils import ShowBestEpochResult

import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 5, 28, 14, 54, 20, 310003)

# %%
# GPU Setting
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
from platform import python_version
print(f'Python: {python_version()}')
# Out:
# Python: 3.8.5

# %%
import tensorflow as tf
print(f'Tensorflow: {tf.__version__}')
# Out:
# Tensorflow: 2.3.1

# %%
seed1=127
np.random.seed(seed1)

# %% [markdown]
# ## Define environment variables

# %%
BASEDIR = ".."

DATADIR = os.path.join(BASEDIR, "pickles")

TRAIN_DATAFILE = os.path.join(DATADIR, f"train_{shape}.pickle")
VAL_DATAFILE   = os.path.join(DATADIR, f"val_{shape}.pickle")
TEST_DATAFILE  = os.path.join(DATADIR, f"test_{shape}.pickle")

MODEL_DIR      = os.path.join(BASEDIR, "saved_models")
model_name     = os.path.join(MODEL_DIR, f"{shape}1.model")

# %%
# Set image properties
image_size  = 70     # Pixel width and height
pixel_depth = 255.0  # Number of levels per pixel

# %%
# Create model directory
Path(MODEL_DIR).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Load train, validation and test datasets from Pickles

# %%
with open(TRAIN_DATAFILE, 'rb') as file:
    train_dict = pickle.load(file)
with open(VAL_DATAFILE, 'rb') as file:
    val_dict = pickle.load(file)
with open(TEST_DATAFILE, 'rb') as file:
    test_dict = pickle.load(file)

# %%
# Load params used in ETL
params_dict = train_dict['params']

etl_shape = params_dict['shape']
nb_vertices = params_dict['nb_vertices']
anchor_x = params_dict['anchor_x']
anchor_y = params_dict['anchor_y']

print(f"{shape=}, {nb_vertices=}, {anchor_x=}, {anchor_y=}") 

assert shape == etl_shape, f"Invalid shape read. Expected: {shape}. Actual {etl_shape}."
# Out:
# shape='triangle', nb_vertices=3, anchor_x=0.2, anchor_y=1.0

# %%
# Construct train set
train_X = train_dict['train_data']
train_y = train_dict['train_labels']

# %%
# Construct validation set
val_X = val_dict['val_data']
val_y = val_dict['val_labels']

# %%
print("train_X shape: ", train_X.shape)
print("train_y shape: ", train_y.shape)
# Out:
# train_X shape:  (5045, 70, 70)
# train_y shape:  (5045, 6)

# %%
print("val_X shape: ", val_X.shape)
print("val_y shape: ", val_y.shape)
# Out:
# val_X shape:  (1370, 70, 70)
# val_y shape:  (1370, 6)

# %%
# Reshape each image in 3 dimensions (height = 70px, width = 70px, canal = 1)
X_train = train_X.reshape(-1, image_size, image_size, 1)
X_val   = val_X.reshape(-1, image_size, image_size, 1)

# %%
Y_train = train_y
Y_val = val_y

# %%
X_train.shape
# Out:
# (5045, 70, 70, 1)

# %%
X_val.shape
# Out:
# (1370, 70, 70, 1)

# %%
# We expect to have 6 values for the labels of a triangle.

# %%
Y_train.shape
# Out:
# (5045, 6)

# %%
Y_val.shape
# Out:
# (1370, 6)

# %%
# Labels are vertices: x1, y1, x2, y2, x3, y3
# Where:
# - (0, 0) is the top left corner of the image
# - (1, 1) is the bottom right corner of the image
print("Real Label example: ", Y_val[0])
# Out:
# Real Label example:  [0.34 0.82 0.53 0.05 0.65 0.88]

# %% [markdown]
# ## Let's visualize the data
# An image is worth a thousand words.

# %%
def plot_loss(hist,name,plt,RMSE_TF=False):
    '''
    RMSE_TF: if True, then RMSE is plotted with original scale 
    '''
    loss = hist['loss']
    val_loss = hist['val_loss']
    if RMSE_TF:
        loss = np.sqrt(np.array(loss))*48 
        val_loss = np.sqrt(np.array(val_loss))*48 
        
    plt.plot(loss,"--",linewidth=3,label="train:"+name)
    plt.plot(val_loss,linewidth=3,label="val:"+name)

# %%
def plot_sample(X, y, axs):
    axs.imshow(X.reshape(image_size, image_size), cmap="gray") # Put the Image
    y = y.ravel()
    axs.scatter(image_size * y[0::2], image_size * y[1::2], c='orange') # Add the labels as orange dots

# %%
# This function shows images with their real vertices
# Presentation is rows of 10 images
def display_images_with_vertices(X, Y):

    fig = plt.figure(figsize=(13, 9))
    fig.subplots_adjust(hspace=0.2,wspace=0.2,
                        left=0, right=1, bottom=0, top=1.5)

    nb_pictures = len(X)
    for i_pic in range(nb_pictures):
        x = X[i_pic]
        y = Y[i_pic]
        
        nb_per_row = 10
        nb_of_row  = (nb_pictures - 1) // nb_per_row + 1

        ax  = fig.add_subplot(nb_of_row, nb_per_row, i_pic + 1, xticks=[], yticks=[])
        plot_sample(x, y, ax)
    plt.show()

# %%
# Show random images from the Train Set + superimposed vertices
indexes = np.arange(len(Y_train))
np.random.shuffle(indexes)
first_random_indexes = indexes[:100]

display_images_with_vertices(X_train[first_random_indexes], Y_train[first_random_indexes])

# %%
# Show random images from the Validation Set + superimposed vertices
indexes = np.arange(len(Y_val))
np.random.shuffle(indexes)
first_random_indexes = indexes[:100]

display_images_with_vertices(X_val[first_random_indexes], Y_val[first_random_indexes])

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Define Deep Learning Model

# %%
def get_model_cnn():
    # Set the CNN model using Keras functional API
    input_img = Input(shape=(image_size,image_size,1))

    x = Conv2D(32, (5, 5), padding='same')(input_img)  # Conv2D 1
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Conv2D(32, (5, 5), padding='same')(x)          # Conv2D 2
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(64, (3, 3))(x)                          # Conv2D 3
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Conv2D(64, (3, 3))(x)                          # Conv2D 4
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Conv2D(128, (3, 3))(x)                         # Conv2D 5
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3))(x)                         # Conv2D 6
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.1)(x)

    x = Flatten()(x)
    x = Dense(160)(x)  
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    output = Dense(nb_vertices * 2)(x)

    model = Model(inputs=input_img, outputs=output)
    
    return model

# %%
# select a model
model = get_model_cnn()

model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 70, 70, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 70, 70, 32)        832
# _________________________________________________________________
# batch_normalization (BatchNo (None, 70, 70, 32)        128
# _________________________________________________________________
# activation (Activation)      (None, 70, 70, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 35, 35, 32)        25632
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 35, 35, 32)        128
# _________________________________________________________________
# activation_1 (Activation)    (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 33, 33, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 33, 33, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 33, 33, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# activation_3 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 128)         73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5, 5, 128)         512
# _________________________________________________________________
# activation_4 (Activation)    (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 128)         147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# activation_5 (Activation)    (None, 3, 3, 128)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 160)               184480
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 160)               640
# _________________________________________________________________
# activation_6 (Activation)    (None, 160)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 966
# =================================================================
# Total params: 491,206
# Trainable params: 489,990
# Non-trainable params: 1,216
# _________________________________________________________________

# %% [markdown]
# ## Data augmentation: Full rotation, Flip vert. and Horiz with Targets modified

# %%
# Partition for the Generator
partition = []

nb_samples = X_train.shape[0]
print("nb_samples: ", nb_samples)

for i in range(nb_samples):
    partition.append(i)
# Out:
# nb_samples:  5045

# %% [markdown]
# For the generator, I create a custom Generator that does augmentation:
# - Flips the images horizontally and vertically.
# - Rotate the images 360 degres.
# - **Adjust the labels (vertices) according the flips and rotation.**
# - In particular, it manages the complexities of determining the first vertex.
#
# This is an improved and more complex version of my generator described at: https://github.com/frobertpixto/tf_keras_generator_with_targets
#
# Regarding **x_pos and y_pos**, this is the **anchor** used to finding the first vertex that I describe in more details
# [here](https://github.com/frobertpixto/hand_drawn_shapes_dataset/blob/main/processing/find_vertices/README.md).

# %%
batch_size = 128
hds_gen = HdsDataGenerator(partition, X_train, Y_train, batch_size=batch_size,
                           n_vertices=nb_vertices,
                           x_pos=anchor_x,
                           y_pos=anchor_y)

# %% [markdown]
# ## Define the optimizer

# %%
optimizer = Adam(lr=4e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0, amsgrad=False)

# %% [markdown]
# # Compile the model

# %%
model.compile(optimizer = optimizer , loss = "mean_squared_error")

# %% [markdown]
# # Set a learning rate callback

# %%
# when running for 1000 epoch, the reduction must be very slow.
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss',
                                            patience=28,
                                            verbose=1,
                                            factor=0.90, 
                                            mode='min',
                                            min_delta=0.0000001,
                                            min_lr=0.000000001)

# %% [markdown]
# # Fit the model with data Augmentation

# %%
# I like to start a few epoch with a small batch size because:
# - This basically makes the learning rate larger. https://openreview.net/pdf?id=B1Yy1BxCZ#:~:text=Increasing%20the%20batch%20size%20during%20training%20achieves%20similar%20results%20to,twice%20to%20illustrate%20the%20variance.
# - This covers to 0 to 80% of the accuracy/loss curve, cleaning the graphs
epochs = 6
history = model.fit(x=hds_gen,
                    epochs = epochs, validation_data = (X_val,Y_val),
                    verbose = 1, steps_per_epoch=X_train.shape[0] // batch_size)
# Out:
# Epoch 1/6
# 39/39 [==============================] - 7s 168ms/step - loss: 0.1960 - val_loss: 0.1198
# Epoch 2/6
# 39/39 [==============================] - 7s 167ms/step - loss: 0.0194 - val_loss: 0.1486
# Epoch 3/6
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0158 - val_loss: 0.0950
# Epoch 4/6
# 39/39 [==============================] - 7s 167ms/step - loss: 0.0142 - val_loss: 0.0830
# Epoch 5/6
# 39/39 [==============================] - 7s 170ms/step - loss: 0.0134 - val_loss: 0.0735
# Epoch 6/6
# 39/39 [==============================] - 7s 170ms/step - loss: 0.0122 - val_loss: 0.0571

# %%
# Fit and Save the Best model
h5_path    = model_name + ".h5"
checkpoint = ModelCheckpoint(h5_path, monitor='val_loss', verbose=1, save_best_only=True)

best_epoch_results = ShowBestEpochResult(on_param='val_loss', show_params=['val_loss', 'loss'], mode='min')

callbacks_list = [learning_rate_reduction, checkpoint, best_epoch_results]

epochs  = 200 #1100
history = model.fit(x=hds_gen,
                      epochs = epochs, validation_data = (X_val,Y_val),
                      verbose = 1, steps_per_epoch=X_train.shape[0] // batch_size,
                      callbacks=callbacks_list)
# Out:
# Epoch 1/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0107
# Epoch 00001: val_loss improved from inf to 0.04396, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 166ms/step - loss: 0.0107 - val_loss: 0.0440
# Epoch 2/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0106
# Epoch 00002: val_loss improved from 0.04396 to 0.03663, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0106 - val_loss: 0.0366
# Epoch 3/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 00003: val_loss improved from 0.03663 to 0.02490, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 7s 169ms/step - loss: 0.0104 - val_loss: 0.0249
# Epoch 4/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0090
# Epoch 00004: val_loss improved from 0.02490 to 0.01481, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 7s 170ms/step - loss: 0.0090 - val_loss: 0.0148
# Epoch 5/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0089
# Epoch 00005: val_loss improved from 0.01481 to 0.01256, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0089 - val_loss: 0.0126
# Epoch 6/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 00006: val_loss improved from 0.01256 to 0.00947, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 7s 167ms/step - loss: 0.0082 - val_loss: 0.0095
# Epoch 7/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 00007: val_loss improved from 0.00947 to 0.00757, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 167ms/step - loss: 0.0083 - val_loss: 0.0076
# Epoch 8/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 00008: val_loss improved from 0.00757 to 0.00602, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 7s 168ms/step - loss: 0.0081 - val_loss: 0.0060
# Epoch 9/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 00009: val_loss improved from 0.00602 to 0.00443, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0078 - val_loss: 0.0044
# Epoch 10/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 00010: val_loss improved from 0.00443 to 0.00254, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 166ms/step - loss: 0.0075 - val_loss: 0.0025
# Epoch 11/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 00011: val_loss did not improve from 0.00254
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0076 - val_loss: 0.0029
# Epoch 12/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 00012: val_loss improved from 0.00254 to 0.00199, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0079 - val_loss: 0.0020
# Epoch 13/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 00013: val_loss did not improve from 0.00199
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0077 - val_loss: 0.0043
# Epoch 14/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 00014: val_loss did not improve from 0.00199
# 39/39 [==============================] - 6s 166ms/step - loss: 0.0074 - val_loss: 0.0045
# Epoch 15/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 00015: val_loss did not improve from 0.00199
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0066 - val_loss: 0.0021
# Epoch 16/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 00016: val_loss did not improve from 0.00199
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0077 - val_loss: 0.0041
# Epoch 17/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 00017: val_loss did not improve from 0.00199
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0072 - val_loss: 0.0034
# Epoch 18/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 00018: val_loss did not improve from 0.00199
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0062 - val_loss: 0.0029
# Epoch 19/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 00019: val_loss did not improve from 0.00199
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0066 - val_loss: 0.0039
# Epoch 20/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 00020: val_loss did not improve from 0.00199
# 39/39 [==============================] - 6s 166ms/step - loss: 0.0061 - val_loss: 0.0029
# Epoch 21/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 00021: val_loss did not improve from 0.00199
# 39/39 [==============================] - 6s 167ms/step - loss: 0.0066 - val_loss: 0.0027
# Epoch 22/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 00022: val_loss did not improve from 0.00199
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0059 - val_loss: 0.0023
# Epoch 23/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 00023: val_loss did not improve from 0.00199
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0059 - val_loss: 0.0023
# Epoch 24/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 00024: val_loss did not improve from 0.00199
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0059 - val_loss: 0.0031
# Epoch 25/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 00025: val_loss improved from 0.00199 to 0.00178, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 166ms/step - loss: 0.0056 - val_loss: 0.0018
# Epoch 26/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 00026: val_loss did not improve from 0.00178
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 27/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 00027: val_loss did not improve from 0.00178
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0056 - val_loss: 0.0025
# Epoch 28/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 00028: val_loss did not improve from 0.00178
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0057 - val_loss: 0.0035
# Epoch 29/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 00029: val_loss did not improve from 0.00178
# 39/39 [==============================] - 6s 166ms/step - loss: 0.0060 - val_loss: 0.0026
# Epoch 30/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 00030: val_loss did not improve from 0.00178
# 39/39 [==============================] - 6s 166ms/step - loss: 0.0052 - val_loss: 0.0022
# Epoch 31/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 00031: val_loss did not improve from 0.00178
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0050 - val_loss: 0.0038
# Epoch 32/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 00032: val_loss did not improve from 0.00178
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0053 - val_loss: 0.0019
# Epoch 33/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 00033: val_loss did not improve from 0.00178
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0049 - val_loss: 0.0029
# Epoch 34/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 00034: val_loss did not improve from 0.00178
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0057 - val_loss: 0.0034
# Epoch 35/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 00035: val_loss improved from 0.00178 to 0.00153, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0048 - val_loss: 0.0015
# Epoch 36/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 00036: val_loss did not improve from 0.00153
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0054 - val_loss: 0.0025
# Epoch 37/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 00037: val_loss did not improve from 0.00153
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0048 - val_loss: 0.0023
# Epoch 38/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 00038: val_loss improved from 0.00153 to 0.00146, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 39/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 00039: val_loss did not improve from 0.00146
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0050 - val_loss: 0.0017
# Epoch 40/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 00040: val_loss improved from 0.00146 to 0.00131, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 41/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 00041: val_loss did not improve from 0.00131
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0050 - val_loss: 0.0020
# Epoch 42/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 00042: val_loss did not improve from 0.00131
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0054 - val_loss: 0.0024
# Epoch 43/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 00043: val_loss did not improve from 0.00131
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0045 - val_loss: 0.0015
# Epoch 44/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 00044: val_loss did not improve from 0.00131
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 45/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 00045: val_loss did not improve from 0.00131
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0049 - val_loss: 0.0030
# Epoch 46/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 00046: val_loss did not improve from 0.00131
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0053 - val_loss: 0.0028
# Epoch 47/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 00047: val_loss did not improve from 0.00131
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0044 - val_loss: 0.0016
# Epoch 48/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 00048: val_loss improved from 0.00131 to 0.00116, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 167ms/step - loss: 0.0043 - val_loss: 0.0012
# Epoch 49/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00049: val_loss did not improve from 0.00116
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 50/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 00050: val_loss did not improve from 0.00116
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 51/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 00051: val_loss did not improve from 0.00116
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0048 - val_loss: 0.0012
# Epoch 52/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 00052: val_loss did not improve from 0.00116
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 53/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00053: val_loss did not improve from 0.00116
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0041 - val_loss: 0.0018
# Epoch 54/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 00054: val_loss did not improve from 0.00116
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 55/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 00055: val_loss did not improve from 0.00116
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0040 - val_loss: 0.0017
# Epoch 56/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 00056: val_loss did not improve from 0.00116
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0048 - val_loss: 0.0016
# Epoch 57/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 00057: val_loss did not improve from 0.00116
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0045 - val_loss: 0.0020
# Epoch 58/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00058: val_loss improved from 0.00116 to 0.00105, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 166ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 59/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00059: val_loss did not improve from 0.00105
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0039 - val_loss: 0.0012
# Epoch 60/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00060: val_loss did not improve from 0.00105
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0039 - val_loss: 0.0025
# Epoch 61/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00061: val_loss did not improve from 0.00105
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 62/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 00062: val_loss did not improve from 0.00105
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 63/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00063: val_loss improved from 0.00105 to 0.00104, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 7s 168ms/step - loss: 0.0041 - val_loss: 0.0010
# Epoch 64/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00064: val_loss improved from 0.00104 to 0.00088, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0037 - val_loss: 8.8064e-04
# Epoch 65/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 00065: val_loss did not improve from 0.00088
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 66/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 00066: val_loss did not improve from 0.00088
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0043 - val_loss: 0.0019
# Epoch 67/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00067: val_loss did not improve from 0.00088
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0039 - val_loss: 0.0012
# Epoch 68/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00068: val_loss did not improve from 0.00088
# 39/39 [==============================] - 7s 167ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 69/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 00069: val_loss did not improve from 0.00088
# 39/39 [==============================] - 7s 167ms/step - loss: 0.0040 - val_loss: 0.0012
# Epoch 70/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00070: val_loss did not improve from 0.00088
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 71/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 00071: val_loss did not improve from 0.00088
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0040 - val_loss: 0.0014
# Epoch 72/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00072: val_loss did not improve from 0.00088
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 73/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00073: val_loss did not improve from 0.00088
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0037 - val_loss: 0.0012
# Epoch 74/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00074: val_loss did not improve from 0.00088
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 75/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00075: val_loss did not improve from 0.00088
# 39/39 [==============================] - 6s 160ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 76/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 00076: val_loss did not improve from 0.00088
# 39/39 [==============================] - 6s 160ms/step - loss: 0.0042 - val_loss: 9.6909e-04
# Epoch 77/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00077: val_loss did not improve from 0.00088
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 78/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00078: val_loss did not improve from 0.00088
# 39/39 [==============================] - 6s 160ms/step - loss: 0.0039 - val_loss: 0.0023
# Epoch 79/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00079: val_loss did not improve from 0.00088
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0036 - val_loss: 0.0011
# Epoch 80/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00080: val_loss improved from 0.00088 to 0.00079, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 7s 167ms/step - loss: 0.0036 - val_loss: 7.9268e-04
# Epoch 81/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00081: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 82/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 00082: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0045 - val_loss: 0.0016
# Epoch 83/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00083: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0039 - val_loss: 0.0015
# Epoch 84/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00084: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0036 - val_loss: 0.0013
# Epoch 85/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 00085: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 160ms/step - loss: 0.0040 - val_loss: 0.0018
# Epoch 86/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00086: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 160ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 87/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00087: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0037 - val_loss: 8.4090e-04
# Epoch 88/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00088: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 89/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00089: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0039 - val_loss: 8.9183e-04
# Epoch 90/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00090: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0037 - val_loss: 0.0012
# Epoch 91/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00091: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 160ms/step - loss: 0.0036 - val_loss: 0.0016
# Epoch 92/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00092: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0041 - val_loss: 8.7736e-04
# Epoch 93/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00093: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 160ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 94/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00094: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0033 - val_loss: 0.0016
# Epoch 95/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00095: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0037 - val_loss: 0.0013
# Epoch 96/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 00096: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0038 - val_loss: 0.0010
# Epoch 97/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00097: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0031 - val_loss: 8.9552e-04
# Epoch 98/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00098: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 99/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00099: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0041 - val_loss: 0.0018
# Epoch 100/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00100: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0033 - val_loss: 0.0010
# Epoch 101/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00101: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0031 - val_loss: 9.6174e-04
# Epoch 102/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00102: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 160ms/step - loss: 0.0034 - val_loss: 8.6102e-04
# Epoch 103/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00103: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0036 - val_loss: 9.3254e-04
# Epoch 104/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00104: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0033 - val_loss: 0.0010
# Epoch 105/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00105: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 106/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00106: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 160ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 107/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00107: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0033 - val_loss: 0.0014
# Epoch 108/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00108: ReduceLROnPlateau reducing learning rate to 0.0036000001709908247.
#
# Epoch 00108: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0036 - val_loss: 0.0011
# Epoch 109/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00109: val_loss did not improve from 0.00079
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0037 - val_loss: 0.0017
# Epoch 110/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00110: val_loss improved from 0.00079 to 0.00079, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0032 - val_loss: 7.8973e-04
# Epoch 111/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00111: val_loss improved from 0.00079 to 0.00069, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0032 - val_loss: 6.9372e-04
# Epoch 112/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00112: val_loss did not improve from 0.00069
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0034 - val_loss: 0.0016
# Epoch 113/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00113: val_loss did not improve from 0.00069
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0029 - val_loss: 8.8885e-04
# Epoch 114/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00114: val_loss did not improve from 0.00069
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0031 - val_loss: 7.2804e-04
# Epoch 115/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00115: val_loss did not improve from 0.00069
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0032 - val_loss: 8.1303e-04
# Epoch 116/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00116: val_loss improved from 0.00069 to 0.00067, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0032 - val_loss: 6.6970e-04
# Epoch 117/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00117: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0032 - val_loss: 8.0195e-04
# Epoch 118/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00118: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0033 - val_loss: 0.0010
# Epoch 119/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00119: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 166ms/step - loss: 0.0031 - val_loss: 0.0010
# Epoch 120/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00120: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0032 - val_loss: 7.5990e-04
# Epoch 121/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00121: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 160ms/step - loss: 0.0031 - val_loss: 6.7774e-04
# Epoch 122/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00122: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0032 - val_loss: 0.0010
# Epoch 123/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00123: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 124/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00124: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 125/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00125: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0031 - val_loss: 9.0825e-04
# Epoch 126/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00126: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 158ms/step - loss: 0.0033 - val_loss: 9.5121e-04
# Epoch 127/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00127: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0030 - val_loss: 8.9471e-04
# Epoch 128/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00128: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 129/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00129: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0036 - val_loss: 9.1925e-04
# Epoch 130/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00130: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 131/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00131: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 166ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 132/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00132: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0032 - val_loss: 8.0250e-04
# Epoch 133/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00133: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 134/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00134: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0031 - val_loss: 9.9702e-04
# Epoch 135/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00135: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0029 - val_loss: 7.9220e-04
# Epoch 136/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00136: val_loss did not improve from 0.00067
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0032 - val_loss: 7.9692e-04
# Epoch 137/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00137: val_loss improved from 0.00067 to 0.00064, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0032 - val_loss: 6.4120e-04
# Epoch 138/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00138: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0030 - val_loss: 8.4878e-04
# Epoch 139/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00139: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0028 - val_loss: 7.9304e-04
# Epoch 140/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00140: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 141/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00141: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 142/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00142: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 160ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 143/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00143: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0035 - val_loss: 8.2684e-04
# Epoch 144/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00144: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 145/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00145: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 146/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00146: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 166ms/step - loss: 0.0028 - val_loss: 9.1291e-04
# Epoch 147/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00147: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0026 - val_loss: 8.1133e-04
# Epoch 148/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00148: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0028 - val_loss: 9.9736e-04
# Epoch 149/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00149: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0028 - val_loss: 7.6835e-04
# Epoch 150/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00150: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0028 - val_loss: 8.6157e-04
# Epoch 151/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00151: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0032 - val_loss: 7.2742e-04
# Epoch 152/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00152: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0028 - val_loss: 8.8122e-04
# Epoch 153/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00153: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0030 - val_loss: 8.3926e-04
# Epoch 154/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00154: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 159ms/step - loss: 0.0027 - val_loss: 8.8490e-04
# Epoch 155/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00155: val_loss did not improve from 0.00064
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0029 - val_loss: 9.3287e-04
# Epoch 156/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00156: val_loss improved from 0.00064 to 0.00063, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0030 - val_loss: 6.3062e-04
# Epoch 157/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00157: val_loss did not improve from 0.00063
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0030 - val_loss: 7.2560e-04
# Epoch 158/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00158: val_loss improved from 0.00063 to 0.00060, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0031 - val_loss: 5.9969e-04
# Epoch 159/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00159: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0028 - val_loss: 7.4156e-04
# Epoch 160/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00160: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 159ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 161/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00161: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0027 - val_loss: 7.1024e-04
# Epoch 162/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00162: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0027 - val_loss: 8.5588e-04
# Epoch 163/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00163: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0030 - val_loss: 7.5737e-04
# Epoch 164/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00164: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0031 - val_loss: 9.0487e-04
# Epoch 165/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00165: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0030 - val_loss: 7.2159e-04
# Epoch 166/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00166: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0026 - val_loss: 0.0011
# Epoch 167/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00167: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 168/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00168: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0027 - val_loss: 6.9446e-04
# Epoch 169/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00169: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 160ms/step - loss: 0.0029 - val_loss: 9.7939e-04
# Epoch 170/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00170: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0031 - val_loss: 8.4364e-04
# Epoch 171/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00171: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 160ms/step - loss: 0.0033 - val_loss: 9.2093e-04
# Epoch 172/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00172: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 173/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00173: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0026 - val_loss: 6.5676e-04
# Epoch 174/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00174: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0031 - val_loss: 9.7752e-04
# Epoch 175/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00175: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 161ms/step - loss: 0.0025 - val_loss: 9.2723e-04
# Epoch 176/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00176: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0032 - val_loss: 6.1065e-04
# Epoch 177/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00177: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0028 - val_loss: 7.8556e-04
# Epoch 178/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00178: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0028 - val_loss: 9.2357e-04
# Epoch 179/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00179: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0030 - val_loss: 6.9882e-04
# Epoch 180/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00180: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0024 - val_loss: 6.2969e-04
# Epoch 181/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00181: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0028 - val_loss: 8.8789e-04
# Epoch 182/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00182: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 183/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00183: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0029 - val_loss: 7.9215e-04
# Epoch 184/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00184: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 166ms/step - loss: 0.0027 - val_loss: 7.4104e-04
# Epoch 185/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00185: val_loss did not improve from 0.00060
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0028 - val_loss: 7.3224e-04
# Epoch 186/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00186: val_loss improved from 0.00060 to 0.00056, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0032 - val_loss: 5.6426e-04
# Epoch 187/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00187: val_loss did not improve from 0.00056
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 188/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00188: val_loss improved from 0.00056 to 0.00047, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0025 - val_loss: 4.6975e-04
# Epoch 189/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00189: val_loss did not improve from 0.00047
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0026 - val_loss: 6.8837e-04
# Epoch 190/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00190: val_loss did not improve from 0.00047
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0026 - val_loss: 6.1108e-04
# Epoch 191/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00191: val_loss did not improve from 0.00047
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0029 - val_loss: 7.5587e-04
# Epoch 192/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00192: val_loss did not improve from 0.00047
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0027 - val_loss: 6.6715e-04
# Epoch 193/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00193: val_loss did not improve from 0.00047
# 39/39 [==============================] - 6s 163ms/step - loss: 0.0026 - val_loss: 7.6215e-04
# Epoch 194/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00194: val_loss did not improve from 0.00047
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0024 - val_loss: 6.6217e-04
# Epoch 195/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00195: val_loss did not improve from 0.00047
# 39/39 [==============================] - 6s 165ms/step - loss: 0.0022 - val_loss: 7.8526e-04
# Epoch 196/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00196: val_loss did not improve from 0.00047
# 39/39 [==============================] - 7s 168ms/step - loss: 0.0025 - val_loss: 7.9391e-04
# Epoch 197/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00197: val_loss did not improve from 0.00047
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 198/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00198: val_loss did not improve from 0.00047
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0025 - val_loss: 6.2755e-04
# Epoch 199/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00199: val_loss did not improve from 0.00047
# 39/39 [==============================] - 6s 164ms/step - loss: 0.0028 - val_loss: 6.0784e-04
# Epoch 200/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00200: val_loss did not improve from 0.00047
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0027 - val_loss: 5.8390e-04
# BestEpochResult. Epoch: 188, val_loss: 0.00047, loss: 0.00247,

# %% [markdown]
# ## Plot the loss curves for training and validation

# %%
plt.figure(figsize=(15,10))
plot_loss(history.history,"model",plt)
plt.legend()
plt.grid()
plt.yscale("log")
plt.xlabel("epoch")
plt.ylabel("log loss")
plt.show()

# %% [markdown]
# ## Delete the existing model + Load the best one

# %%
# deletes the existing model
del model

# Load last saved model
model = load_model(model_name + ".h5")

# %%
Y_val_pred = model.predict(X_val)

# %%
# Labels are vertices: x1, y1, x2, y2, x3, y3
# Where:
# - (0, 0) is the top left corner of the image
# - (1, 1) is the bottom right corner of the image
print("Y_val shape: ", Y_val.shape)
print("Y_val_pred shape: ", Y_val_pred.shape)
print("Real Label example: ", Y_val[0])
print("Prediction example: ", Y_val_pred[0])
# Out:
# Y_val shape:  (1370, 6)
# Y_val_pred shape:  (1370, 6)
# Real Label example:  [0.34 0.82 0.53 0.05 0.65 0.88]
# Prediction example:  [0.32803342 0.8046449  0.54298055 0.09882613 0.63751334 0.90722346]

# %% [markdown]
# # Calculate Dice accuracy for the whole Validation set

# %%
dice_val = calculate_Dice_for_set(Y_val, Y_val_pred, nb_vertices)
print(f"Validation Accuracy(Dice): {dice_val}.")
# Out:
# Validation Accuracy(Dice): 0.9213769355126837.

# %%
def plot_sample_with_pred(X, y, pred,axs):
    axs.imshow(X.reshape(image_size, image_size),cmap="gray") # Shape
    axs.scatter(image_size*y[0::2], image_size*y[1::2],c='orange') # Real Vertices
    axs.scatter(image_size*pred[0::2], image_size*pred[1::2],c='green') # Predicted Vertices

# %% [markdown]
# # Validation set predictions - Visualization

# %%
fig = plt.figure(figsize=(13, 21))
fig.subplots_adjust(hspace=0.13, wspace=0.01,
                    left=0, right=1, bottom=0, top=1.2)
nb_pictures = 32
count = 1
for irow in range(nb_pictures):
    ipic = np.random.choice(X_val.shape[0])
    ax = fig.add_subplot(nb_pictures/4 , 4, count,xticks=[],yticks=[])        
    plot_sample_with_pred(X_val[ipic], Y_val[ipic], Y_val_pred[ipic], ax)

    dice = calculate_Dice(Y_val[ipic], Y_val_pred[ipic], nb_vertices=nb_vertices)
    ax.set_title("dice {:5.3f}".format(dice))
    count += 1
plt.show()
# Out:
# <ipython-input-46-6c45d09a7f7e>:8: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax = fig.add_subplot(nb_pictures/4 , 4, count,xticks=[],yticks=[])

# %%
#TODO Display the 32 worst RMSE images

# %% [markdown]
# ## Predict for the test set

# %%
## Prepare the Test set
test_X = test_dict['test_data']
test_y = test_dict['test_labels']
print("test_X shape: ", test_X.shape)
print("test_y shape: ", test_y.shape)

X_test    = test_X.reshape(-1, image_size,image_size, 1)
Y_test    = test_y 
print("X_test shape: ", X_test.shape)
print("Y_test shape: ", Y_test.shape)
# Out:
# test_X shape:  (180, 70, 70)
# test_y shape:  (180, 6)
# X_test shape:  (180, 70, 70, 1)
# Y_test shape:  (180, 6)

# %%
# Show random images from the Test Set + superimposed vertices
indexes = np.arange(len(Y_test))
np.random.shuffle(indexes)
first_random_indexes = indexes[:100]

display_images_with_vertices(X_test[first_random_indexes], Y_test[first_random_indexes])

# %%
test_loss = model.evaluate(X_test, Y_test)
print("test_loss: ", test_loss)
# Out:
# 6/6 [==============================] - 0s 7ms/step - loss: 4.3857e-04
# test_loss:  0.0004385727515909821

# %%
Y_test_pred = model.predict(X_test)

# %%
print("Y_pred shape: ", Y_test_pred.shape)
Y_test_pred[0:2, :]
# Out:
# Y_pred shape:  (180, 6)
# array([[0.14852436, 0.7554783 , 0.49515206, 0.21187608, 0.869132  ,
#         0.70745397],
#        [0.1510497 , 0.67293155, 0.49445185, 0.29878187, 0.855115  ,
#         0.63702726]], dtype=float32)

# %% [markdown]
# # Calculate Dice accuracy for the whole Test set

# %%
dice_val = calculate_Dice_for_set(Y_test, Y_test_pred, nb_vertices)
print(f"Validation Accuracy(Dice): {dice_val}.")
# Out:
# Validation Accuracy(Dice): 0.933126812520332.

# %% [markdown]
# # Test set predictions - Visualization

# %%
fig = plt.figure(figsize=(13, 21))
fig.subplots_adjust(hspace=0.13, wspace=0.01,
                    left=0, right=1, bottom=0, top=1.2)
nb_pictures = 32
count = 1
for irow in range(nb_pictures):
    ipic = np.random.choice(X_test.shape[0])
    ax = fig.add_subplot(nb_pictures/4 , 4, count,xticks=[],yticks=[])        
    plot_sample_with_pred(X_test[ipic], Y_test[ipic], Y_test_pred[ipic], ax)
    
    try:
        dice = calculate_Dice(Y_test[ipic], Y_test_pred[ipic], nb_vertices=nb_vertices)
        ax.set_title("dice {:5.3f}".format(dice))
    except Exception as e:
        print(f"Cannot compute Dice for shape: {i}.")    
        
    count += 1
plt.show()
# Out:
# <ipython-input-54-033545e13e56>:8: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax = fig.add_subplot(nb_pictures/4 , 4, count,xticks=[],yticks=[])

# %% [markdown]
# # Conclusions
# Accuracy is generally good. We see that:
# - Most are very close to the real labels.
# - Some are off and between to real labels. See the first of 32 images above. I describe that issue [here](https://github.com/frobertpixto/hand_drawn_shapes_dataset/blob/main/processing/find_vertices/README.md).
#
#
# Regarding the loss, we have:
# - BestEpochResult. Epoch: 188, val_loss: **0.00047**
#
# For Mix on pix, when training for 1100 epoch, I had:
# - BestEpochResult. Epoch: 1090, val_loss: **0.00017**
#
# The model was definitively useful in [Mix on Pix](https://apps.apple.com/us/app/mix-on-pix-text-on-photos/id633281586).
#
# ## TensorFlow Lite Notes
# When creating a TensorFlow Lite model with quantization, accuracy can be a tiny bit lower, but the model size is 25% of the original. That's super important when running directly in a mobile app.

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 5, 28, 15, 17, 9, 90694)
