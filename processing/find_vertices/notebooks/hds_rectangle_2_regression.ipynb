# %% [markdown]
# # Train a model to estimate the vertices in an image - Rectangles
#
# Predict position of vertices for Rectangles.
# Using Supervised Learning with Tensorflow
#
# Data is received in 3 pickles that contain:
# 1. Train images and labels (vertices)
# 2. Validation images and labels (vertices)
# 3. Test images and labels (vertices)
#
# ---
# Francois Robert

# %%
# This notebook estimates the vertices for 1 shape
shape = "rectangle"

# %%
### Load packages
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

import seaborn as sns
sns.set(style='white', context='notebook', palette='deep')

import os
from pathlib import Path

from six.moves import cPickle as pickle

# %%
# More packages
import tensorflow as tf

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Input, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# Our modules
from hds_module.shape_utils import HdsDataGenerator, calculate_Dice, calculate_Dice_for_set  
from hds_module.utils import ShowBestEpochResult

import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 10, 1, 16, 2, 51, 977794)

# %%
# GPU Setting
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# Metal device set to: Apple M1 Max
# 2022-10-01 16:02:51.983906: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-01 16:02:51.984041: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
from platform import python_version
print(f'Python: {python_version()}')
# Out:
# Python: 3.9.13

# %%
import tensorflow as tf
print(f'Tensorflow: {tf.__version__}')
# Out:
# Tensorflow: 2.10.0

# %%
seed1 = 127
np.random.seed(seed1)

# %% [markdown]
# ## Define environment variables

# %%
BASEDIR = ".."

DATADIR = os.path.join(BASEDIR, "pickles")

TRAIN_DATAFILE = os.path.join(DATADIR, f"train_{shape}.pickle")
VAL_DATAFILE   = os.path.join(DATADIR, f"val_{shape}.pickle")
TEST_DATAFILE  = os.path.join(DATADIR, f"test_{shape}.pickle")

MODEL_DIR      = os.path.join(BASEDIR, "saved_models")
model_name     = os.path.join(MODEL_DIR, f"{shape}1.model")

# %%
# Set image properties
image_size  = 70     # Pixel width and height
pixel_depth = 255.0  # Number of levels per pixel

# %%
# Create model directory
Path(MODEL_DIR).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Load train, validation and test datasets from Pickles

# %%
with open(TRAIN_DATAFILE, 'rb') as file:
    train_dict = pickle.load(file)
with open(VAL_DATAFILE, 'rb') as file:
    val_dict = pickle.load(file)
with open(TEST_DATAFILE, 'rb') as file:
    test_dict = pickle.load(file)

# %%
# Load params used in ETL
params_dict = train_dict['params']

etl_shape = params_dict['shape']
nb_vertices = params_dict['nb_vertices']
anchor_x = params_dict['anchor_x']
anchor_y = params_dict['anchor_y']

print(f"{shape=}, {nb_vertices=}, {anchor_x=}, {anchor_y=}") 

assert shape == etl_shape, f"Invalid shape read. Expected: {shape}. Actual {etl_shape}."
# Out:
# shape='rectangle', nb_vertices=4, anchor_x=0.2, anchor_y=1.0

# %%
# Construct train set
train_X = train_dict['train_data']
train_y = train_dict['train_labels']

# %%
# Construct validation set
val_X = val_dict['val_data']
val_y = val_dict['val_labels']

# %%
print("train_X shape: ", train_X.shape)
print("train_y shape: ", train_y.shape)
# Out:
# train_X shape:  (5386, 70, 70)
# train_y shape:  (5386, 8)

# %%
print("val_X shape: ", val_X.shape)
print("val_y shape: ", val_y.shape)
# Out:
# val_X shape:  (1391, 70, 70)
# val_y shape:  (1391, 8)

# %%
# Reshape each image in 3 dimensions (height = 70px, width = 70px, canal = 1)
X_train = train_X.reshape(-1, image_size, image_size, 1)
X_val   = val_X.reshape(-1, image_size, image_size, 1)

# %%
Y_train = train_y
Y_val = val_y

# %%
X_train.shape
# Out:
# (5386, 70, 70, 1)

# %%
X_val.shape
# Out:
# (1391, 70, 70, 1)

# %%
# We expect to have 8 values for the labels of a rectangle.

# %%
Y_train.shape
# Out:
# (5386, 8)

# %%
Y_val.shape
# Out:
# (1391, 8)

# %%
# Labels are vertices: x1, y1, x2, y2, x3, y3, y4, y4
# Where:
# - (0, 0) is the top left corner of the image
# - (1, 1) is the bottom right corner of the image
print("Real Label example: ", Y_val[0])
# Out:
# Real Label example:  [0.28 0.87 0.27 0.13 0.77 0.12 0.78 0.88]

# %% [markdown]
# ## Let's visualize the data
# An image is worth a thousand words.

# %%
def plot_loss(hist,name,plt,RMSE_TF=False):
    '''
    RMSE_TF: if True, then RMSE is plotted with original scale 
    '''
    loss = hist['loss']
    val_loss = hist['val_loss']
    if RMSE_TF:
        loss = np.sqrt(np.array(loss))*48 
        val_loss = np.sqrt(np.array(val_loss))*48 
        
    plt.plot(loss,"--",linewidth=3,label="train:"+name)
    plt.plot(val_loss,linewidth=3,label="val:"+name)

# %%
def plot_sample(X, y, axs):
    axs.imshow(X.reshape(image_size, image_size), cmap="gray") # Put the Image
    y = y.ravel()
    axs.scatter(image_size * y[0::2], image_size * y[1::2], c='orange') # Add the labels as orange dots

# %%
# This function shows images with their real vertices
# Presentation is rows of 10 images
def display_images_with_vertices(X, Y):

    fig = plt.figure(figsize=(13, 9))
    fig.subplots_adjust(hspace=0.2,wspace=0.2,
                        left=0, right=1, bottom=0, top=1.5)

    nb_pictures = len(X)
    for i_pic in range(nb_pictures):
        x = X[i_pic]
        y = Y[i_pic]
        
        nb_per_row = 10
        nb_of_row  = (nb_pictures - 1) // nb_per_row + 1

        ax  = fig.add_subplot(nb_of_row, nb_per_row, i_pic + 1, xticks=[], yticks=[])
        plot_sample(x, y, ax)
    plt.show()

# %%
# Show random images from the Train Set + superimposed vertices
indexes = np.arange(len(Y_train))
np.random.shuffle(indexes)
first_random_indexes = indexes[:100]

display_images_with_vertices(X_train[first_random_indexes], Y_train[first_random_indexes])

# %%
# Show random images from the Validation Set + superimposed vertices
indexes = np.arange(len(Y_val))
np.random.shuffle(indexes)
first_random_indexes = indexes[:100]

display_images_with_vertices(X_val[first_random_indexes], Y_val[first_random_indexes])

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Define Deep Learning Model

# %%
def get_model_cnn():
    # Set the CNN model using Keras functional API
    input_img = Input(shape=(image_size,image_size,1))

    x = Conv2D(32, (5, 5), padding='same')(input_img)  # Conv2D 1
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Conv2D(32, (5, 5), padding='same')(x)          # Conv2D 2
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(64, (3, 3))(x)                          # Conv2D 3
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Conv2D(64, (3, 3))(x)                          # Conv2D 4
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Conv2D(128, (3, 3))(x)                         # Conv2D 5
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3))(x)                         # Conv2D 6
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.1)(x)

    x = Flatten()(x)
    x = Dense(160)(x)  
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    output = Dense(nb_vertices * 2)(x)

    model = Model(inputs=input_img, outputs=output)
    
    return model

# %%
# select a model
model = get_model_cnn()

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 70, 70, 1)]       0
#
#  conv2d (Conv2D)             (None, 70, 70, 32)        832
#
#  batch_normalization (BatchN  (None, 70, 70, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 70, 70, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 35, 35, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 35, 35, 32)        25632
#
#  batch_normalization_1 (Batc  (None, 35, 35, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 35, 35, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 33, 33, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 33, 33, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 33, 33, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 14, 14, 64)       256
#  hNormalization)
#
#  activation_3 (Activation)   (None, 14, 14, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 128)         73856
#
#  batch_normalization_4 (Batc  (None, 5, 5, 128)        512
#  hNormalization)
#
#  activation_4 (Activation)   (None, 5, 5, 128)         0
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 3, 3, 128)        512
#  hNormalization)
#
#  activation_5 (Activation)   (None, 3, 3, 128)         0
#
#  dropout (Dropout)           (None, 3, 3, 128)         0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 160)               184480
#
#  batch_normalization_6 (Batc  (None, 160)              640
#  hNormalization)
#
#  activation_6 (Activation)   (None, 160)               0
#
#  dense_1 (Dense)             (None, 8)                 1288
#
# =================================================================
# Total params: 491,528
# Trainable params: 490,312
# Non-trainable params: 1,216
# _________________________________________________________________
# 2022-10-01 16:02:55.445300: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-01 16:02:55.445319: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Data augmentation: Full rotation, Flip vert. and Horiz with Targets modified

# %%
# Partition for the Generator
partition = []

nb_samples = X_train.shape[0]
print("nb_samples: ", nb_samples)

for i in range(nb_samples):
    partition.append(i)
# Out:
# nb_samples:  5386

# %% [markdown]
# For the generator, I created a custom Generator that does augmentation:
# - Flips the images horizontally and vertically.
# - Rotate the images 360 degres.
# - **Adjust the labels (vertices) according to the flips and rotation.**
# - In particular, it manages the complexities of determining the first vertex.
#
# This is an improved and more complex version of my generator described at: https://github.com/frobertpixto/tf_keras_generator_with_targets
#
# Regarding **x_pos and y_pos**, this is the **anchor** used to finding the first vertex that I describe in more details
# [here](https://github.com/frobertpixto/hand_drawn_shapes_dataset/blob/main/processing/find_vertices/README.md).

# %%
batch_size = 128
hds_gen = HdsDataGenerator(partition, X_train, Y_train, batch_size=batch_size,
                           n_vertices=nb_vertices,
                           x_pos=anchor_x,
                           y_pos=anchor_y)

# %% [markdown]
# ## Define the optimizer

# %%
optimizer = Adam(lr=4e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0, amsgrad=False)
# Out:
# /Users/frobert/miniforge-envs/tensorflow-test/env/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# # Compile the model

# %%
model.compile(optimizer = optimizer , loss = "mean_squared_error")

# %% [markdown]
# # Set a learning rate callback

# %%
# when running for 1000 epoch, the reduction must be very slow.
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss',
                                            patience=25,
                                            verbose=1,
                                            factor=0.90, 
                                            mode='min',
                                            min_delta=0.0000001,
                                            min_lr=0.000000001)

# %% [markdown]
# # Fit the model with data Augmentation

# %%
# I like to start a few epoch with a small batch size because:
# - This basically makes the learning rate larger. https://openreview.net/pdf?id=B1Yy1BxCZ#:~:text=Increasing%20the%20batch%20size%20during%20training%20achieves%20similar%20results%20to,twice%20to%20illustrate%20the%20variance.
# - This covers to 0 to 80% of the accuracy/loss curve, cleaning the graphs
epochs = 6
history = model.fit(x=hds_gen,
                    epochs = epochs, validation_data = (X_val,Y_val),
                    verbose = 1, steps_per_epoch=X_train.shape[0] // batch_size)
# Out:
# Epoch 1/6
# 2022-10-01 16:02:55.798337: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-10-01 16:02:56.103178: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 42/42 [==============================] - ETA: 0s - loss: 0.1720
# 2022-10-01 16:03:01.781435: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 42/42 [==============================] - 7s 140ms/step - loss: 0.1720 - val_loss: 0.0905
# Epoch 2/6
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0131 - val_loss: 0.0650
# Epoch 3/6
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0107 - val_loss: 0.0451
# Epoch 4/6
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0093 - val_loss: 0.0472
# Epoch 5/6
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0081 - val_loss: 0.0349
# Epoch 6/6
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0080 - val_loss: 0.0368

# %%
# Fit and Save the Best model
h5_path    = model_name + ".h5"
checkpoint = ModelCheckpoint(h5_path, monitor='val_loss', verbose=1, save_best_only=True)

best_epoch_results = ShowBestEpochResult(on_param='val_loss', show_params=['val_loss', 'loss'], mode='min')

callbacks_list = [learning_rate_reduction, checkpoint, best_epoch_results]

epochs  = 200 #1000
history = model.fit(x=hds_gen,
                      epochs = epochs, validation_data = (X_val,Y_val),
                      verbose = 1, steps_per_epoch=X_train.shape[0] // batch_size,
                      callbacks=callbacks_list)
# Out:
# Epoch 1/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 1: val_loss improved from inf to 0.02737, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0080 - val_loss: 0.0274 - lr: 0.0040
# Epoch 2/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 2: val_loss improved from 0.02737 to 0.02423, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 130ms/step - loss: 0.0069 - val_loss: 0.0242 - lr: 0.0040
# Epoch 3/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 3: val_loss improved from 0.02423 to 0.01889, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0070 - val_loss: 0.0189 - lr: 0.0040
# Epoch 4/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 4: val_loss improved from 0.01889 to 0.01697, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0064 - val_loss: 0.0170 - lr: 0.0040
# Epoch 5/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 5: val_loss improved from 0.01697 to 0.01428, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 6s 131ms/step - loss: 0.0064 - val_loss: 0.0143 - lr: 0.0040
# Epoch 6/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 6: val_loss improved from 0.01428 to 0.01111, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0068 - val_loss: 0.0111 - lr: 0.0040
# Epoch 7/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 7: val_loss improved from 0.01111 to 0.00855, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 6s 130ms/step - loss: 0.0066 - val_loss: 0.0086 - lr: 0.0040
# Epoch 8/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 8: val_loss improved from 0.00855 to 0.00381, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0061 - val_loss: 0.0038 - lr: 0.0040
# Epoch 9/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 9: val_loss did not improve from 0.00381
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0059 - val_loss: 0.0041 - lr: 0.0040
# Epoch 10/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 10: val_loss improved from 0.00381 to 0.00353, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 6s 132ms/step - loss: 0.0055 - val_loss: 0.0035 - lr: 0.0040
# Epoch 11/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 11: val_loss improved from 0.00353 to 0.00185, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0059 - val_loss: 0.0019 - lr: 0.0040
# Epoch 12/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 12: val_loss improved from 0.00185 to 0.00184, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0056 - val_loss: 0.0018 - lr: 0.0040
# Epoch 13/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 13: val_loss did not improve from 0.00184
# 42/42 [==============================] - 6s 130ms/step - loss: 0.0050 - val_loss: 0.0033 - lr: 0.0040
# Epoch 14/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 14: val_loss did not improve from 0.00184
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0052 - val_loss: 0.0022 - lr: 0.0040
# Epoch 15/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 15: val_loss did not improve from 0.00184
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0052 - val_loss: 0.0019 - lr: 0.0040
# Epoch 16/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 16: val_loss did not improve from 0.00184
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0051 - val_loss: 0.0031 - lr: 0.0040
# Epoch 17/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 17: val_loss improved from 0.00184 to 0.00150, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0045 - val_loss: 0.0015 - lr: 0.0040
# Epoch 18/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 18: val_loss did not improve from 0.00150
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0046 - val_loss: 0.0019 - lr: 0.0040
# Epoch 19/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 19: val_loss did not improve from 0.00150
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0046 - val_loss: 0.0016 - lr: 0.0040
# Epoch 20/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 20: val_loss did not improve from 0.00150
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0049 - val_loss: 0.0023 - lr: 0.0040
# Epoch 21/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 21: val_loss improved from 0.00150 to 0.00145, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0045 - val_loss: 0.0014 - lr: 0.0040
# Epoch 22/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 22: val_loss did not improve from 0.00145
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0043 - val_loss: 0.0015 - lr: 0.0040
# Epoch 23/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 23: val_loss did not improve from 0.00145
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0048 - val_loss: 0.0024 - lr: 0.0040
# Epoch 24/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 24: val_loss did not improve from 0.00145
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0045 - val_loss: 0.0025 - lr: 0.0040
# Epoch 25/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 25: val_loss did not improve from 0.00145
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0050 - val_loss: 0.0020 - lr: 0.0040
# Epoch 26/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 26: val_loss did not improve from 0.00145
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0048 - val_loss: 0.0019 - lr: 0.0040
# Epoch 27/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 27: val_loss did not improve from 0.00145
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0046 - val_loss: 0.0015 - lr: 0.0040
# Epoch 28/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 28: val_loss did not improve from 0.00145
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0044 - val_loss: 0.0016 - lr: 0.0040
# Epoch 29/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 29: val_loss improved from 0.00145 to 0.00106, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0048 - val_loss: 0.0011 - lr: 0.0040
# Epoch 30/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 30: val_loss did not improve from 0.00106
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0044 - val_loss: 0.0024 - lr: 0.0040
# Epoch 31/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 31: val_loss did not improve from 0.00106
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0041 - val_loss: 0.0017 - lr: 0.0040
# Epoch 32/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 32: val_loss did not improve from 0.00106
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0041 - val_loss: 0.0018 - lr: 0.0040
# Epoch 33/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 33: val_loss did not improve from 0.00106
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0044 - val_loss: 0.0016 - lr: 0.0040
# Epoch 34/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 34: val_loss did not improve from 0.00106
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0042 - val_loss: 0.0017 - lr: 0.0040
# Epoch 35/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 35: val_loss did not improve from 0.00106
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0041 - val_loss: 0.0011 - lr: 0.0040
# Epoch 36/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 36: val_loss improved from 0.00106 to 0.00096, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0039 - val_loss: 9.5825e-04 - lr: 0.0040
# Epoch 37/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 37: val_loss did not improve from 0.00096
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0040 - val_loss: 0.0027 - lr: 0.0040
# Epoch 38/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 38: val_loss did not improve from 0.00096
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0044 - val_loss: 0.0014 - lr: 0.0040
# Epoch 39/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 39: val_loss did not improve from 0.00096
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0039 - val_loss: 0.0013 - lr: 0.0040
# Epoch 40/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 40: val_loss did not improve from 0.00096
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0039 - val_loss: 0.0016 - lr: 0.0040
# Epoch 41/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 41: val_loss did not improve from 0.00096
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0041 - val_loss: 0.0010 - lr: 0.0040
# Epoch 42/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 42: val_loss did not improve from 0.00096
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0036 - val_loss: 0.0014 - lr: 0.0040
# Epoch 43/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 43: val_loss did not improve from 0.00096
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0040 - val_loss: 0.0011 - lr: 0.0040
# Epoch 44/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 44: val_loss did not improve from 0.00096
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0045 - val_loss: 0.0012 - lr: 0.0040
# Epoch 45/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 45: val_loss did not improve from 0.00096
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0037 - val_loss: 0.0026 - lr: 0.0040
# Epoch 46/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 46: val_loss did not improve from 0.00096
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0036 - val_loss: 0.0013 - lr: 0.0040
# Epoch 47/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 47: val_loss did not improve from 0.00096
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0038 - val_loss: 0.0018 - lr: 0.0040
# Epoch 48/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 48: val_loss did not improve from 0.00096
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0035 - val_loss: 0.0011 - lr: 0.0040
# Epoch 49/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 49: val_loss did not improve from 0.00096
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0036 - val_loss: 0.0011 - lr: 0.0040
# Epoch 50/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 50: val_loss did not improve from 0.00096
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0037 - val_loss: 0.0017 - lr: 0.0040
# Epoch 51/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 51: val_loss improved from 0.00096 to 0.00090, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 130ms/step - loss: 0.0037 - val_loss: 9.0451e-04 - lr: 0.0040
# Epoch 52/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 52: val_loss did not improve from 0.00090
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0037 - val_loss: 0.0011 - lr: 0.0040
# Epoch 53/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 53: val_loss did not improve from 0.00090
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0037 - val_loss: 0.0016 - lr: 0.0040
# Epoch 54/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 54: val_loss did not improve from 0.00090
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0040 - val_loss: 0.0012 - lr: 0.0040
# Epoch 55/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 55: val_loss did not improve from 0.00090
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0034 - val_loss: 0.0011 - lr: 0.0040
# Epoch 56/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 56: val_loss did not improve from 0.00090
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0040 - val_loss: 0.0010 - lr: 0.0040
# Epoch 57/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 57: val_loss did not improve from 0.00090
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0037 - val_loss: 9.9543e-04 - lr: 0.0040
# Epoch 58/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 58: val_loss did not improve from 0.00090
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0038 - val_loss: 0.0011 - lr: 0.0040
# Epoch 59/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 59: val_loss did not improve from 0.00090
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0036 - val_loss: 0.0011 - lr: 0.0040
# Epoch 60/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 60: val_loss did not improve from 0.00090
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0036 - val_loss: 0.0011 - lr: 0.0040
# Epoch 61/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 61: val_loss improved from 0.00090 to 0.00080, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 130ms/step - loss: 0.0034 - val_loss: 7.9637e-04 - lr: 0.0040
# Epoch 62/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 62: val_loss did not improve from 0.00080
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0034 - val_loss: 0.0012 - lr: 0.0040
# Epoch 63/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 63: val_loss did not improve from 0.00080
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0032 - val_loss: 0.0010 - lr: 0.0040
# Epoch 64/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 64: val_loss did not improve from 0.00080
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0034 - val_loss: 9.6793e-04 - lr: 0.0040
# Epoch 65/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 65: val_loss did not improve from 0.00080
# 42/42 [==============================] - 6s 131ms/step - loss: 0.0034 - val_loss: 0.0013 - lr: 0.0040
# Epoch 66/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 66: val_loss did not improve from 0.00080
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0036 - val_loss: 8.8997e-04 - lr: 0.0040
# Epoch 67/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 67: val_loss did not improve from 0.00080
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0036 - val_loss: 0.0017 - lr: 0.0040
# Epoch 68/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 68: val_loss improved from 0.00080 to 0.00076, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0033 - val_loss: 7.5777e-04 - lr: 0.0040
# Epoch 69/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 69: val_loss did not improve from 0.00076
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0034 - val_loss: 7.7135e-04 - lr: 0.0040
# Epoch 70/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 70: val_loss did not improve from 0.00076
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0035 - val_loss: 0.0016 - lr: 0.0040
# Epoch 71/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 71: val_loss did not improve from 0.00076
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0032 - val_loss: 9.4751e-04 - lr: 0.0040
# Epoch 72/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 72: val_loss did not improve from 0.00076
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0033 - val_loss: 0.0012 - lr: 0.0040
# Epoch 73/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 73: val_loss did not improve from 0.00076
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0035 - val_loss: 9.6201e-04 - lr: 0.0040
# Epoch 74/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 74: val_loss did not improve from 0.00076
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0036 - val_loss: 0.0012 - lr: 0.0040
# Epoch 75/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 75: val_loss improved from 0.00076 to 0.00070, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0031 - val_loss: 6.9795e-04 - lr: 0.0040
# Epoch 76/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 76: val_loss did not improve from 0.00070
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0032 - val_loss: 0.0012 - lr: 0.0040
# Epoch 77/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 77: val_loss did not improve from 0.00070
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0032 - val_loss: 0.0012 - lr: 0.0040
# Epoch 78/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 78: val_loss did not improve from 0.00070
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0031 - val_loss: 9.7070e-04 - lr: 0.0040
# Epoch 79/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 79: val_loss did not improve from 0.00070
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0031 - val_loss: 8.7685e-04 - lr: 0.0040
# Epoch 80/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 80: val_loss did not improve from 0.00070
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0032 - val_loss: 7.3967e-04 - lr: 0.0040
# Epoch 81/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 81: val_loss did not improve from 0.00070
# 42/42 [==============================] - 5s 130ms/step - loss: 0.0031 - val_loss: 0.0011 - lr: 0.0040
# Epoch 82/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 82: val_loss did not improve from 0.00070
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0033 - val_loss: 0.0011 - lr: 0.0040
# Epoch 83/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 83: val_loss did not improve from 0.00070
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0033 - val_loss: 7.0680e-04 - lr: 0.0040
# Epoch 84/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 84: val_loss did not improve from 0.00070
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0033 - val_loss: 7.9570e-04 - lr: 0.0040
# Epoch 85/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 85: val_loss improved from 0.00070 to 0.00062, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 6s 130ms/step - loss: 0.0033 - val_loss: 6.1827e-04 - lr: 0.0040
# Epoch 86/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 86: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0030 - val_loss: 7.2053e-04 - lr: 0.0040
# Epoch 87/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 87: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0033 - val_loss: 9.5430e-04 - lr: 0.0040
# Epoch 88/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 88: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 130ms/step - loss: 0.0033 - val_loss: 0.0011 - lr: 0.0040
# Epoch 89/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 89: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0032 - val_loss: 8.6271e-04 - lr: 0.0040
# Epoch 90/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 90: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0029 - val_loss: 9.0741e-04 - lr: 0.0040
# Epoch 91/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 91: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 130ms/step - loss: 0.0031 - val_loss: 7.1757e-04 - lr: 0.0040
# Epoch 92/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 92: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0031 - val_loss: 6.6569e-04 - lr: 0.0040
# Epoch 93/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 93: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0031 - val_loss: 7.3844e-04 - lr: 0.0040
# Epoch 94/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 94: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0031 - val_loss: 0.0014 - lr: 0.0040
# Epoch 95/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 95: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0035 - val_loss: 9.1957e-04 - lr: 0.0040
# Epoch 96/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 96: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0033 - val_loss: 8.5864e-04 - lr: 0.0040
# Epoch 97/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 97: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0032 - val_loss: 0.0012 - lr: 0.0040
# Epoch 98/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 98: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0032 - val_loss: 8.0182e-04 - lr: 0.0040
# Epoch 99/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 99: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0029 - val_loss: 7.5206e-04 - lr: 0.0040
# Epoch 100/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 100: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0029 - val_loss: 0.0011 - lr: 0.0040
# Epoch 101/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 101: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0032 - val_loss: 6.8214e-04 - lr: 0.0040
# Epoch 102/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 102: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0031 - val_loss: 8.3008e-04 - lr: 0.0040
# Epoch 103/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 103: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0032 - val_loss: 8.5724e-04 - lr: 0.0040
# Epoch 104/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 104: val_loss did not improve from 0.00062
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0031 - val_loss: 7.8827e-04 - lr: 0.0040
# Epoch 105/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 105: val_loss improved from 0.00062 to 0.00061, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0032 - val_loss: 6.1441e-04 - lr: 0.0040
# Epoch 106/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 106: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0029 - val_loss: 7.6070e-04 - lr: 0.0040
# Epoch 107/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 107: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0026 - val_loss: 6.9307e-04 - lr: 0.0040
# Epoch 108/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 108: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0028 - val_loss: 7.6304e-04 - lr: 0.0040
# Epoch 109/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 109: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 124ms/step - loss: 0.0031 - val_loss: 8.6892e-04 - lr: 0.0040
# Epoch 110/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 110: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0029 - val_loss: 6.8544e-04 - lr: 0.0040
# Epoch 111/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 111: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0029 - val_loss: 8.2779e-04 - lr: 0.0040
# Epoch 112/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 112: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 130ms/step - loss: 0.0031 - val_loss: 9.8523e-04 - lr: 0.0040
# Epoch 113/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 113: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0029 - val_loss: 8.6523e-04 - lr: 0.0040
# Epoch 114/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 114: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0031 - val_loss: 8.1615e-04 - lr: 0.0040
# Epoch 115/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 115: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0028 - val_loss: 7.0824e-04 - lr: 0.0040
# Epoch 116/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 116: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0030 - val_loss: 8.4586e-04 - lr: 0.0040
# Epoch 117/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 117: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0030 - val_loss: 7.0360e-04 - lr: 0.0040
# Epoch 118/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 118: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0031 - val_loss: 9.5412e-04 - lr: 0.0040
# Epoch 119/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 119: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0031 - val_loss: 9.7906e-04 - lr: 0.0040
# Epoch 120/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 120: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0031 - val_loss: 7.3321e-04 - lr: 0.0040
# Epoch 121/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 121: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0030 - val_loss: 8.6570e-04 - lr: 0.0040
# Epoch 122/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 122: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0027 - val_loss: 8.0414e-04 - lr: 0.0040
# Epoch 123/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 123: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0031 - val_loss: 7.1608e-04 - lr: 0.0040
# Epoch 124/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 124: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0028 - val_loss: 7.1853e-04 - lr: 0.0040
# Epoch 125/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 125: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0031 - val_loss: 0.0011 - lr: 0.0040
# Epoch 126/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 126: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0030 - val_loss: 6.8978e-04 - lr: 0.0040
# Epoch 127/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 127: val_loss improved from 0.00061 to 0.00061, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0027 - val_loss: 6.1006e-04 - lr: 0.0040
# Epoch 128/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 128: val_loss did not improve from 0.00061
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0028 - val_loss: 0.0011 - lr: 0.0040
# Epoch 129/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 129: val_loss improved from 0.00061 to 0.00059, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0032 - val_loss: 5.8927e-04 - lr: 0.0040
# Epoch 130/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 130: val_loss did not improve from 0.00059
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0028 - val_loss: 6.0280e-04 - lr: 0.0040
# Epoch 131/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 131: val_loss did not improve from 0.00059
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0028 - val_loss: 9.0770e-04 - lr: 0.0040
# Epoch 132/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 132: val_loss did not improve from 0.00059
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0028 - val_loss: 9.4888e-04 - lr: 0.0040
# Epoch 133/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 133: val_loss did not improve from 0.00059
# 42/42 [==============================] - 5s 130ms/step - loss: 0.0027 - val_loss: 6.2105e-04 - lr: 0.0040
# Epoch 134/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 134: val_loss did not improve from 0.00059
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0027 - val_loss: 6.0513e-04 - lr: 0.0040
# Epoch 135/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 135: val_loss did not improve from 0.00059
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0026 - val_loss: 7.9333e-04 - lr: 0.0040
# Epoch 136/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 136: val_loss did not improve from 0.00059
# 42/42 [==============================] - 5s 124ms/step - loss: 0.0030 - val_loss: 7.4492e-04 - lr: 0.0040
# Epoch 137/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 137: val_loss did not improve from 0.00059
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0028 - val_loss: 0.0013 - lr: 0.0040
# Epoch 138/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 138: val_loss did not improve from 0.00059
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0026 - val_loss: 7.8474e-04 - lr: 0.0040
# Epoch 139/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 139: val_loss did not improve from 0.00059
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0030 - val_loss: 8.5812e-04 - lr: 0.0040
# Epoch 140/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 140: val_loss did not improve from 0.00059
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0027 - val_loss: 6.4671e-04 - lr: 0.0040
# Epoch 141/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 141: val_loss improved from 0.00059 to 0.00051, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0025 - val_loss: 5.0880e-04 - lr: 0.0040
# Epoch 142/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 142: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0029 - val_loss: 7.2689e-04 - lr: 0.0040
# Epoch 143/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 143: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 124ms/step - loss: 0.0026 - val_loss: 6.6697e-04 - lr: 0.0040
# Epoch 144/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 144: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0029 - val_loss: 8.9988e-04 - lr: 0.0040
# Epoch 145/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 145: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 124ms/step - loss: 0.0031 - val_loss: 7.5219e-04 - lr: 0.0040
# Epoch 146/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 146: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0029 - val_loss: 7.0280e-04 - lr: 0.0040
# Epoch 147/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 147: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0027 - val_loss: 7.4713e-04 - lr: 0.0040
# Epoch 148/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 148: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0027 - val_loss: 8.4165e-04 - lr: 0.0040
# Epoch 149/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 149: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0028 - val_loss: 8.3804e-04 - lr: 0.0040
# Epoch 150/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 150: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0030 - val_loss: 7.1371e-04 - lr: 0.0040
# Epoch 151/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 151: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0030 - val_loss: 6.7316e-04 - lr: 0.0040
# Epoch 152/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 152: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0025 - val_loss: 5.6195e-04 - lr: 0.0040
# Epoch 153/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 153: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0027 - val_loss: 7.3485e-04 - lr: 0.0040
# Epoch 154/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 154: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0027 - val_loss: 5.6945e-04 - lr: 0.0040
# Epoch 155/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 155: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0026 - val_loss: 9.4346e-04 - lr: 0.0040
# Epoch 156/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 156: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0027 - val_loss: 7.1760e-04 - lr: 0.0040
# Epoch 157/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 157: val_loss did not improve from 0.00051
# 42/42 [==============================] - 6s 131ms/step - loss: 0.0030 - val_loss: 6.9986e-04 - lr: 0.0040
# Epoch 158/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 158: val_loss did not improve from 0.00051
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0025 - val_loss: 6.7108e-04 - lr: 0.0040
# Epoch 159/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 159: val_loss improved from 0.00051 to 0.00048, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0026 - val_loss: 4.7861e-04 - lr: 0.0040
# Epoch 160/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 160: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 130ms/step - loss: 0.0026 - val_loss: 6.5317e-04 - lr: 0.0040
# Epoch 161/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 161: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0027 - val_loss: 8.3228e-04 - lr: 0.0040
# Epoch 162/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 162: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0027 - val_loss: 5.7948e-04 - lr: 0.0040
# Epoch 163/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 163: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0027 - val_loss: 6.1146e-04 - lr: 0.0040
# Epoch 164/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 164: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0027 - val_loss: 6.6624e-04 - lr: 0.0040
# Epoch 165/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 165: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0027 - val_loss: 4.9531e-04 - lr: 0.0040
# Epoch 166/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 166: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0031 - val_loss: 7.3983e-04 - lr: 0.0040
# Epoch 167/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 167: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0031 - val_loss: 7.1917e-04 - lr: 0.0040
# Epoch 168/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 168: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0028 - val_loss: 8.8266e-04 - lr: 0.0040
# Epoch 169/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 169: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0028 - val_loss: 5.8484e-04 - lr: 0.0040
# Epoch 170/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 170: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0026 - val_loss: 6.9509e-04 - lr: 0.0040
# Epoch 171/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 171: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0028 - val_loss: 6.4179e-04 - lr: 0.0040
# Epoch 172/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 172: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0025 - val_loss: 6.3916e-04 - lr: 0.0040
# Epoch 173/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 173: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0025 - val_loss: 6.0471e-04 - lr: 0.0040
# Epoch 174/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 174: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0025 - val_loss: 7.0882e-04 - lr: 0.0040
# Epoch 175/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 175: val_loss did not improve from 0.00048
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0029 - val_loss: 9.1212e-04 - lr: 0.0040
# Epoch 176/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 176: val_loss improved from 0.00048 to 0.00046, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 6s 131ms/step - loss: 0.0029 - val_loss: 4.6455e-04 - lr: 0.0040
# Epoch 177/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 177: val_loss did not improve from 0.00046
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0025 - val_loss: 6.4916e-04 - lr: 0.0040
# Epoch 178/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 178: val_loss did not improve from 0.00046
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0027 - val_loss: 6.3453e-04 - lr: 0.0040
# Epoch 179/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 179: val_loss did not improve from 0.00046
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0026 - val_loss: 5.7900e-04 - lr: 0.0040
# Epoch 180/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 180: val_loss did not improve from 0.00046
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0024 - val_loss: 5.9074e-04 - lr: 0.0040
# Epoch 181/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 181: val_loss did not improve from 0.00046
# 42/42 [==============================] - 5s 125ms/step - loss: 0.0028 - val_loss: 8.3719e-04 - lr: 0.0040
# Epoch 182/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 182: val_loss did not improve from 0.00046
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0025 - val_loss: 5.6101e-04 - lr: 0.0040
# Epoch 183/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 183: val_loss improved from 0.00046 to 0.00045, saving model to ../saved_models/rectangle1.model.h5
# 42/42 [==============================] - 5s 129ms/step - loss: 0.0024 - val_loss: 4.4950e-04 - lr: 0.0040
# Epoch 184/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 184: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0024 - val_loss: 5.7197e-04 - lr: 0.0040
# Epoch 185/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 185: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0025 - val_loss: 5.5246e-04 - lr: 0.0040
# Epoch 186/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 186: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0025 - val_loss: 9.4804e-04 - lr: 0.0040
# Epoch 187/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 187: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0023 - val_loss: 7.9704e-04 - lr: 0.0040
# Epoch 188/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 188: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0028 - val_loss: 9.0369e-04 - lr: 0.0040
# Epoch 189/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 189: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 130ms/step - loss: 0.0024 - val_loss: 5.1585e-04 - lr: 0.0040
# Epoch 190/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 190: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0024 - val_loss: 7.9269e-04 - lr: 0.0040
# Epoch 191/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 191: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0024 - val_loss: 6.2641e-04 - lr: 0.0040
# Epoch 192/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 192: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0026 - val_loss: 5.3475e-04 - lr: 0.0040
# Epoch 193/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 193: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0025 - val_loss: 7.8135e-04 - lr: 0.0040
# Epoch 194/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 194: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0028 - val_loss: 7.2851e-04 - lr: 0.0040
# Epoch 195/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 195: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 128ms/step - loss: 0.0027 - val_loss: 6.9353e-04 - lr: 0.0040
# Epoch 196/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 196: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0026 - val_loss: 6.5740e-04 - lr: 0.0040
# Epoch 197/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 197: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0022 - val_loss: 5.4376e-04 - lr: 0.0040
# Epoch 198/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 198: val_loss did not improve from 0.00045
# 42/42 [==============================] - 6s 130ms/step - loss: 0.0026 - val_loss: 6.0796e-04 - lr: 0.0040
# Epoch 199/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 199: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0027 - val_loss: 6.8006e-04 - lr: 0.0040
# Epoch 200/200
# 42/42 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 200: val_loss did not improve from 0.00045
# 42/42 [==============================] - 5s 127ms/step - loss: 0.0025 - val_loss: 5.2159e-04 - lr: 0.0040
# BestEpochResult. Epoch: 183, val_loss: 0.00045, loss: 0.00242,

# %% [markdown]
# ## Plot the loss curves for training and validation

# %%
plt.figure(figsize=(15,10))
plot_loss(history.history,"model",plt)
plt.legend()
plt.grid()
plt.yscale("log")
plt.xlabel("epoch")
plt.ylabel("log loss")
plt.show()

# %% [markdown]
# ## Delete the existing model + Load the best one

# %%
# deletes the existing model
del model

# Load last saved model
model = load_model(model_name + ".h5")

# %%
Y_val_pred = model.predict(X_val)
# Out:
# 25/44 [================>.............] - ETA: 0s
# 2022-10-01 16:21:28.113741: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 44/44 [==============================] - 0s 5ms/step

# %%
# Labels are vertices: x1, y1, x2, y2, x3, y3, y4, y4
# Where:
# - (0, 0) is the top left corner of the image
# - (1, 1) is the bottom right corner of the image
print("Y_val shape: ", Y_val.shape)
print("Y_val_pred shape: ", Y_val_pred.shape)
print("Real Label example: ", Y_val[0])
print("Prediction example: ", Y_val_pred[0])
# Out:
# Y_val shape:  (1391, 8)
# Y_val_pred shape:  (1391, 8)
# Real Label example:  [0.28 0.87 0.27 0.13 0.77 0.12 0.78 0.88]
# Prediction example:  [0.2720173  0.8855158  0.27423584 0.1235249  0.72874725 0.12884778
#  0.7322459  0.86502385]

# %% [markdown]
# # Calculate Dice accuracy for the whole Validation set
#
# To get more information about Dice accuracy, see: https://github.com/frobertpixto/ml_dice_and_iou_accuracy

# %%
dice_val = calculate_Dice_for_set(Y_val, Y_val_pred, nb_vertices)
print(f"Validation Accuracy(Dice): {dice_val}.")
# Out:
# 681574751195 0.13594704874026636
# 740003798426 0.61838752582595724
# 8521657952828 0.5570866011643465
# Cannot compute Dice for shape: 95.
# Cannot compute Dice for shape: 96.
# Cannot compute Dice for shape: 107.
# Validation Accuracy(Dice): 0.9336668642928193.

# %%
def plot_sample_with_pred(X, y, pred,axs):
    axs.imshow(X.reshape(image_size, image_size),cmap="gray") # Shape
    axs.scatter(image_size*y[0::2], image_size*y[1::2],c='orange') # Real Vertices
    axs.scatter(image_size*pred[0::2], image_size*pred[1::2],c='green') # Predicted Vertices

# %% [markdown]
# # Validation set predictions - Visualization
# - Orange dot: Real Vertex
# - Green dot: Predicted Vertex

# %%
fig = plt.figure(figsize=(13, 21))
fig.subplots_adjust(hspace=0.13, wspace=0.01,
                    left=0, right=1, bottom=0, top=1.2)
nb_pictures = 32
count = 1
for irow in range(nb_pictures):
    ipic = np.random.choice(X_val.shape[0])
    ax = fig.add_subplot(nb_pictures // 4, 4, count,xticks=[],yticks=[])        
    plot_sample_with_pred(X_val[ipic], Y_val[ipic], Y_val_pred[ipic], ax)

    dice = calculate_Dice(Y_val[ipic], Y_val_pred[ipic], nb_vertices=nb_vertices)
    ax.set_title("dice {:5.3f}".format(dice))
    count += 1
plt.show()

# %%
#TODO Display the 32 worst RMSE images

# %% [markdown]
# ## Predict for the test set

# %%
## Prepare the Test set
test_X = test_dict['test_data']
test_y = test_dict['test_labels']
print("test_X shape: ", test_X.shape)
print("test_y shape: ", test_y.shape)

X_test    = test_X.reshape(-1, image_size,image_size, 1)
Y_test    = test_y 
print("X_test shape: ", X_test.shape)
print("Y_test shape: ", Y_test.shape)
# Out:
# test_X shape:  (179, 70, 70)
# test_y shape:  (179, 8)
# X_test shape:  (179, 70, 70, 1)
# Y_test shape:  (179, 8)

# %%
# Show random images from the Test Set + superimposed vertices
indexes = np.arange(len(Y_test))
np.random.shuffle(indexes)
first_random_indexes = indexes[:100]

display_images_with_vertices(X_test[first_random_indexes], Y_test[first_random_indexes])

# %%
test_loss = model.evaluate(X_test, Y_test)
print("test_loss: ", test_loss)
# Out:
# 6/6 [==============================] - 0s 15ms/step - loss: 3.2558e-04
# test_loss:  0.0003255822230130434
# 2022-10-01 16:22:18.025797: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
Y_test_pred = model.predict(X_test)
# Out:
# 6/6 [==============================] - 0s 11ms/step

# %%
print("Y_pred shape: ", Y_test_pred.shape)
Y_test_pred[0:2, :]
# Out:
# Y_pred shape:  (179, 8)
# array([[0.3187458 , 0.74815345, 0.33006075, 0.21178345, 0.67152464,
#         0.21123452, 0.65328014, 0.74433124],
#        [0.14124188, 0.6786203 , 0.17360556, 0.26652774, 0.8628905 ,
#         0.30056265, 0.8582059 , 0.7018616 ]], dtype=float32)

# %% [markdown]
# # Calculate Dice accuracy for the whole Test set

# %%
dice_val = calculate_Dice_for_set(Y_test, Y_test_pred, nb_vertices)
print(f"Validation Accuracy(Dice): {dice_val}.")
# Out:
# Validation Accuracy(Dice): 0.9503141035856314.

# %% [markdown]
# # Test set predictions - Visualization
# - Orange dot: Real Vertex
# - Green dot: Predicted Vertex

# %%
fig = plt.figure(figsize=(13, 21))
fig.subplots_adjust(hspace=0.13, wspace=0.01,
                    left=0, right=1, bottom=0, top=1.2)
nb_pictures = 32
count = 1
for irow in range(nb_pictures):
    ipic = np.random.choice(X_test.shape[0])
    ax = fig.add_subplot(nb_pictures // 4, 4, count,xticks=[],yticks=[])        
    plot_sample_with_pred(X_test[ipic], Y_test[ipic], Y_test_pred[ipic], ax)
    
    try:
        dice = calculate_Dice(Y_test[ipic], Y_test_pred[ipic], nb_vertices=nb_vertices)
        ax.set_title("dice {:5.3f}".format(dice))
    except Exception as e:
        print(f"Cannot compute Dice for shape: {i}.")    
        
    count += 1
plt.show()

# %% [markdown]
# # Conclusions
# Accuracy is generally good. We see that:
# - Most are very close to the real labels.
# - Some are off and between to real labels. I describe that issue [here](https://github.com/frobertpixto/hand_drawn_shapes_dataset/blob/main/processing/find_vertices/README.md).
#
#
# Regarding the loss, we have:
# - BestEpochResult. Epoch: 183, val_loss: **0.00045**
#
# For Mix on pix, when training for 1000 epoch, I had:
# - BestEpochResult. Epoch: 977, val_loss: **0.00021**
#
# The model was definitively useful in [Mix on Pix](https://apps.apple.com/us/app/mix-on-pix-text-on-photos/id633281586).
#
# ## TensorFlow Lite Notes
# When creating a TensorFlow Lite model with quantization, accuracy can be a tiny bit lower, but the model size is 25% of the original. That's super important when running **directly in a mobile app**.

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 10, 1, 16, 23, 53, 452859)
