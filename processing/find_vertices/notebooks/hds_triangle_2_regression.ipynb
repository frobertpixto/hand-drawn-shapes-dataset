# %% [markdown]
# # Train a model to estimate the vertices in an image - Triangles
#
# Predict position of vertices for Triangles.
# Using Supervised Learning with Tensorflow
#
# Data is received in 3 pickles that contain:
# 1. Train images and labels (vertices)
# 2. Validation images and labels (vertices)
# 3. Test images and labels (vertices)
#
# ---
# Francois Robert

# %%
# This notebook estimates the vertices for 1 shape
shape = "triangle"

# %%
### Load packages
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

import seaborn as sns
sns.set(style='white', context='notebook', palette='deep')

import os
from pathlib import Path

from six.moves import cPickle as pickle

# %%
# More packages
import tensorflow as tf

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Input, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# Our modules
from hds_module.shape_utils import HdsDataGenerator, calculate_Dice, calculate_Dice_for_set  
from hds_module.utils import ShowBestEpochResult

import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 6, 14, 22, 11, 51, 98065)

# %%
# GPU Setting
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# 2025-06-14 22:11:51.103498: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2025-06-14 22:11:51.103519: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2025-06-14 22:11:51.103524: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2025-06-14 22:11:51.103543: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-06-14 22:11:51.103555: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
from platform import python_version
print(f'Python: {python_version()}')
# Out:
# Python: 3.11.12

# %%
import tensorflow as tf
print(f'Tensorflow: {tf.__version__}')
# Out:
# Tensorflow: 2.16.2

# %%
seed1=127
np.random.seed(seed1)

# %% [markdown]
# ## Define environment variables

# %%
BASEDIR = ".."

DATADIR = os.path.join(BASEDIR, "pickles")

TRAIN_DATAFILE = os.path.join(DATADIR, f"train_{shape}.pickle")
VAL_DATAFILE   = os.path.join(DATADIR, f"val_{shape}.pickle")
TEST_DATAFILE  = os.path.join(DATADIR, f"test_{shape}.pickle")

MODEL_DIR      = os.path.join(BASEDIR, "saved_models")
model_filename = os.path.join(MODEL_DIR, f"{shape}1.model.keras")

# %%
# Set image properties
image_size  = 70     # Pixel width and height
pixel_depth = 255.0  # Number of levels per pixel

# %%
# Create model directory
Path(MODEL_DIR).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Load train, validation and test datasets from Pickles

# %%
with open(TRAIN_DATAFILE, 'rb') as file:
    train_dict = pickle.load(file)
with open(VAL_DATAFILE, 'rb') as file:
    val_dict = pickle.load(file)
with open(TEST_DATAFILE, 'rb') as file:
    test_dict = pickle.load(file)

# %%
# Load params used in ETL
params_dict = train_dict['params']

etl_shape = params_dict['shape']
nb_vertices = params_dict['nb_vertices']
anchor_x = params_dict['anchor_x']
anchor_y = params_dict['anchor_y']

print(f"{shape=}, {nb_vertices=}, {anchor_x=}, {anchor_y=}") 

assert shape == etl_shape, f"Invalid shape read. Expected: {shape}. Actual {etl_shape}."
# Out:
# shape='triangle', nb_vertices=3, anchor_x=0.2, anchor_y=1.0

# %%
# Construct train set
train_X = train_dict['train_data']
train_y = train_dict['train_labels']

# %%
# Construct validation set
val_X = val_dict['val_data']
val_y = val_dict['val_labels']

# %%
print("train_X shape: ", train_X.shape)
print("train_y shape: ", train_y.shape)
# Out:
# train_X shape:  (5045, 70, 70)
# train_y shape:  (5045, 6)

# %%
print("val_X shape: ", val_X.shape)
print("val_y shape: ", val_y.shape)
# Out:
# val_X shape:  (1370, 70, 70)
# val_y shape:  (1370, 6)

# %%
# Reshape each image in 3 dimensions (height = 70px, width = 70px, canal = 1)
X_train = train_X.reshape(-1, image_size, image_size, 1)
X_val   = val_X.reshape(-1, image_size, image_size, 1)

# %%
Y_train = train_y
Y_val = val_y

# %%
X_train.shape
# Out:
# (5045, 70, 70, 1)

# %%
X_val.shape
# Out:
# (1370, 70, 70, 1)

# %%
# We expect to have 6 values for the labels of a triangle.

# %%
Y_train.shape
# Out:
# (5045, 6)

# %%
Y_val.shape
# Out:
# (1370, 6)

# %%
# Labels are vertices: x1, y1, x2, y2, x3, y3
# Where:
# - (0, 0) is the top left corner of the image
# - (1, 1) is the bottom right corner of the image
print("Real Label example: ", Y_val[0])
# Out:
# Real Label example:  [0.34 0.82 0.53 0.05 0.65 0.88]

# %% [markdown]
# ## Let's visualize the data
# An image is worth a thousand words.

# %%
def plot_loss(hist,name,plt,RMSE_TF=False):
    '''
    RMSE_TF: if True, then RMSE is plotted with original scale 
    '''
    loss = hist['loss']
    val_loss = hist['val_loss']
    if RMSE_TF:
        loss = np.sqrt(np.array(loss))*48 
        val_loss = np.sqrt(np.array(val_loss))*48 
        
    plt.plot(loss,"--",linewidth=3,label="train:"+name)
    plt.plot(val_loss,linewidth=3,label="val:"+name)

# %%
def plot_sample(X, y, axs):
    axs.imshow(X.reshape(image_size, image_size), cmap="gray") # Put the Image
    y = y.ravel()
    axs.scatter(image_size * y[0::2], image_size * y[1::2], c='orange') # Add the labels as orange dots

# %%
# This function shows images with their real vertices
# Presentation is rows of 10 images
def display_images_with_vertices(X, Y):

    fig = plt.figure(figsize=(13, 9))
    fig.subplots_adjust(hspace=0.2,wspace=0.2,
                        left=0, right=1, bottom=0, top=1.5)

    nb_pictures = len(X)
    for i_pic in range(nb_pictures):
        x = X[i_pic]
        y = Y[i_pic]
        
        nb_per_row = 10
        nb_of_row  = (nb_pictures - 1) // nb_per_row + 1

        ax  = fig.add_subplot(nb_of_row, nb_per_row, i_pic + 1, xticks=[], yticks=[])
        plot_sample(x, y, ax)
    plt.show()

# %%
# Show random images from the Train Set + superimposed vertices
indexes = np.arange(len(Y_train))
np.random.shuffle(indexes)
first_random_indexes = indexes[:100]

display_images_with_vertices(X_train[first_random_indexes], Y_train[first_random_indexes])

# %%
# Show random images from the Validation Set + superimposed vertices
indexes = np.arange(len(Y_val))
np.random.shuffle(indexes)
first_random_indexes = indexes[:100]

display_images_with_vertices(X_val[first_random_indexes], Y_val[first_random_indexes])

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Define Deep Learning Model

# %%
def get_model_cnn():
    # Set the CNN model using Keras functional API
    input_img = Input(shape=(image_size, image_size, 1))

    x = Conv2D(32, (5, 5), padding='same')(input_img)  # Conv2D 1
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Conv2D(32, (5, 5), padding='same')(x)          # Conv2D 2
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(64, (3, 3))(x)                          # Conv2D 3
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Conv2D(64, (3, 3))(x)                          # Conv2D 4
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Conv2D(128, (3, 3))(x)                         # Conv2D 5
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3))(x)                         # Conv2D 6
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.1)(x)

    x = Flatten()(x)
    x = Dense(160)(x)  
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    output = Dense(nb_vertices * 2)(x)

    model = Model(inputs=input_img, outputs=output)
    
    return model

# %%
# select a model
model = get_model_cnn()

model.summary()
# Out:
# 2025-06-14 22:11:53.173545: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-06-14 22:11:53.173564: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 70, 70, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 70, 70, 32)     │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 70, 70, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 70, 70, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 35, 35, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 35, 35, 32)     │        25,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 35, 35, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 35, 35, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 33, 33, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 33, 33, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 33, 33, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 14, 14, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 14, 14, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 5, 5, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 5, 5, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 5, 5, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 3, 3, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 3, 3, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 160)            │       184,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 160)            │           640 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           966 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491,206 (1.87 MB)
#  Trainable params: 489,990 (1.87 MB)
#  Non-trainable params: 1,216 (4.75 KB)

# %% [markdown]
# ## Data augmentation: Full rotation, Flip vert. and Horiz with Targets modified

# %%
# Partition for the Generator
partition = []

nb_samples = X_train.shape[0]
print("nb_samples: ", nb_samples)

for i in range(nb_samples):
    partition.append(i)
# Out:
# nb_samples:  5045

# %% [markdown]
# For the generator, I created a custom Generator that does augmentation:
# - Flips the images horizontally and vertically.
# - Rotate the images 360 degres.
# - **Adjust the labels (vertices) according to the flips and rotation.**
# - In particular, it manages the complexities of determining the first vertex.
#
# This is an improved and more complex version of my generator described at: https://github.com/frobertpixto/tf_keras_generator_with_targets
#
# Regarding **x_pos and y_pos**, this is the **anchor** used to finding the first vertex that I describe in more details
# [here](https://github.com/frobertpixto/hand_drawn_shapes_dataset/blob/main/processing/find_vertices/README.md).

# %%
batch_size = 128
hds_gen = HdsDataGenerator(partition, X_train, Y_train, batch_size=batch_size,
                           n_vertices=nb_vertices,
                           x_pos=anchor_x,
                           y_pos=anchor_y)

# %% [markdown]
# ## Define the optimizer

# %%
optimizer = Adam(learning_rate=4e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-08, amsgrad=False)

# %% [markdown]
# # Compile the model

# %%
model.compile(optimizer = optimizer , loss = "mean_squared_error")

# %% [markdown]
# # Set a learning rate callback

# %%
# when running for 1000 epoch, the reduction must be very slow.
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss',
                                            patience=28,
                                            verbose=1,
                                            factor=0.90, 
                                            mode='min',
                                            min_delta=0.0000001,
                                            min_lr=0.000000001)

# %% [markdown]
# # Fit the model with data Augmentation

# %%
# I like to start a few epoch with a small batch size because:
# - This basically makes the learning rate larger. https://openreview.net/pdf?id=B1Yy1BxCZ#:~:text=Increasing%20the%20batch%20size%20during%20training%20achieves%20similar%20results%20to,twice%20to%20illustrate%20the%20variance.
# - This covers to 0 to 80% of the accuracy/loss curve, cleaning the graphs
epochs = 6
history = model.fit(x=hds_gen,
                    epochs = epochs, validation_data = (X_val,Y_val),
                    verbose = 1, steps_per_epoch=X_train.shape[0] // batch_size)
# Out:
# /Users/frobert/miniforge3/envs/tensorflow-2025-01/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/6
# 2025-06-14 22:11:54.445722: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - loss: 0.4856 - val_loss: 0.1209
# Epoch 2/6
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0241 - val_loss: 0.0566
# Epoch 3/6
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0171 - val_loss: 0.0453
# Epoch 4/6
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0158 - val_loss: 0.0339
# Epoch 5/6
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0139 - val_loss: 0.0347
# Epoch 6/6
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0139 - val_loss: 0.0430

# %%
# Fit and Save the Best model
checkpoint = ModelCheckpoint(model_filename, monitor='val_loss', verbose=1, save_best_only=True)

best_epoch_results = ShowBestEpochResult(on_param='val_loss', show_params=['val_loss', 'loss'], mode='min')

callbacks_list = [learning_rate_reduction, checkpoint, best_epoch_results]

epochs  = 200 #1100
history = model.fit(x=hds_gen,
                      epochs=epochs, validation_data=(X_val,Y_val),
                      verbose=1, steps_per_epoch=X_train.shape[0] // batch_size,
                      callbacks=callbacks_list)
# Out:
# Epoch 1/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0125
# Epoch 1: val_loss improved from inf to 0.02854, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0125 - val_loss: 0.0285 - learning_rate: 0.0040
# Epoch 2/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0111
# Epoch 2: val_loss improved from 0.02854 to 0.01841, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0111 - val_loss: 0.0184 - learning_rate: 0.0040
# Epoch 3/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0107
# Epoch 3: val_loss improved from 0.01841 to 0.01804, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0107 - val_loss: 0.0180 - learning_rate: 0.0040
# Epoch 4/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0118
# Epoch 4: val_loss improved from 0.01804 to 0.01198, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0118 - val_loss: 0.0120 - learning_rate: 0.0040
# Epoch 5/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0095
# Epoch 5: val_loss improved from 0.01198 to 0.01184, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0095 - val_loss: 0.0118 - learning_rate: 0.0040
# Epoch 6/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0100
# Epoch 6: val_loss improved from 0.01184 to 0.00714, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0099 - val_loss: 0.0071 - learning_rate: 0.0040
# Epoch 7/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0082
# Epoch 7: val_loss improved from 0.00714 to 0.00534, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0082 - val_loss: 0.0053 - learning_rate: 0.0040
# Epoch 8/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0084
# Epoch 8: val_loss improved from 0.00534 to 0.00434, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0084 - val_loss: 0.0043 - learning_rate: 0.0040
# Epoch 9/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0082
# Epoch 9: val_loss did not improve from 0.00434
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0082 - val_loss: 0.0054 - learning_rate: 0.0040
# Epoch 10/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0088
# Epoch 10: val_loss improved from 0.00434 to 0.00263, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0088 - val_loss: 0.0026 - learning_rate: 0.0040
# Epoch 11/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0074
# Epoch 11: val_loss did not improve from 0.00263
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0074 - val_loss: 0.0031 - learning_rate: 0.0040
# Epoch 12/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0078
# Epoch 12: val_loss did not improve from 0.00263
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0078 - val_loss: 0.0035 - learning_rate: 0.0040
# Epoch 13/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0069
# Epoch 13: val_loss improved from 0.00263 to 0.00246, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0069 - val_loss: 0.0025 - learning_rate: 0.0040
# Epoch 14/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0076
# Epoch 14: val_loss did not improve from 0.00246
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0076 - val_loss: 0.0025 - learning_rate: 0.0040
# Epoch 15/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0079
# Epoch 15: val_loss did not improve from 0.00246
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0079 - val_loss: 0.0031 - learning_rate: 0.0040
# Epoch 16/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0068
# Epoch 16: val_loss improved from 0.00246 to 0.00220, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0068 - val_loss: 0.0022 - learning_rate: 0.0040
# Epoch 17/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0068
# Epoch 17: val_loss did not improve from 0.00220
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0068 - val_loss: 0.0025 - learning_rate: 0.0040
# Epoch 18/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0070
# Epoch 18: val_loss did not improve from 0.00220
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0070 - val_loss: 0.0026 - learning_rate: 0.0040
# Epoch 19/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0066
# Epoch 19: val_loss improved from 0.00220 to 0.00216, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0066 - val_loss: 0.0022 - learning_rate: 0.0040
# Epoch 20/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0062
# Epoch 20: val_loss did not improve from 0.00216
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0062 - val_loss: 0.0027 - learning_rate: 0.0040
# Epoch 21/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0058
# Epoch 21: val_loss did not improve from 0.00216
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0059 - val_loss: 0.0024 - learning_rate: 0.0040
# Epoch 22/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0062
# Epoch 22: val_loss did not improve from 0.00216
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0062 - val_loss: 0.0027 - learning_rate: 0.0040
# Epoch 23/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0060
# Epoch 23: val_loss improved from 0.00216 to 0.00199, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0060 - val_loss: 0.0020 - learning_rate: 0.0040
# Epoch 24/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0057
# Epoch 24: val_loss did not improve from 0.00199
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0057 - val_loss: 0.0030 - learning_rate: 0.0040
# Epoch 25/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0058
# Epoch 25: val_loss did not improve from 0.00199
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0058 - val_loss: 0.0021 - learning_rate: 0.0040
# Epoch 26/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0055
# Epoch 26: val_loss did not improve from 0.00199
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0055 - val_loss: 0.0028 - learning_rate: 0.0040
# Epoch 27/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0057
# Epoch 27: val_loss did not improve from 0.00199
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0057 - val_loss: 0.0025 - learning_rate: 0.0040
# Epoch 28/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0055
# Epoch 28: val_loss improved from 0.00199 to 0.00193, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 0.0055 - val_loss: 0.0019 - learning_rate: 0.0040
# Epoch 29/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0054
# Epoch 29: val_loss improved from 0.00193 to 0.00144, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.0054 - val_loss: 0.0014 - learning_rate: 0.0040
# Epoch 30/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0062
# Epoch 30: val_loss did not improve from 0.00144
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0062 - val_loss: 0.0027 - learning_rate: 0.0040
# Epoch 31/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0051
# Epoch 31: val_loss did not improve from 0.00144
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0051 - val_loss: 0.0017 - learning_rate: 0.0040
# Epoch 32/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0054
# Epoch 32: val_loss did not improve from 0.00144
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0054 - val_loss: 0.0021 - learning_rate: 0.0040
# Epoch 33/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0051
# Epoch 33: val_loss did not improve from 0.00144
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0051 - val_loss: 0.0023 - learning_rate: 0.0040
# Epoch 34/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0056
# Epoch 34: val_loss improved from 0.00144 to 0.00144, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0056 - val_loss: 0.0014 - learning_rate: 0.0040
# Epoch 35/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0045
# Epoch 35: val_loss did not improve from 0.00144
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0045 - val_loss: 0.0022 - learning_rate: 0.0040
# Epoch 36/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0047
# Epoch 36: val_loss did not improve from 0.00144
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0047 - val_loss: 0.0015 - learning_rate: 0.0040
# Epoch 37/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0043
# Epoch 37: val_loss did not improve from 0.00144
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0043 - val_loss: 0.0015 - learning_rate: 0.0040
# Epoch 38/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0047
# Epoch 38: val_loss did not improve from 0.00144
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0047 - val_loss: 0.0016 - learning_rate: 0.0040
# Epoch 39/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0045
# Epoch 39: val_loss improved from 0.00144 to 0.00137, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 0.0045 - val_loss: 0.0014 - learning_rate: 0.0040
# Epoch 40/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0046
# Epoch 40: val_loss did not improve from 0.00137
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 0.0046 - val_loss: 0.0024 - learning_rate: 0.0040
# Epoch 41/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0051
# Epoch 41: val_loss did not improve from 0.00137
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0051 - val_loss: 0.0016 - learning_rate: 0.0040
# Epoch 42/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0050
# Epoch 42: val_loss did not improve from 0.00137
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0050 - val_loss: 0.0014 - learning_rate: 0.0040
# Epoch 43/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0045
# Epoch 43: val_loss did not improve from 0.00137
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0045 - val_loss: 0.0024 - learning_rate: 0.0040
# Epoch 44/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0047
# Epoch 44: val_loss did not improve from 0.00137
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0047 - val_loss: 0.0020 - learning_rate: 0.0040
# Epoch 45/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0050
# Epoch 45: val_loss did not improve from 0.00137
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0050 - val_loss: 0.0017 - learning_rate: 0.0040
# Epoch 46/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0046
# Epoch 46: val_loss did not improve from 0.00137
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0046 - val_loss: 0.0022 - learning_rate: 0.0040
# Epoch 47/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0045
# Epoch 47: val_loss did not improve from 0.00137
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0045 - val_loss: 0.0021 - learning_rate: 0.0040
# Epoch 48/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0050
# Epoch 48: val_loss did not improve from 0.00137
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0050 - val_loss: 0.0015 - learning_rate: 0.0040
# Epoch 49/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0041
# Epoch 49: val_loss did not improve from 0.00137
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0042 - val_loss: 0.0018 - learning_rate: 0.0040
# Epoch 50/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0049
# Epoch 50: val_loss did not improve from 0.00137
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0049 - val_loss: 0.0018 - learning_rate: 0.0040
# Epoch 51/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0043
# Epoch 51: val_loss improved from 0.00137 to 0.00124, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0043 - val_loss: 0.0012 - learning_rate: 0.0040
# Epoch 52/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0042
# Epoch 52: val_loss did not improve from 0.00124
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0042 - val_loss: 0.0017 - learning_rate: 0.0040
# Epoch 53/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0046
# Epoch 53: val_loss did not improve from 0.00124
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0046 - val_loss: 0.0016 - learning_rate: 0.0040
# Epoch 54/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0044
# Epoch 54: val_loss improved from 0.00124 to 0.00123, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0044 - val_loss: 0.0012 - learning_rate: 0.0040
# Epoch 55/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0046
# Epoch 55: val_loss did not improve from 0.00123
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0046 - val_loss: 0.0014 - learning_rate: 0.0040
# Epoch 56/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0052
# Epoch 56: val_loss did not improve from 0.00123
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0052 - val_loss: 0.0031 - learning_rate: 0.0040
# Epoch 57/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0044
# Epoch 57: val_loss did not improve from 0.00123
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0044 - val_loss: 0.0013 - learning_rate: 0.0040
# Epoch 58/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0044
# Epoch 58: val_loss did not improve from 0.00123
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0044 - val_loss: 0.0020 - learning_rate: 0.0040
# Epoch 59/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0044
# Epoch 59: val_loss did not improve from 0.00123
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0044 - val_loss: 0.0017 - learning_rate: 0.0040
# Epoch 60/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0038
# Epoch 60: val_loss did not improve from 0.00123
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0038 - val_loss: 0.0013 - learning_rate: 0.0040
# Epoch 61/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0041
# Epoch 61: val_loss did not improve from 0.00123
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0041 - val_loss: 0.0018 - learning_rate: 0.0040
# Epoch 62/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0040
# Epoch 62: val_loss did not improve from 0.00123
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0040 - val_loss: 0.0014 - learning_rate: 0.0040
# Epoch 63/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0042
# Epoch 63: val_loss improved from 0.00123 to 0.00104, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0042 - val_loss: 0.0010 - learning_rate: 0.0040
# Epoch 64/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0041
# Epoch 64: val_loss improved from 0.00104 to 0.00091, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0041 - val_loss: 9.1424e-04 - learning_rate: 0.0040
# Epoch 65/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0031
# Epoch 65: val_loss did not improve from 0.00091
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0031 - val_loss: 0.0014 - learning_rate: 0.0040
# Epoch 66/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0043
# Epoch 66: val_loss did not improve from 0.00091
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0043 - val_loss: 0.0014 - learning_rate: 0.0040
# Epoch 67/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0034
# Epoch 67: val_loss did not improve from 0.00091
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0034 - val_loss: 0.0017 - learning_rate: 0.0040
# Epoch 68/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0041
# Epoch 68: val_loss did not improve from 0.00091
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0041 - val_loss: 0.0014 - learning_rate: 0.0040
# Epoch 69/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0038
# Epoch 69: val_loss did not improve from 0.00091
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0038 - val_loss: 0.0012 - learning_rate: 0.0040
# Epoch 70/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0033
# Epoch 70: val_loss did not improve from 0.00091
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0033 - val_loss: 9.8780e-04 - learning_rate: 0.0040
# Epoch 71/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0033
# Epoch 71: val_loss improved from 0.00091 to 0.00080, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0033 - val_loss: 7.9717e-04 - learning_rate: 0.0040
# Epoch 72/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0034
# Epoch 72: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0034 - val_loss: 0.0021 - learning_rate: 0.0040
# Epoch 73/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0038
# Epoch 73: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0038 - val_loss: 0.0023 - learning_rate: 0.0040
# Epoch 74/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0037
# Epoch 74: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0037 - val_loss: 0.0016 - learning_rate: 0.0040
# Epoch 75/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0039
# Epoch 75: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0040 - val_loss: 9.6807e-04 - learning_rate: 0.0040
# Epoch 76/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0038
# Epoch 76: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0038 - val_loss: 0.0015 - learning_rate: 0.0040
# Epoch 77/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0040
# Epoch 77: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0040 - val_loss: 9.7017e-04 - learning_rate: 0.0040
# Epoch 78/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0037
# Epoch 78: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0037 - val_loss: 0.0014 - learning_rate: 0.0040
# Epoch 79/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0036
# Epoch 79: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0036 - val_loss: 0.0012 - learning_rate: 0.0040
# Epoch 80/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0035
# Epoch 80: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0035 - val_loss: 0.0017 - learning_rate: 0.0040
# Epoch 81/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0042
# Epoch 81: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0042 - val_loss: 0.0014 - learning_rate: 0.0040
# Epoch 82/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0034
# Epoch 82: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0034 - val_loss: 0.0016 - learning_rate: 0.0040
# Epoch 83/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0036
# Epoch 83: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0036 - val_loss: 9.5196e-04 - learning_rate: 0.0040
# Epoch 84/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0034
# Epoch 84: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0034 - val_loss: 0.0010 - learning_rate: 0.0040
# Epoch 85/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0035
# Epoch 85: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0035 - val_loss: 8.9077e-04 - learning_rate: 0.0040
# Epoch 86/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0035
# Epoch 86: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0035 - val_loss: 0.0014 - learning_rate: 0.0040
# Epoch 87/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0035
# Epoch 87: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0035 - val_loss: 9.3963e-04 - learning_rate: 0.0040
# Epoch 88/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0040
# Epoch 88: val_loss did not improve from 0.00080
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0040 - val_loss: 0.0013 - learning_rate: 0.0040
# Epoch 89/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0033
# Epoch 89: val_loss improved from 0.00080 to 0.00067, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0033 - val_loss: 6.6505e-04 - learning_rate: 0.0040
# Epoch 90/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0033
# Epoch 90: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0033 - val_loss: 9.3651e-04 - learning_rate: 0.0040
# Epoch 91/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0031
# Epoch 91: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0031 - val_loss: 0.0011 - learning_rate: 0.0040
# Epoch 92/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0032
# Epoch 92: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0032 - val_loss: 0.0012 - learning_rate: 0.0040
# Epoch 93/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0038
# Epoch 93: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0038 - val_loss: 0.0016 - learning_rate: 0.0040
# Epoch 94/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0036
# Epoch 94: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0036 - val_loss: 0.0013 - learning_rate: 0.0040
# Epoch 95/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0031
# Epoch 95: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0031 - val_loss: 8.0411e-04 - learning_rate: 0.0040
# Epoch 96/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0032
# Epoch 96: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0032 - val_loss: 0.0016 - learning_rate: 0.0040
# Epoch 97/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0038
# Epoch 97: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0038 - val_loss: 0.0013 - learning_rate: 0.0040
# Epoch 98/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0031
# Epoch 98: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0031 - val_loss: 9.5586e-04 - learning_rate: 0.0040
# Epoch 99/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0040
# Epoch 99: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0040 - val_loss: 8.7108e-04 - learning_rate: 0.0040
# Epoch 100/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0038
# Epoch 100: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0038 - val_loss: 0.0017 - learning_rate: 0.0040
# Epoch 101/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0032
# Epoch 101: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0032 - val_loss: 9.5254e-04 - learning_rate: 0.0040
# Epoch 102/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0030
# Epoch 102: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0030 - val_loss: 7.4806e-04 - learning_rate: 0.0040
# Epoch 103/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0029
# Epoch 103: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0029 - val_loss: 9.1782e-04 - learning_rate: 0.0040
# Epoch 104/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0035
# Epoch 104: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0035 - val_loss: 0.0014 - learning_rate: 0.0040
# Epoch 105/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0036
# Epoch 105: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0036 - val_loss: 0.0015 - learning_rate: 0.0040
# Epoch 106/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0037
# Epoch 106: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0037 - val_loss: 9.6682e-04 - learning_rate: 0.0040
# Epoch 107/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0035
# Epoch 107: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0035 - val_loss: 0.0010 - learning_rate: 0.0040
# Epoch 108/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0033
# Epoch 108: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0033 - val_loss: 0.0011 - learning_rate: 0.0040
# Epoch 109/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0032
# Epoch 109: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0032 - val_loss: 8.4552e-04 - learning_rate: 0.0040
# Epoch 110/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0029
# Epoch 110: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0030 - val_loss: 0.0012 - learning_rate: 0.0040
# Epoch 111/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0035
# Epoch 111: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0035 - val_loss: 0.0011 - learning_rate: 0.0040
# Epoch 112/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0031
# Epoch 112: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0031 - val_loss: 0.0014 - learning_rate: 0.0040
# Epoch 113/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0031
# Epoch 113: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0031 - val_loss: 7.7652e-04 - learning_rate: 0.0040
# Epoch 114/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0032
# Epoch 114: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0032 - val_loss: 9.6358e-04 - learning_rate: 0.0040
# Epoch 115/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0030
# Epoch 115: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0030 - val_loss: 0.0013 - learning_rate: 0.0040
# Epoch 116/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0033
# Epoch 116: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0033 - val_loss: 9.4714e-04 - learning_rate: 0.0040
# Epoch 117/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0029
# Epoch 117: ReduceLROnPlateau reducing learning rate to 0.0036000001709908247.
#
# Epoch 117: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0029 - val_loss: 9.8397e-04 - learning_rate: 0.0040
# Epoch 118/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0032
# Epoch 118: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0032 - val_loss: 0.0017 - learning_rate: 0.0036
# Epoch 119/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0036
# Epoch 119: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0036 - val_loss: 7.2429e-04 - learning_rate: 0.0036
# Epoch 120/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0026
# Epoch 120: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0026 - val_loss: 0.0010 - learning_rate: 0.0036
# Epoch 121/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0030
# Epoch 121: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0030 - val_loss: 0.0010 - learning_rate: 0.0036
# Epoch 122/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0030
# Epoch 122: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0030 - val_loss: 7.0462e-04 - learning_rate: 0.0036
# Epoch 123/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0029
# Epoch 123: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0029 - val_loss: 7.8653e-04 - learning_rate: 0.0036
# Epoch 124/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0035
# Epoch 124: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0035 - val_loss: 7.0625e-04 - learning_rate: 0.0036
# Epoch 125/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0030
# Epoch 125: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0029 - val_loss: 6.8696e-04 - learning_rate: 0.0036
# Epoch 126/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0028
# Epoch 126: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0028 - val_loss: 0.0011 - learning_rate: 0.0036
# Epoch 127/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0027
# Epoch 127: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0027 - val_loss: 0.0010 - learning_rate: 0.0036
# Epoch 128/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0033
# Epoch 128: val_loss did not improve from 0.00067
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0033 - val_loss: 8.3186e-04 - learning_rate: 0.0036
# Epoch 129/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0027
# Epoch 129: val_loss improved from 0.00067 to 0.00060, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0027 - val_loss: 5.9888e-04 - learning_rate: 0.0036
# Epoch 130/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0027
# Epoch 130: val_loss did not improve from 0.00060
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0027 - val_loss: 8.2804e-04 - learning_rate: 0.0036
# Epoch 131/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0032
# Epoch 131: val_loss did not improve from 0.00060
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0032 - val_loss: 7.5844e-04 - learning_rate: 0.0036
# Epoch 132/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0030
# Epoch 132: val_loss did not improve from 0.00060
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0030 - val_loss: 8.4052e-04 - learning_rate: 0.0036
# Epoch 133/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0030
# Epoch 133: val_loss did not improve from 0.00060
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0030 - val_loss: 6.0112e-04 - learning_rate: 0.0036
# Epoch 134/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0030
# Epoch 134: val_loss did not improve from 0.00060
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0030 - val_loss: 8.2816e-04 - learning_rate: 0.0036
# Epoch 135/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0030
# Epoch 135: val_loss did not improve from 0.00060
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0030 - val_loss: 6.3025e-04 - learning_rate: 0.0036
# Epoch 136/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0030
# Epoch 136: val_loss improved from 0.00060 to 0.00059, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0030 - val_loss: 5.9014e-04 - learning_rate: 0.0036
# Epoch 137/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0024
# Epoch 137: val_loss did not improve from 0.00059
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0024 - val_loss: 0.0011 - learning_rate: 0.0036
# Epoch 138/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0030
# Epoch 138: val_loss did not improve from 0.00059
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0030 - val_loss: 9.5672e-04 - learning_rate: 0.0036
# Epoch 139/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0029
# Epoch 139: val_loss did not improve from 0.00059
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0029 - val_loss: 0.0010 - learning_rate: 0.0036
# Epoch 140/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0028
# Epoch 140: val_loss did not improve from 0.00059
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0028 - val_loss: 7.4213e-04 - learning_rate: 0.0036
# Epoch 141/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0029
# Epoch 141: val_loss did not improve from 0.00059
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0029 - val_loss: 8.4268e-04 - learning_rate: 0.0036
# Epoch 142/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025
# Epoch 142: val_loss did not improve from 0.00059
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0025 - val_loss: 7.7454e-04 - learning_rate: 0.0036
# Epoch 143/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0023
# Epoch 143: val_loss did not improve from 0.00059
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0024 - val_loss: 6.2250e-04 - learning_rate: 0.0036
# Epoch 144/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0027
# Epoch 144: val_loss did not improve from 0.00059
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0027 - val_loss: 7.3731e-04 - learning_rate: 0.0036
# Epoch 145/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0027
# Epoch 145: val_loss did not improve from 0.00059
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0027 - val_loss: 7.2765e-04 - learning_rate: 0.0036
# Epoch 146/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0028
# Epoch 146: val_loss improved from 0.00059 to 0.00054, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0028 - val_loss: 5.4061e-04 - learning_rate: 0.0036
# Epoch 147/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0029
# Epoch 147: val_loss did not improve from 0.00054
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0029 - val_loss: 9.2984e-04 - learning_rate: 0.0036
# Epoch 148/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0026
# Epoch 148: val_loss did not improve from 0.00054
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0026 - val_loss: 5.6724e-04 - learning_rate: 0.0036
# Epoch 149/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025
# Epoch 149: val_loss did not improve from 0.00054
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0025 - val_loss: 6.0482e-04 - learning_rate: 0.0036
# Epoch 150/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0027
# Epoch 150: val_loss did not improve from 0.00054
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0027 - val_loss: 6.7399e-04 - learning_rate: 0.0036
# Epoch 151/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0026
# Epoch 151: val_loss did not improve from 0.00054
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0026 - val_loss: 7.0660e-04 - learning_rate: 0.0036
# Epoch 152/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0027
# Epoch 152: val_loss did not improve from 0.00054
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0027 - val_loss: 8.4544e-04 - learning_rate: 0.0036
# Epoch 153/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0026
# Epoch 153: val_loss improved from 0.00054 to 0.00053, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0026 - val_loss: 5.3423e-04 - learning_rate: 0.0036
# Epoch 154/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0027
# Epoch 154: val_loss did not improve from 0.00053
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0027 - val_loss: 6.0451e-04 - learning_rate: 0.0036
# Epoch 155/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0029
# Epoch 155: val_loss did not improve from 0.00053
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0029 - val_loss: 8.0279e-04 - learning_rate: 0.0036
# Epoch 156/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0026
# Epoch 156: val_loss did not improve from 0.00053
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0026 - val_loss: 0.0011 - learning_rate: 0.0036
# Epoch 157/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025
# Epoch 157: val_loss did not improve from 0.00053
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0025 - val_loss: 7.5959e-04 - learning_rate: 0.0036
# Epoch 158/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0031
# Epoch 158: val_loss improved from 0.00053 to 0.00052, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0031 - val_loss: 5.2039e-04 - learning_rate: 0.0036
# Epoch 159/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0030
# Epoch 159: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0030 - val_loss: 7.3469e-04 - learning_rate: 0.0036
# Epoch 160/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0026
# Epoch 160: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0026 - val_loss: 8.2375e-04 - learning_rate: 0.0036
# Epoch 161/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0030
# Epoch 161: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0030 - val_loss: 9.0586e-04 - learning_rate: 0.0036
# Epoch 162/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0025
# Epoch 162: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0025 - val_loss: 8.3573e-04 - learning_rate: 0.0036
# Epoch 163/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0027
# Epoch 163: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0027 - val_loss: 0.0014 - learning_rate: 0.0036
# Epoch 164/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0026
# Epoch 164: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0026 - val_loss: 9.2280e-04 - learning_rate: 0.0036
# Epoch 165/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0026
# Epoch 165: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0026 - val_loss: 8.0865e-04 - learning_rate: 0.0036
# Epoch 166/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0026
# Epoch 166: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0026 - val_loss: 5.2046e-04 - learning_rate: 0.0036
# Epoch 167/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0032
# Epoch 167: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0032 - val_loss: 9.8223e-04 - learning_rate: 0.0036
# Epoch 168/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0034
# Epoch 168: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0034 - val_loss: 9.6974e-04 - learning_rate: 0.0036
# Epoch 169/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025
# Epoch 169: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0025 - val_loss: 8.8287e-04 - learning_rate: 0.0036
# Epoch 170/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0033
# Epoch 170: val_loss improved from 0.00052 to 0.00052, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0033 - val_loss: 5.1632e-04 - learning_rate: 0.0036
# Epoch 171/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0024
# Epoch 171: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0024 - val_loss: 6.6110e-04 - learning_rate: 0.0036
# Epoch 172/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0030
# Epoch 172: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0030 - val_loss: 5.8983e-04 - learning_rate: 0.0036
# Epoch 173/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0025
# Epoch 173: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0025 - val_loss: 9.1060e-04 - learning_rate: 0.0036
# Epoch 174/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0028
# Epoch 174: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0028 - val_loss: 8.2482e-04 - learning_rate: 0.0036
# Epoch 175/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0027
# Epoch 175: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0027 - val_loss: 6.0999e-04 - learning_rate: 0.0036
# Epoch 176/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0025
# Epoch 176: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0025 - val_loss: 9.0982e-04 - learning_rate: 0.0036
# Epoch 177/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0032
# Epoch 177: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0032 - val_loss: 7.2928e-04 - learning_rate: 0.0036
# Epoch 178/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0024
# Epoch 178: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0024 - val_loss: 0.0012 - learning_rate: 0.0036
# Epoch 179/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0030
# Epoch 179: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0030 - val_loss: 5.5085e-04 - learning_rate: 0.0036
# Epoch 180/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0025
# Epoch 180: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0025 - val_loss: 5.5162e-04 - learning_rate: 0.0036
# Epoch 181/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0022
# Epoch 181: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0022 - val_loss: 8.3421e-04 - learning_rate: 0.0036
# Epoch 182/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0029
# Epoch 182: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0029 - val_loss: 8.0334e-04 - learning_rate: 0.0036
# Epoch 183/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0024
# Epoch 183: val_loss did not improve from 0.00052
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0024 - val_loss: 6.4608e-04 - learning_rate: 0.0036
# Epoch 184/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0026
# Epoch 184: val_loss improved from 0.00052 to 0.00049, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0026 - val_loss: 4.9446e-04 - learning_rate: 0.0036
# Epoch 185/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0025
# Epoch 185: val_loss did not improve from 0.00049
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0025 - val_loss: 0.0010 - learning_rate: 0.0036
# Epoch 186/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0023
# Epoch 186: val_loss did not improve from 0.00049
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0023 - val_loss: 7.7102e-04 - learning_rate: 0.0036
# Epoch 187/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0026
# Epoch 187: val_loss did not improve from 0.00049
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0026 - val_loss: 8.4764e-04 - learning_rate: 0.0036
# Epoch 188/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0028
# Epoch 188: val_loss did not improve from 0.00049
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0028 - val_loss: 5.7282e-04 - learning_rate: 0.0036
# Epoch 189/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0025
# Epoch 189: val_loss did not improve from 0.00049
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0025 - val_loss: 6.7881e-04 - learning_rate: 0.0036
# Epoch 190/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0024
# Epoch 190: val_loss did not improve from 0.00049
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0024 - val_loss: 6.8249e-04 - learning_rate: 0.0036
# Epoch 191/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0023
# Epoch 191: val_loss did not improve from 0.00049
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0023 - val_loss: 6.1956e-04 - learning_rate: 0.0036
# Epoch 192/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0028
# Epoch 192: val_loss did not improve from 0.00049
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0028 - val_loss: 9.0274e-04 - learning_rate: 0.0036
# Epoch 193/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0024
# Epoch 193: val_loss did not improve from 0.00049
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0024 - val_loss: 8.4421e-04 - learning_rate: 0.0036
# Epoch 194/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0022
# Epoch 194: val_loss did not improve from 0.00049
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0022 - val_loss: 5.5637e-04 - learning_rate: 0.0036
# Epoch 195/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0023
# Epoch 195: val_loss improved from 0.00049 to 0.00046, saving model to ../saved_models/triangle1.model.keras
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0023 - val_loss: 4.6229e-04 - learning_rate: 0.0036
# Epoch 196/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0032
# Epoch 196: val_loss did not improve from 0.00046
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0032 - val_loss: 6.4026e-04 - learning_rate: 0.0036
# Epoch 197/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0032
# Epoch 197: val_loss did not improve from 0.00046
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0032 - val_loss: 6.5523e-04 - learning_rate: 0.0036
# Epoch 198/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0026
# Epoch 198: val_loss did not improve from 0.00046
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0026 - val_loss: 8.7345e-04 - learning_rate: 0.0036
# Epoch 199/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0024
# Epoch 199: val_loss did not improve from 0.00046
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0024 - val_loss: 5.8657e-04 - learning_rate: 0.0036
# Epoch 200/200
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0029
# Epoch 200: val_loss did not improve from 0.00046
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0029 - val_loss: 5.5498e-04 - learning_rate: 0.0036
# BestEpochResult. Epoch: 195, val_loss: 0.00046, loss: 0.00228,
# 39/39 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 34: val_loss did not improve from 0.00168
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0054 - val_loss: 0.0020 - lr: 0.0040
# Epoch 35/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 35: val_loss did not improve from 0.00168
# 39/39 [==============================] - 5s 127ms/step - loss: 0.0057 - val_loss: 0.0022 - lr: 0.0040
# Epoch 36/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 36: val_loss did not improve from 0.00168
# 39/39 [==============================] - 5s 127ms/step - loss: 0.0049 - val_loss: 0.0023 - lr: 0.0040
# Epoch 37/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 37: val_loss did not improve from 0.00168
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0052 - val_loss: 0.0021 - lr: 0.0040
# Epoch 38/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 38: val_loss did not improve from 0.00168
# 39/39 [==============================] - 5s 127ms/step - loss: 0.0051 - val_loss: 0.0024 - lr: 0.0040
# Epoch 39/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 39: val_loss did not improve from 0.00168
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0049 - val_loss: 0.0031 - lr: 0.0040
# Epoch 40/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 40: val_loss did not improve from 0.00168
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0050 - val_loss: 0.0026 - lr: 0.0040
# Epoch 41/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 41: val_loss did not improve from 0.00168
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0051 - val_loss: 0.0025 - lr: 0.0040
# Epoch 42/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 42: val_loss did not improve from 0.00168
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0052 - val_loss: 0.0023 - lr: 0.0040
# Epoch 43/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 43: val_loss did not improve from 0.00168
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0049 - val_loss: 0.0020 - lr: 0.0040
# Epoch 44/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 44: val_loss did not improve from 0.00168
# ...
# Epoch 133/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 133: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0031 - val_loss: 0.0010 - lr: 0.0032
# Epoch 134/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 134: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0029 - val_loss: 0.0010 - lr: 0.0032
# Epoch 135/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 135: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0028 - val_loss: 9.7812e-04 - lr: 0.0032
# Epoch 136/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 136: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 127ms/step - loss: 0.0029 - val_loss: 0.0012 - lr: 0.0032
# Epoch 137/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 137: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0031 - val_loss: 8.7513e-04 - lr: 0.0032
# Epoch 138/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 138: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0033 - val_loss: 0.0023 - lr: 0.0032
# Epoch 139/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 139: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0031 - val_loss: 0.0011 - lr: 0.0032
# Epoch 140/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 140: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0035 - val_loss: 0.0013 - lr: 0.0032
# Epoch 141/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 141: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0027 - val_loss: 0.0018 - lr: 0.0032
# Epoch 142/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 142: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0030 - val_loss: 0.0011 - lr: 0.0032
# Epoch 143/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 143: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0029 - val_loss: 0.0012 - lr: 0.0032
# Epoch 144/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 144: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0032 - val_loss: 9.3158e-04 - lr: 0.0032
# Epoch 145/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 145: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0030 - val_loss: 0.0013 - lr: 0.0032
# Epoch 146/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 146: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0030 - val_loss: 0.0016 - lr: 0.0032
# Epoch 147/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 147: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0033 - val_loss: 8.5953e-04 - lr: 0.0032
# Epoch 148/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 148: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 127ms/step - loss: 0.0027 - val_loss: 0.0012 - lr: 0.0032
# Epoch 149/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 149: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0029 - val_loss: 8.9990e-04 - lr: 0.0032
# Epoch 150/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 150: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0031 - val_loss: 0.0011 - lr: 0.0032
# Epoch 151/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 151: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0025 - val_loss: 8.5923e-04 - lr: 0.0032
# Epoch 152/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 152: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0024 - val_loss: 0.0011 - lr: 0.0032
# Epoch 153/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 153: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0029 - val_loss: 8.4793e-04 - lr: 0.0032
# Epoch 154/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 154: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0027 - val_loss: 0.0011 - lr: 0.0032
# Epoch 155/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 155: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0027 - val_loss: 0.0020 - lr: 0.0032
# Epoch 156/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 156: val_loss did not improve from 0.00070
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0029 - val_loss: 9.6562e-04 - lr: 0.0032
# Epoch 157/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 157: val_loss improved from 0.00070 to 0.00069, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 5s 127ms/step - loss: 0.0028 - val_loss: 6.9308e-04 - lr: 0.0032
# Epoch 158/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 158: val_loss did not improve from 0.00069
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0028 - val_loss: 8.9021e-04 - lr: 0.0032
# Epoch 159/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 159: val_loss did not improve from 0.00069
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0026 - val_loss: 9.6245e-04 - lr: 0.0032
# Epoch 160/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 160: val_loss improved from 0.00069 to 0.00060, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 5s 127ms/step - loss: 0.0030 - val_loss: 6.0343e-04 - lr: 0.0032
# Epoch 161/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 161: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0027 - val_loss: 8.8343e-04 - lr: 0.0032
# Epoch 162/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 162: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0029 - val_loss: 0.0012 - lr: 0.0032
# Epoch 163/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 163: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0032 - val_loss: 0.0011 - lr: 0.0032
# Epoch 164/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 164: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0026 - val_loss: 7.9708e-04 - lr: 0.0032
# Epoch 165/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 165: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0026 - val_loss: 7.7593e-04 - lr: 0.0032
# Epoch 166/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 166: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0028 - val_loss: 0.0012 - lr: 0.0032
# Epoch 167/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 167: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0029 - val_loss: 7.5094e-04 - lr: 0.0032
# Epoch 168/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 168: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 124ms/step - loss: 0.0027 - val_loss: 8.8539e-04 - lr: 0.0032
# Epoch 169/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 169: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 124ms/step - loss: 0.0031 - val_loss: 9.7231e-04 - lr: 0.0032
# Epoch 170/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 170: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0030 - val_loss: 6.3499e-04 - lr: 0.0032
# Epoch 171/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 171: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0030 - val_loss: 7.9507e-04 - lr: 0.0032
# Epoch 172/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 172: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 127ms/step - loss: 0.0028 - val_loss: 0.0012 - lr: 0.0032
# Epoch 173/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 173: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0028 - val_loss: 8.8427e-04 - lr: 0.0032
# Epoch 174/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 174: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0031 - val_loss: 9.8527e-04 - lr: 0.0032
# Epoch 175/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 175: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0028 - val_loss: 8.5870e-04 - lr: 0.0032
# Epoch 176/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 176: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0025 - val_loss: 7.7776e-04 - lr: 0.0032
# Epoch 177/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 177: val_loss did not improve from 0.00060
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0025 - val_loss: 7.5534e-04 - lr: 0.0032
# Epoch 178/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 178: val_loss improved from 0.00060 to 0.00051, saving model to ../saved_models/triangle1.model.h5
# 39/39 [==============================] - 5s 127ms/step - loss: 0.0025 - val_loss: 5.1048e-04 - lr: 0.0032
# Epoch 179/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 179: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0023 - val_loss: 8.1525e-04 - lr: 0.0032
# Epoch 180/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 180: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0026 - val_loss: 0.0011 - lr: 0.0032
# Epoch 181/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 181: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0026 - val_loss: 0.0014 - lr: 0.0032
# Epoch 182/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 182: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0024 - val_loss: 9.0750e-04 - lr: 0.0032
# Epoch 183/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 183: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0024 - val_loss: 0.0011 - lr: 0.0032
# Epoch 184/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 184: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0025 - val_loss: 7.5911e-04 - lr: 0.0032
# Epoch 185/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 185: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0026 - val_loss: 8.2368e-04 - lr: 0.0032
# Epoch 186/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 186: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0025 - val_loss: 7.2523e-04 - lr: 0.0032
# Epoch 187/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 187: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0027 - val_loss: 0.0010 - lr: 0.0032
# Epoch 188/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 188: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0025 - val_loss: 0.0011 - lr: 0.0032
# Epoch 189/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 189: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0029 - val_loss: 8.0996e-04 - lr: 0.0032
# Epoch 190/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 190: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 127ms/step - loss: 0.0028 - val_loss: 5.4627e-04 - lr: 0.0032
# Epoch 191/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 191: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0033 - val_loss: 6.2535e-04 - lr: 0.0032
# Epoch 192/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 192: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 127ms/step - loss: 0.0026 - val_loss: 0.0010 - lr: 0.0032
# Epoch 193/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 193: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0025 - val_loss: 7.7388e-04 - lr: 0.0032
# Epoch 194/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 194: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0026 - val_loss: 0.0012 - lr: 0.0032
# Epoch 195/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 195: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0026 - val_loss: 7.2981e-04 - lr: 0.0032
# Epoch 196/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 196: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0025 - val_loss: 5.2156e-04 - lr: 0.0032
# Epoch 197/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 197: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0026 - val_loss: 9.9929e-04 - lr: 0.0032
# Epoch 198/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 198: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0026 - val_loss: 9.6084e-04 - lr: 0.0032
# Epoch 199/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 199: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 126ms/step - loss: 0.0026 - val_loss: 6.5426e-04 - lr: 0.0032
# Epoch 200/200
# 39/39 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 200: val_loss did not improve from 0.00051
# 39/39 [==============================] - 5s 125ms/step - loss: 0.0026 - val_loss: 7.9010e-04 - lr: 0.0032
# BestEpochResult. Epoch: 178, val_loss: 0.00051, loss: 0.00252,

# %% [markdown]
# ## Plot the loss curves for training and validation

# %%
plt.figure(figsize=(15,10))
plot_loss(history.history,"model",plt)
plt.legend()
plt.grid()
plt.yscale("log")
plt.xlabel("epoch")
plt.ylabel("log loss")
plt.show()

# %% [markdown]
# ## Delete the existing model + Load the best one

# %%
# deletes the existing model
del model

# Load last saved model
model = load_model(model_filename)

# %%
Y_val_pred = model.predict(X_val)
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step

# %%
# Labels are vertices: x1, y1, x2, y2, x3, y3
# Where:
# - (0, 0) is the top left corner of the image
# - (1, 1) is the bottom right corner of the image
print("Y_val shape: ", Y_val.shape)
print("Y_val_pred shape: ", Y_val_pred.shape)
print("Real Label example: ", Y_val[0])
print("Prediction example: ", Y_val_pred[0])
# Out:
# Y_val shape:  (1370, 6)
# Y_val_pred shape:  (1370, 6)
# Real Label example:  [0.34 0.82 0.53 0.05 0.65 0.88]
# Prediction example:  [0.3265288  0.81363857 0.55489933 0.09800912 0.64754224 0.8780469 ]

# %% [markdown]
# # Calculate Dice accuracy for the whole Validation set
#
# To get more information about Dice accuracy, see: https://github.com/frobertpixto/ml_dice_and_iou_accuracy

# %%
dice_val = calculate_Dice_for_set(Y_val, Y_val_pred, nb_vertices)
print(f"Validation Accuracy(Dice): {dice_val}.")
# Out:
# Validation Accuracy(Dice): 0.911680232505542.

# %%
def plot_sample_with_pred(X, y, pred,axs):
    axs.imshow(X.reshape(image_size, image_size),cmap="gray") # Shape
    axs.scatter(image_size*y[0::2], image_size*y[1::2],c='orange') # Real Vertices
    axs.scatter(image_size*pred[0::2], image_size*pred[1::2],c='green') # Predicted Vertices

# %% [markdown]
# # Validation set predictions - Visualization
# - Orange dot: Real Vertex
# - Green dot: Predicted Vertex

# %%
fig = plt.figure(figsize=(13, 21))
fig.subplots_adjust(hspace=0.13, wspace=0.01,
                    left=0, right=1, bottom=0, top=1.2)
nb_pictures = 32
count = 1
for irow in range(nb_pictures):
    ipic = np.random.choice(X_val.shape[0])
    ax = fig.add_subplot(nb_pictures // 4, 4, count,xticks=[],yticks=[])        
    plot_sample_with_pred(X_val[ipic], Y_val[ipic], Y_val_pred[ipic], ax)

    dice = calculate_Dice(Y_val[ipic], Y_val_pred[ipic], nb_vertices=nb_vertices)
    ax.set_title("dice {:5.3f}".format(dice))
    count += 1
plt.show()

# %%
#TODO Display the 32 worst RMSE images

# %% [markdown]
# ## Predict for the test set

# %%
## Prepare the Test set
test_X = test_dict['test_data']
test_y = test_dict['test_labels']
print("test_X shape: ", test_X.shape)
print("test_y shape: ", test_y.shape)

X_test    = test_X.reshape(-1, image_size,image_size, 1)
Y_test    = test_y 
print("X_test shape: ", X_test.shape)
print("Y_test shape: ", Y_test.shape)
# Out:
# test_X shape:  (180, 70, 70)
# test_y shape:  (180, 6)
# X_test shape:  (180, 70, 70, 1)
# Y_test shape:  (180, 6)

# %%
# Show random images from the Test Set + superimposed vertices
indexes = np.arange(len(Y_test))
np.random.shuffle(indexes)
first_random_indexes = indexes[:100]

display_images_with_vertices(X_test[first_random_indexes], Y_test[first_random_indexes])

# %%
test_loss = model.evaluate(X_test, Y_test)
print("test_loss: ", test_loss)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.1465e-04
# test_loss:  0.0003872914530802518

# %%
Y_test_pred = model.predict(X_test)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
print("Y_pred shape: ", Y_test_pred.shape)
Y_test_pred[0:2, :]
# Out:
# Y_pred shape:  (180, 6)
# array([[0.14059629, 0.75987893, 0.5485761 , 0.20062675, 0.8650381 ,
#         0.7070149 ],
#        [0.1269759 , 0.6884436 , 0.5478176 , 0.28409073, 0.8599721 ,
#         0.64212036]], dtype=float32)

# %% [markdown]
# # Calculate Dice accuracy for the whole Test set

# %%
dice_val = calculate_Dice_for_set(Y_test, Y_test_pred, nb_vertices)
print(f"Validation Accuracy(Dice): {dice_val}.")
# Out:
# Validation Accuracy(Dice): 0.9189841867145263.

# %% [markdown]
# # Test set predictions - Visualization
# - Orange dot: Real Vertex
# - Green dot: Predicted Vertex

# %%
fig = plt.figure(figsize=(13, 21))
fig.subplots_adjust(hspace=0.13, wspace=0.01,
                    left=0, right=1, bottom=0, top=1.2)
nb_pictures = 32
count = 1
for irow in range(nb_pictures):
    ipic = np.random.choice(X_test.shape[0])
    ax = fig.add_subplot(nb_pictures // 4, 4, count,xticks=[],yticks=[])        
    plot_sample_with_pred(X_test[ipic], Y_test[ipic], Y_test_pred[ipic], ax)
    
    try:
        dice = calculate_Dice(Y_test[ipic], Y_test_pred[ipic], nb_vertices=nb_vertices)
        ax.set_title("dice {:5.3f}".format(dice))
    except Exception as e:
        print(f"Cannot compute Dice for shape: {i}.")    
        
    count += 1
plt.show()

# %% [markdown]
# # Conclusions
# Accuracy is generally good. We see that:
# - Most are very close to the real labels.
# - Some are off and between to real labels. I describe that issue [here](https://github.com/frobertpixto/hand_drawn_shapes_dataset/blob/main/processing/find_vertices/README.md).
#
#
# Regarding the loss, we have:
# - BestEpochResult. Epoch: 195, val_loss: **0.00046**
#
# For Mix on pix, when training for 1100 epoch, I had:
# - BestEpochResult. Epoch: 1090, val_loss: **0.00017**
#
# The model was definitively useful in [Mix on Pix](https://apps.apple.com/us/app/mix-on-pix-text-on-photos/id633281586).
#
# ## TensorFlow Lite Notes
# When creating a TensorFlow Lite model with quantization, accuracy can be a tiny bit lower, but the model size is 25% of the original. That's super important when running **directly in a mobile app**.

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 6, 14, 22, 26, 26, 944594)
