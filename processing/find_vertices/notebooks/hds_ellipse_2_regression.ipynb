# %% [markdown]
# # Train a model to estimate the vertices in an image - Ellipses
#
# Predict position of vertices for Ellipses.
# Using Supervised Learning with Tensorflow
#
# Data is received in 3 pickles that contain:
# 1. Train images and labels (vertices)
# 2. Validation images and labels (vertices)
# 3. Test images and labels (vertices)
#
# ---
# Francois Robert

# %%
# This notebook estimates the vertices for 1 shape
shape = "ellipse"

# %%
### Load packages
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

import seaborn as sns
sns.set(style='white', context='notebook', palette='deep')

import os
from pathlib import Path

from six.moves import cPickle as pickle

# %%
# More packages
import tensorflow as tf

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Input, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# Our module
from hds_module.shape_utils import HdsDataGenerator, calculate_Dice, calculate_Dice_for_set  
from hds_module.utils import ShowBestEpochResult

import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 6, 14, 21, 23, 50, 271573)

# %%
# GPU Setting
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# 2025-06-14 21:23:50.277125: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2025-06-14 21:23:50.277150: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2025-06-14 21:23:50.277155: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2025-06-14 21:23:50.277171: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-06-14 21:23:50.277183: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
from platform import python_version
print(f'Python: {python_version()}')
# Out:
# Python: 3.11.12

# %%
import tensorflow as tf
print(f'Tensorflow: {tf.__version__}')
# Out:
# Tensorflow: 2.16.2

# %%
seed1=127
np.random.seed(seed1)

# %% [markdown]
# ## Define environment variables

# %%
BASEDIR = ".."

DATADIR = os.path.join(BASEDIR, "pickles")

TRAIN_DATAFILE = os.path.join(DATADIR, f"train_{shape}.pickle")
VAL_DATAFILE   = os.path.join(DATADIR, f"val_{shape}.pickle")
TEST_DATAFILE  = os.path.join(DATADIR, f"test_{shape}.pickle")

MODEL_DIR      = os.path.join(BASEDIR, "saved_models")
model_filename = os.path.join(MODEL_DIR, f"{shape}1.model.keras")

# %%
# Set image properties
image_size  = 70     # Pixel width and height
pixel_depth = 255.0  # Number of levels per pixel

# %%
# Create model directory
Path(MODEL_DIR).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Load train, validation and test datasets from Pickles

# %%
with open(TRAIN_DATAFILE, 'rb') as file:
    train_dict = pickle.load(file)
with open(VAL_DATAFILE, 'rb') as file:
    val_dict = pickle.load(file)
with open(TEST_DATAFILE, 'rb') as file:
    test_dict = pickle.load(file)

# %%
# Load params used in ETL
params_dict = train_dict['params']

etl_shape = params_dict['shape']
nb_vertices = params_dict['nb_vertices']
anchor_x = params_dict['anchor_x']
anchor_y = params_dict['anchor_y']

print(f"{shape=}, {nb_vertices=}, {anchor_x=}, {anchor_y=}") 

assert shape == etl_shape, f"Invalid shape read. Expected: {shape}. Actual {etl_shape}."
# Out:
# shape='ellipse', nb_vertices=4, anchor_x=0.0, anchor_y=0.65

# %%
# Construct train set
train_X = train_dict['train_data']
train_y = train_dict['train_labels']

# %%
# Construct validation set
val_X = val_dict['val_data']
val_y = val_dict['val_labels']

# %%
print("train_X shape: ", train_X.shape)
print("train_y shape: ", train_y.shape)
# Out:
# train_X shape:  (4828, 70, 70)
# train_y shape:  (4828, 8)

# %%
print("val_X shape: ", val_X.shape)
print("val_y shape: ", val_y.shape)
# Out:
# val_X shape:  (1446, 70, 70)
# val_y shape:  (1446, 8)

# %%
# Reshape each image in 3 dimensions (height = 70px, width = 70px, canal = 1)
X_train = train_X.reshape(-1, image_size, image_size, 1)
X_val   = val_X.reshape(-1, image_size, image_size, 1)

# %%
Y_train = train_y
Y_val = val_y

# %%
X_train.shape
# Out:
# (4828, 70, 70, 1)

# %%
X_val.shape
# Out:
# (1446, 70, 70, 1)

# %%
# We expect to have 8 values for the labels of an ellipse.

# %%
Y_train.shape
# Out:
# (4828, 8)

# %%
Y_val.shape
# Out:
# (1446, 8)

# %%
# Labels are vertices: x1, y1, x2, y2, x3, y3, y4, y4
# Where:
# - (0, 0) is the top left corner of the image
# - (1, 1) is the bottom right corner of the image
print("Real Label example: ", Y_val[0])
# Out:
# Real Label example:  [0.42 0.49 0.51 0.12 0.58 0.5  0.48 0.87]

# %% [markdown]
# ## Let's visualize the data
# An image is worth a thousand words.

# %%
def plot_loss(hist,name,plt,RMSE_TF=False):
    '''
    RMSE_TF: if True, then RMSE is plotted with original scale 
    '''
    loss = hist['loss']
    val_loss = hist['val_loss']
    if RMSE_TF:
        loss = np.sqrt(np.array(loss))*48 
        val_loss = np.sqrt(np.array(val_loss))*48 
        
    plt.plot(loss,"--",linewidth=3,label="train:"+name)
    plt.plot(val_loss,linewidth=3,label="val:"+name)

# %%
def plot_sample(X, y, axs):
    axs.imshow(X.reshape(image_size, image_size), cmap="gray") # Put the Image
    y = y.ravel()
    axs.scatter(image_size * y[0::2], image_size * y[1::2], c='orange') # Add the labels as orange dots

# %%
# This function shows images with their real vertices
# Presentation is rows of 10 images
def display_images_with_vertices(X, Y):

    fig = plt.figure(figsize=(13, 9))
    fig.subplots_adjust(hspace=0.2,wspace=0.2,
                        left=0, right=1, bottom=0, top=1.5)

    nb_pictures = len(X)
    for i_pic in range(nb_pictures):
        x = X[i_pic]
        y = Y[i_pic]
        
        nb_per_row = 10
        nb_of_row  = (nb_pictures - 1) // nb_per_row + 1

        ax  = fig.add_subplot(nb_of_row, nb_per_row, i_pic + 1, xticks=[], yticks=[])
        plot_sample(x, y, ax)
    plt.show()

# %%
# Show random images from the Train Set + superimposed vertices
indexes = np.arange(len(Y_train))
np.random.shuffle(indexes)
first_random_indexes = indexes[:100]

display_images_with_vertices(X_train[first_random_indexes], Y_train[first_random_indexes])

# %%
# Show random images from the Validation Set + superimposed vertices
indexes = np.arange(len(Y_val))
np.random.shuffle(indexes)
first_random_indexes = indexes[:100]

display_images_with_vertices(X_val[first_random_indexes], Y_val[first_random_indexes])

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Define Deep Learning Model

# %%
def get_model_cnn():
    # Set the CNN model using Keras functional API
    input_img = Input(shape=(image_size,image_size,1))

    x = Conv2D(32, (5, 5), padding='same')(input_img)  # Conv2D 1
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Conv2D(32, (5, 5), padding='same')(x)          # Conv2D 2
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(64, (3, 3))(x)                          # Conv2D 3
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Conv2D(64, (3, 3))(x)                          # Conv2D 4
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Conv2D(128, (3, 3))(x)                         # Conv2D 5
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3))(x)                         # Conv2D 6
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.05)(x)

    x = Flatten()(x)
    x = Dense(200)(x)  
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    output = Dense(nb_vertices * 2)(x)

    model = Model(inputs=input_img, outputs=output)
    
    return model

# %%
# select a model
model = get_model_cnn()

model.summary()
# Out:
# 2025-06-14 21:23:52.351993: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-06-14 21:23:52.352008: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 70, 70, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 70, 70, 32)     │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 70, 70, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 70, 70, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 35, 35, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 35, 35, 32)     │        25,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 35, 35, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 35, 35, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 33, 33, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 33, 33, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 33, 33, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 14, 14, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 14, 14, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 5, 5, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 5, 5, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 5, 5, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 3, 3, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 3, 3, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 200)            │       230,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 200)            │           800 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         1,608 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 538,128 (2.05 MB)
#  Trainable params: 536,832 (2.05 MB)
#  Non-trainable params: 1,296 (5.06 KB)

# %% [markdown]
# ## Data augmentation: Full rotation, Flip vert. and Horiz with Targets modified

# %%
# Partition for the Generator
partition = []

nb_samples = X_train.shape[0]
print("nb_samples: ", nb_samples)

for i in range(nb_samples):
    partition.append(i)
# Out:
# nb_samples:  4828

# %% [markdown]
# For the generator, I created a custom Generator that does augmentation:
# - Flips the images horizontally and vertically.
# - Rotate the images 360 degres.
# - **Adjust the labels (vertices) according to the flips and rotation.**
# - In particular, it manages the complexities of determining the first vertex.
#
# This is an improved and more complex version of my generator described at: https://github.com/frobertpixto/tf_keras_generator_with_targets
#
# Regarding **x_pos and y_pos**, this is the **anchor** used to finding the first vertex that I describe in more details
# [here](https://github.com/frobertpixto/hand_drawn_shapes_dataset/blob/main/processing/find_vertices/README.md).

# %%
batch_size = 128
hds_gen = HdsDataGenerator(partition, X_train, Y_train, batch_size=batch_size,
                           n_vertices=nb_vertices,
                           x_pos=anchor_x,
                           y_pos=anchor_y)

# %% [markdown]
# ## Define the optimizer

# %%
optimizer = Adam(learning_rate=4e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, amsgrad=False)

# %% [markdown]
# # Compile the model

# %%
model.compile(optimizer = optimizer , loss = "mean_squared_error")

# %% [markdown]
# # Set a learning rate callback

# %%
# when running for 1000 epoch, the reduction must be very slow.
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss',
                                            patience=25,
                                            verbose=1,
                                            factor=0.90, 
                                            mode='min',
                                            min_delta=0.0000001,
                                            min_lr=0.000000001)

# %% [markdown]
# # Fit the model with our custom data Augmentation

# %%
# I like to start a few epoch with a small batch size because:
# - This basically makes the learning rate larger. https://openreview.net/pdf?id=B1Yy1BxCZ#:~:text=Increasing%20the%20batch%20size%20during%20training%20achieves%20similar%20results%20to,twice%20to%20illustrate%20the%20variance.
# - This covers to 0 to 80% of the accuracy/loss curve, cleaning the graphs
epochs = 6
history = model.fit(x=hds_gen,
                    epochs = epochs, validation_data = (X_val,Y_val),
                    verbose = 1, steps_per_epoch=X_train.shape[0] // batch_size)
# Out:
# Epoch 1/6
# /Users/frobert/miniforge3/envs/tensorflow-2025-01/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2025-06-14 21:23:53.561950: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - loss: 1.1275 - val_loss: 0.2080
# Epoch 2/6
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0777 - val_loss: 0.1483
# Epoch 3/6
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0372 - val_loss: 0.1007
# Epoch 4/6
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0271 - val_loss: 0.0740
# Epoch 5/6
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0214 - val_loss: 0.0638
# Epoch 6/6
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0187 - val_loss: 0.0506

# %%
# Fit and Save the Best model
checkpoint = ModelCheckpoint(model_filename, monitor='val_loss', verbose=1, save_best_only=True)

best_epoch_results = ShowBestEpochResult(on_param='val_loss', show_params=['val_loss', 'loss'], mode='min')

callbacks_list = [learning_rate_reduction, checkpoint, best_epoch_results]

epochs  = 200 #1000
history = model.fit(x=hds_gen,
                      epochs=epochs, validation_data=(X_val,Y_val),
                      verbose=1, steps_per_epoch=X_train.shape[0] // batch_size,
                      callbacks=callbacks_list)
# Out:
# Epoch 1/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0160
# Epoch 1: val_loss improved from inf to 0.04507, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0160 - val_loss: 0.0451 - learning_rate: 4.0000e-04
# Epoch 2/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0149
# Epoch 2: val_loss improved from 0.04507 to 0.04192, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0149 - val_loss: 0.0419 - learning_rate: 4.0000e-04
# Epoch 3/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0135
# Epoch 3: val_loss improved from 0.04192 to 0.03966, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0135 - val_loss: 0.0397 - learning_rate: 4.0000e-04
# Epoch 4/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0120
# Epoch 4: val_loss improved from 0.03966 to 0.03688, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0120 - val_loss: 0.0369 - learning_rate: 4.0000e-04
# Epoch 5/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0116
# Epoch 5: val_loss did not improve from 0.03688
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0116 - val_loss: 0.0423 - learning_rate: 4.0000e-04
# Epoch 6/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0103
# Epoch 6: val_loss improved from 0.03688 to 0.02513, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0103 - val_loss: 0.0251 - learning_rate: 4.0000e-04
# Epoch 7/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0101
# Epoch 7: val_loss improved from 0.02513 to 0.01516, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0101 - val_loss: 0.0152 - learning_rate: 4.0000e-04
# Epoch 8/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0095
# Epoch 8: val_loss improved from 0.01516 to 0.00982, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0095 - val_loss: 0.0098 - learning_rate: 4.0000e-04
# Epoch 9/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0091
# Epoch 9: val_loss improved from 0.00982 to 0.00651, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0091 - val_loss: 0.0065 - learning_rate: 4.0000e-04
# Epoch 10/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0081
# Epoch 10: val_loss improved from 0.00651 to 0.00412, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0081 - val_loss: 0.0041 - learning_rate: 4.0000e-04
# Epoch 11/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0082
# Epoch 11: val_loss did not improve from 0.00412
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0082 - val_loss: 0.0041 - learning_rate: 4.0000e-04
# Epoch 12/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0075
# Epoch 12: val_loss improved from 0.00412 to 0.00311, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0075 - val_loss: 0.0031 - learning_rate: 4.0000e-04
# Epoch 13/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0076
# Epoch 13: val_loss did not improve from 0.00311
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0076 - val_loss: 0.0033 - learning_rate: 4.0000e-04
# Epoch 14/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0071
# Epoch 14: val_loss improved from 0.00311 to 0.00296, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0071 - val_loss: 0.0030 - learning_rate: 4.0000e-04
# Epoch 15/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0076
# Epoch 15: val_loss did not improve from 0.00296
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0076 - val_loss: 0.0030 - learning_rate: 4.0000e-04
# Epoch 16/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0070
# Epoch 16: val_loss improved from 0.00296 to 0.00277, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0070 - val_loss: 0.0028 - learning_rate: 4.0000e-04
# Epoch 17/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0068
# Epoch 17: val_loss improved from 0.00277 to 0.00264, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0068 - val_loss: 0.0026 - learning_rate: 4.0000e-04
# Epoch 18/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0065
# Epoch 18: val_loss did not improve from 0.00264
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0065 - val_loss: 0.0029 - learning_rate: 4.0000e-04
# Epoch 19/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0062
# Epoch 19: val_loss did not improve from 0.00264
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0062 - val_loss: 0.0029 - learning_rate: 4.0000e-04
# Epoch 20/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0066
# Epoch 20: val_loss did not improve from 0.00264
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0066 - val_loss: 0.0037 - learning_rate: 4.0000e-04
# Epoch 21/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0063
# Epoch 21: val_loss did not improve from 0.00264
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0063 - val_loss: 0.0027 - learning_rate: 4.0000e-04
# Epoch 22/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0061
# Epoch 22: val_loss improved from 0.00264 to 0.00256, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0061 - val_loss: 0.0026 - learning_rate: 4.0000e-04
# Epoch 23/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0061
# Epoch 23: val_loss improved from 0.00256 to 0.00256, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0060 - val_loss: 0.0026 - learning_rate: 4.0000e-04
# Epoch 24/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0056
# Epoch 24: val_loss improved from 0.00256 to 0.00251, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0057 - val_loss: 0.0025 - learning_rate: 4.0000e-04
# Epoch 25/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0057
# Epoch 25: val_loss did not improve from 0.00251
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0057 - val_loss: 0.0028 - learning_rate: 4.0000e-04
# Epoch 26/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0056
# Epoch 26: val_loss did not improve from 0.00251
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0056 - val_loss: 0.0031 - learning_rate: 4.0000e-04
# Epoch 27/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0059
# Epoch 27: val_loss improved from 0.00251 to 0.00226, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0059 - val_loss: 0.0023 - learning_rate: 4.0000e-04
# Epoch 28/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0056
# Epoch 28: val_loss did not improve from 0.00226
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0056 - val_loss: 0.0024 - learning_rate: 4.0000e-04
# Epoch 29/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0056
# Epoch 29: val_loss did not improve from 0.00226
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0056 - val_loss: 0.0026 - learning_rate: 4.0000e-04
# Epoch 30/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0056
# Epoch 30: val_loss did not improve from 0.00226
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0056 - val_loss: 0.0024 - learning_rate: 4.0000e-04
# Epoch 31/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0054
# Epoch 31: val_loss did not improve from 0.00226
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0055 - val_loss: 0.0025 - learning_rate: 4.0000e-04
# Epoch 32/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0054
# Epoch 32: val_loss did not improve from 0.00226
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0054 - val_loss: 0.0023 - learning_rate: 4.0000e-04
# Epoch 33/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0053
# Epoch 33: val_loss improved from 0.00226 to 0.00211, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0053 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 34/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0049
# Epoch 34: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0049 - val_loss: 0.0022 - learning_rate: 4.0000e-04
# Epoch 35/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0049
# Epoch 35: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0049 - val_loss: 0.0023 - learning_rate: 4.0000e-04
# Epoch 36/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0050
# Epoch 36: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0050 - val_loss: 0.0022 - learning_rate: 4.0000e-04
# Epoch 37/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0052
# Epoch 37: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0052 - val_loss: 0.0026 - learning_rate: 4.0000e-04
# Epoch 38/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0054
# Epoch 38: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0054 - val_loss: 0.0022 - learning_rate: 4.0000e-04
# Epoch 39/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0048
# Epoch 39: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0048 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 40/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0049
# Epoch 40: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0049 - val_loss: 0.0024 - learning_rate: 4.0000e-04
# Epoch 41/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0050
# Epoch 41: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0050 - val_loss: 0.0023 - learning_rate: 4.0000e-04
# Epoch 42/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0046
# Epoch 42: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0046 - val_loss: 0.0025 - learning_rate: 4.0000e-04
# Epoch 43/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0047
# Epoch 43: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0047 - val_loss: 0.0024 - learning_rate: 4.0000e-04
# Epoch 44/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0046
# Epoch 44: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0046 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 45/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0047
# Epoch 45: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0047 - val_loss: 0.0023 - learning_rate: 4.0000e-04
# Epoch 46/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0046
# Epoch 46: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0046 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 47/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0043
# Epoch 47: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0043 - val_loss: 0.0029 - learning_rate: 4.0000e-04
# Epoch 48/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0045
# Epoch 48: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - loss: 0.0045 - val_loss: 0.0023 - learning_rate: 4.0000e-04
# Epoch 49/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0048
# Epoch 49: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0048 - val_loss: 0.0023 - learning_rate: 4.0000e-04
# Epoch 50/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0044
# Epoch 50: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0044 - val_loss: 0.0024 - learning_rate: 4.0000e-04
# Epoch 51/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0042
# Epoch 51: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0042 - val_loss: 0.0031 - learning_rate: 4.0000e-04
# Epoch 52/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0046
# Epoch 52: val_loss did not improve from 0.00211
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0046 - val_loss: 0.0022 - learning_rate: 4.0000e-04
# Epoch 53/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0046
# Epoch 53: val_loss improved from 0.00211 to 0.00206, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0046 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 54/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0039
# Epoch 54: val_loss did not improve from 0.00206
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0039 - val_loss: 0.0023 - learning_rate: 4.0000e-04
# Epoch 55/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0044
# Epoch 55: val_loss did not improve from 0.00206
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0044 - val_loss: 0.0022 - learning_rate: 4.0000e-04
# Epoch 56/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0044
# Epoch 56: val_loss did not improve from 0.00206
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0043 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 57/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0042
# Epoch 57: val_loss did not improve from 0.00206
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0042 - val_loss: 0.0023 - learning_rate: 4.0000e-04
# Epoch 58/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0045
# Epoch 58: val_loss did not improve from 0.00206
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0045 - val_loss: 0.0023 - learning_rate: 4.0000e-04
# Epoch 59/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0041
# Epoch 59: val_loss did not improve from 0.00206
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0041 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 60/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0044
# Epoch 60: val_loss improved from 0.00206 to 0.00189, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0044 - val_loss: 0.0019 - learning_rate: 4.0000e-04
# Epoch 61/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0042
# Epoch 61: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0042 - val_loss: 0.0020 - learning_rate: 4.0000e-04
# Epoch 62/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0041
# Epoch 62: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0042 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 63/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0040
# Epoch 63: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0040 - val_loss: 0.0024 - learning_rate: 4.0000e-04
# Epoch 64/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0042
# Epoch 64: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0042 - val_loss: 0.0020 - learning_rate: 4.0000e-04
# Epoch 65/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0041
# Epoch 65: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0041 - val_loss: 0.0020 - learning_rate: 4.0000e-04
# Epoch 66/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0040
# Epoch 66: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0040 - val_loss: 0.0020 - learning_rate: 4.0000e-04
# Epoch 67/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0042
# Epoch 67: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0042 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 68/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0041
# Epoch 68: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0041 - val_loss: 0.0022 - learning_rate: 4.0000e-04
# Epoch 69/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0042
# Epoch 69: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0042 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 70/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0044
# Epoch 70: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0044 - val_loss: 0.0023 - learning_rate: 4.0000e-04
# Epoch 71/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0039
# Epoch 71: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0039 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 72/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0043
# Epoch 72: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0043 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 73/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0036
# Epoch 73: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0036 - val_loss: 0.0019 - learning_rate: 4.0000e-04
# Epoch 74/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0040
# Epoch 74: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0040 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 75/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0040
# Epoch 75: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0040 - val_loss: 0.0025 - learning_rate: 4.0000e-04
# Epoch 76/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0040
# Epoch 76: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0040 - val_loss: 0.0020 - learning_rate: 4.0000e-04
# Epoch 77/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0037
# Epoch 77: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0037 - val_loss: 0.0024 - learning_rate: 4.0000e-04
# Epoch 78/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0041
# Epoch 78: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0041 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 79/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0038
# Epoch 79: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0038 - val_loss: 0.0020 - learning_rate: 4.0000e-04
# Epoch 80/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0041
# Epoch 80: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0041 - val_loss: 0.0020 - learning_rate: 4.0000e-04
# Epoch 81/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0037
# Epoch 81: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0037 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 82/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0038
# Epoch 82: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0038 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 83/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0040
# Epoch 83: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0040 - val_loss: 0.0024 - learning_rate: 4.0000e-04
# Epoch 84/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0038
# Epoch 84: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0038 - val_loss: 0.0025 - learning_rate: 4.0000e-04
# Epoch 85/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0038
# Epoch 85: ReduceLROnPlateau reducing learning rate to 0.00035999999090563506.
#
# Epoch 85: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0038 - val_loss: 0.0021 - learning_rate: 4.0000e-04
# Epoch 86/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0035
# Epoch 86: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0035 - val_loss: 0.0019 - learning_rate: 3.6000e-04
# Epoch 87/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0039
# Epoch 87: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0039 - val_loss: 0.0021 - learning_rate: 3.6000e-04
# Epoch 88/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0039
# Epoch 88: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0038 - val_loss: 0.0020 - learning_rate: 3.6000e-04
# Epoch 89/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0037
# Epoch 89: val_loss did not improve from 0.00189
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0037 - val_loss: 0.0022 - learning_rate: 3.6000e-04
# Epoch 90/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0037
# Epoch 90: val_loss improved from 0.00189 to 0.00183, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0037 - val_loss: 0.0018 - learning_rate: 3.6000e-04
# Epoch 91/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0036
# Epoch 91: val_loss did not improve from 0.00183
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0036 - val_loss: 0.0020 - learning_rate: 3.6000e-04
# Epoch 92/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0037
# Epoch 92: val_loss did not improve from 0.00183
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0037 - val_loss: 0.0024 - learning_rate: 3.6000e-04
# Epoch 93/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0037
# Epoch 93: val_loss did not improve from 0.00183
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0037 - val_loss: 0.0023 - learning_rate: 3.6000e-04
# Epoch 94/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0035
# Epoch 94: val_loss did not improve from 0.00183
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0035 - val_loss: 0.0020 - learning_rate: 3.6000e-04
# Epoch 95/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0034
# Epoch 95: val_loss did not improve from 0.00183
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0034 - val_loss: 0.0019 - learning_rate: 3.6000e-04
# Epoch 96/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0038
# Epoch 96: val_loss did not improve from 0.00183
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0038 - val_loss: 0.0019 - learning_rate: 3.6000e-04
# Epoch 97/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0037
# Epoch 97: val_loss did not improve from 0.00183
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0037 - val_loss: 0.0022 - learning_rate: 3.6000e-04
# Epoch 98/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0039
# Epoch 98: val_loss did not improve from 0.00183
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0039 - val_loss: 0.0019 - learning_rate: 3.6000e-04
# Epoch 99/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0037
# Epoch 99: val_loss improved from 0.00183 to 0.00177, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0037 - val_loss: 0.0018 - learning_rate: 3.6000e-04
# Epoch 100/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0035
# Epoch 100: val_loss did not improve from 0.00177
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0035 - val_loss: 0.0020 - learning_rate: 3.6000e-04
# Epoch 101/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0037
# Epoch 101: val_loss did not improve from 0.00177
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0037 - val_loss: 0.0021 - learning_rate: 3.6000e-04
# Epoch 102/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0035
# Epoch 102: val_loss did not improve from 0.00177
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0035 - val_loss: 0.0019 - learning_rate: 3.6000e-04
# Epoch 103/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0036
# Epoch 103: val_loss did not improve from 0.00177
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0036 - val_loss: 0.0019 - learning_rate: 3.6000e-04
# Epoch 104/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0033
# Epoch 104: val_loss did not improve from 0.00177
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0034 - val_loss: 0.0018 - learning_rate: 3.6000e-04
# Epoch 105/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0036
# Epoch 105: val_loss did not improve from 0.00177
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0036 - val_loss: 0.0018 - learning_rate: 3.6000e-04
# Epoch 106/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0035
# Epoch 106: val_loss did not improve from 0.00177
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0035 - val_loss: 0.0020 - learning_rate: 3.6000e-04
# Epoch 107/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0032
# Epoch 107: val_loss improved from 0.00177 to 0.00174, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0032 - val_loss: 0.0017 - learning_rate: 3.6000e-04
# Epoch 108/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0035
# Epoch 108: val_loss did not improve from 0.00174
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0035 - val_loss: 0.0019 - learning_rate: 3.6000e-04
# Epoch 109/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0037
# Epoch 109: val_loss improved from 0.00174 to 0.00169, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0037 - val_loss: 0.0017 - learning_rate: 3.6000e-04
# Epoch 110/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0033
# Epoch 110: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0033 - val_loss: 0.0022 - learning_rate: 3.6000e-04
# Epoch 111/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0035
# Epoch 111: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0035 - val_loss: 0.0020 - learning_rate: 3.6000e-04
# Epoch 112/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0033
# Epoch 112: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0033 - val_loss: 0.0019 - learning_rate: 3.6000e-04
# Epoch 113/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0032
# Epoch 113: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0032 - val_loss: 0.0021 - learning_rate: 3.6000e-04
# Epoch 114/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0034
# Epoch 114: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0034 - val_loss: 0.0019 - learning_rate: 3.6000e-04
# Epoch 115/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0037
# Epoch 115: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0037 - val_loss: 0.0017 - learning_rate: 3.6000e-04
# Epoch 116/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0036
# Epoch 116: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0036 - val_loss: 0.0019 - learning_rate: 3.6000e-04
# Epoch 117/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0032
# Epoch 117: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0032 - val_loss: 0.0023 - learning_rate: 3.6000e-04
# Epoch 118/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0032
# Epoch 118: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0032 - val_loss: 0.0021 - learning_rate: 3.6000e-04
# Epoch 119/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0037
# Epoch 119: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0036 - val_loss: 0.0021 - learning_rate: 3.6000e-04
# Epoch 120/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0034
# Epoch 120: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0035 - val_loss: 0.0019 - learning_rate: 3.6000e-04
# Epoch 121/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0037
# Epoch 121: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0037 - val_loss: 0.0020 - learning_rate: 3.6000e-04
# Epoch 122/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0036
# Epoch 122: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0036 - val_loss: 0.0024 - learning_rate: 3.6000e-04
# Epoch 123/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0036
# Epoch 123: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0036 - val_loss: 0.0020 - learning_rate: 3.6000e-04
# Epoch 124/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0036
# Epoch 124: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0036 - val_loss: 0.0023 - learning_rate: 3.6000e-04
# Epoch 125/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0035
# Epoch 125: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0035 - val_loss: 0.0020 - learning_rate: 3.6000e-04
# Epoch 126/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0034
# Epoch 126: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0034 - val_loss: 0.0021 - learning_rate: 3.6000e-04
# Epoch 127/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0033
# Epoch 127: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0033 - val_loss: 0.0020 - learning_rate: 3.6000e-04
# Epoch 128/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0036
# Epoch 128: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0036 - val_loss: 0.0030 - learning_rate: 3.6000e-04
# Epoch 129/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0036
# Epoch 129: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0036 - val_loss: 0.0023 - learning_rate: 3.6000e-04
# Epoch 130/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0036
# Epoch 130: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0036 - val_loss: 0.0018 - learning_rate: 3.6000e-04
# Epoch 131/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0035
# Epoch 131: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0035 - val_loss: 0.0018 - learning_rate: 3.6000e-04
# Epoch 132/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0034
# Epoch 132: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0034 - val_loss: 0.0020 - learning_rate: 3.6000e-04
# Epoch 133/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0036
# Epoch 133: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0036 - val_loss: 0.0021 - learning_rate: 3.6000e-04
# Epoch 134/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0030
# Epoch 134: ReduceLROnPlateau reducing learning rate to 0.00032400000491179527.
#
# Epoch 134: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0030 - val_loss: 0.0022 - learning_rate: 3.6000e-04
# Epoch 135/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0032
# Epoch 135: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0032 - val_loss: 0.0018 - learning_rate: 3.2400e-04
# Epoch 136/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0033
# Epoch 136: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0033 - val_loss: 0.0025 - learning_rate: 3.2400e-04
# Epoch 137/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0030
# Epoch 137: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0030 - val_loss: 0.0018 - learning_rate: 3.2400e-04
# Epoch 138/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0032
# Epoch 138: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0032 - val_loss: 0.0018 - learning_rate: 3.2400e-04
# Epoch 139/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0034
# Epoch 139: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0034 - val_loss: 0.0018 - learning_rate: 3.2400e-04
# Epoch 140/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0032
# Epoch 140: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0032 - val_loss: 0.0019 - learning_rate: 3.2400e-04
# Epoch 141/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0034
# Epoch 141: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0034 - val_loss: 0.0019 - learning_rate: 3.2400e-04
# Epoch 142/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0033
# Epoch 142: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0033 - val_loss: 0.0022 - learning_rate: 3.2400e-04
# Epoch 143/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0033
# Epoch 143: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0033 - val_loss: 0.0017 - learning_rate: 3.2400e-04
# Epoch 144/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0035
# Epoch 144: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0035 - val_loss: 0.0018 - learning_rate: 3.2400e-04
# Epoch 145/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0031
# Epoch 145: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0031 - val_loss: 0.0020 - learning_rate: 3.2400e-04
# Epoch 146/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0035
# Epoch 146: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0035 - val_loss: 0.0017 - learning_rate: 3.2400e-04
# Epoch 147/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0030
# Epoch 147: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0030 - val_loss: 0.0019 - learning_rate: 3.2400e-04
# Epoch 148/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0033
# Epoch 148: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0033 - val_loss: 0.0018 - learning_rate: 3.2400e-04
# Epoch 149/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0033
# Epoch 149: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0033 - val_loss: 0.0020 - learning_rate: 3.2400e-04
# Epoch 150/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0030
# Epoch 150: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0030 - val_loss: 0.0018 - learning_rate: 3.2400e-04
# Epoch 151/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0033
# Epoch 151: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0033 - val_loss: 0.0022 - learning_rate: 3.2400e-04
# Epoch 152/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0027
# Epoch 152: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0027 - val_loss: 0.0019 - learning_rate: 3.2400e-04
# Epoch 153/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0032
# Epoch 153: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0033 - val_loss: 0.0021 - learning_rate: 3.2400e-04
# Epoch 154/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0035
# Epoch 154: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0035 - val_loss: 0.0019 - learning_rate: 3.2400e-04
# Epoch 155/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0033
# Epoch 155: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0033 - val_loss: 0.0019 - learning_rate: 3.2400e-04
# Epoch 156/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0031
# Epoch 156: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0031 - val_loss: 0.0019 - learning_rate: 3.2400e-04
# Epoch 157/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0032
# Epoch 157: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0032 - val_loss: 0.0020 - learning_rate: 3.2400e-04
# Epoch 158/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0030
# Epoch 158: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0030 - val_loss: 0.0020 - learning_rate: 3.2400e-04
# Epoch 159/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0032
# Epoch 159: ReduceLROnPlateau reducing learning rate to 0.00029159999394323677.
#
# Epoch 159: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0032 - val_loss: 0.0022 - learning_rate: 3.2400e-04
# Epoch 160/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0031
# Epoch 160: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0031 - val_loss: 0.0019 - learning_rate: 2.9160e-04
# Epoch 161/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0031
# Epoch 161: val_loss did not improve from 0.00169
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0031 - val_loss: 0.0018 - learning_rate: 2.9160e-04
# Epoch 162/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0033
# Epoch 162: val_loss improved from 0.00169 to 0.00167, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0033 - val_loss: 0.0017 - learning_rate: 2.9160e-04
# Epoch 163/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0031
# Epoch 163: val_loss did not improve from 0.00167
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0031 - val_loss: 0.0018 - learning_rate: 2.9160e-04
# Epoch 164/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0030
# Epoch 164: val_loss did not improve from 0.00167
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0030 - val_loss: 0.0019 - learning_rate: 2.9160e-04
# Epoch 165/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0034
# Epoch 165: val_loss did not improve from 0.00167
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0034 - val_loss: 0.0020 - learning_rate: 2.9160e-04
# Epoch 166/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0031
# Epoch 166: val_loss did not improve from 0.00167
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0031 - val_loss: 0.0017 - learning_rate: 2.9160e-04
# Epoch 167/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0030
# Epoch 167: val_loss did not improve from 0.00167
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0030 - val_loss: 0.0022 - learning_rate: 2.9160e-04
# Epoch 168/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0031
# Epoch 168: val_loss did not improve from 0.00167
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0031 - val_loss: 0.0019 - learning_rate: 2.9160e-04
# Epoch 169/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0035
# Epoch 169: val_loss did not improve from 0.00167
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0035 - val_loss: 0.0017 - learning_rate: 2.9160e-04
# Epoch 170/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0030
# Epoch 170: val_loss did not improve from 0.00167
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0030 - val_loss: 0.0017 - learning_rate: 2.9160e-04
# Epoch 171/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0028
# Epoch 171: val_loss did not improve from 0.00167
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0028 - val_loss: 0.0018 - learning_rate: 2.9160e-04
# Epoch 172/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0033
# Epoch 172: val_loss did not improve from 0.00167
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0033 - val_loss: 0.0019 - learning_rate: 2.9160e-04
# Epoch 173/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0030
# Epoch 173: val_loss did not improve from 0.00167
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0030 - val_loss: 0.0019 - learning_rate: 2.9160e-04
# Epoch 174/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0031
# Epoch 174: val_loss did not improve from 0.00167
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0031 - val_loss: 0.0018 - learning_rate: 2.9160e-04
# Epoch 175/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0030
# Epoch 175: val_loss did not improve from 0.00167
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0030 - val_loss: 0.0017 - learning_rate: 2.9160e-04
# Epoch 176/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0029
# Epoch 176: val_loss did not improve from 0.00167
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0029 - val_loss: 0.0019 - learning_rate: 2.9160e-04
# Epoch 177/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0029
# Epoch 177: val_loss improved from 0.00167 to 0.00166, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0029 - val_loss: 0.0017 - learning_rate: 2.9160e-04
# Epoch 178/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0032
# Epoch 178: val_loss did not improve from 0.00166
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0032 - val_loss: 0.0020 - learning_rate: 2.9160e-04
# Epoch 179/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0031
# Epoch 179: val_loss did not improve from 0.00166
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0031 - val_loss: 0.0024 - learning_rate: 2.9160e-04
# Epoch 180/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0032
# Epoch 180: val_loss did not improve from 0.00166
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0032 - val_loss: 0.0021 - learning_rate: 2.9160e-04
# Epoch 181/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0031
# Epoch 181: val_loss did not improve from 0.00166
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0031 - val_loss: 0.0020 - learning_rate: 2.9160e-04
# Epoch 182/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0029
# Epoch 182: val_loss did not improve from 0.00166
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0029 - val_loss: 0.0019 - learning_rate: 2.9160e-04
# Epoch 183/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0027
# Epoch 183: val_loss did not improve from 0.00166
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0027 - val_loss: 0.0018 - learning_rate: 2.9160e-04
# Epoch 184/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0030
# Epoch 184: val_loss improved from 0.00166 to 0.00165, saving model to ../saved_models/ellipse1.model.keras
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0030 - val_loss: 0.0017 - learning_rate: 2.9160e-04
# Epoch 185/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0032
# Epoch 185: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0032 - val_loss: 0.0021 - learning_rate: 2.9160e-04
# Epoch 186/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0030
# Epoch 186: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0030 - val_loss: 0.0019 - learning_rate: 2.9160e-04
# Epoch 187/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0030
# Epoch 187: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0030 - val_loss: 0.0019 - learning_rate: 2.9160e-04
# Epoch 188/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0032
# Epoch 188: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0032 - val_loss: 0.0019 - learning_rate: 2.9160e-04
# Epoch 189/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0032
# Epoch 189: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0032 - val_loss: 0.0018 - learning_rate: 2.9160e-04
# Epoch 190/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0033
# Epoch 190: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0033 - val_loss: 0.0022 - learning_rate: 2.9160e-04
# Epoch 191/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0033
# Epoch 191: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0033 - val_loss: 0.0017 - learning_rate: 2.9160e-04
# Epoch 192/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0030
# Epoch 192: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0030 - val_loss: 0.0019 - learning_rate: 2.9160e-04
# Epoch 193/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0027
# Epoch 193: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0027 - val_loss: 0.0017 - learning_rate: 2.9160e-04
# Epoch 194/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0030
# Epoch 194: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0030 - val_loss: 0.0017 - learning_rate: 2.9160e-04
# Epoch 195/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0031
# Epoch 195: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0031 - val_loss: 0.0018 - learning_rate: 2.9160e-04
# Epoch 196/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0029
# Epoch 196: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0029 - val_loss: 0.0018 - learning_rate: 2.9160e-04
# Epoch 197/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0031
# Epoch 197: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0031 - val_loss: 0.0020 - learning_rate: 2.9160e-04
# Epoch 198/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0031
# Epoch 198: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0031 - val_loss: 0.0018 - learning_rate: 2.9160e-04
# Epoch 199/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0030
# Epoch 199: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0030 - val_loss: 0.0019 - learning_rate: 2.9160e-04
# Epoch 200/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0032
# Epoch 200: val_loss did not improve from 0.00165
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0032 - val_loss: 0.0022 - learning_rate: 2.9160e-04
# BestEpochResult. Epoch: 184, val_loss: 0.00165, loss: 0.00306,
# 37/37 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 32: val_loss improved from 0.00244 to 0.00227, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 5s 123ms/step - loss: 0.0049 - val_loss: 0.0023 - lr: 4.0000e-04
# Epoch 33/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 33: val_loss did not improve from 0.00227
# 37/37 [==============================] - 4s 119ms/step - loss: 0.0049 - val_loss: 0.0026 - lr: 4.0000e-04
# Epoch 34/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 34: val_loss did not improve from 0.00227
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0049 - val_loss: 0.0028 - lr: 4.0000e-04
# Epoch 35/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 35: val_loss did not improve from 0.00227
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0047 - val_loss: 0.0031 - lr: 4.0000e-04
# Epoch 36/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 36: val_loss did not improve from 0.00227
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0046 - val_loss: 0.0024 - lr: 4.0000e-04
# Epoch 37/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 37: val_loss improved from 0.00227 to 0.00207, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 5s 124ms/step - loss: 0.0045 - val_loss: 0.0021 - lr: 4.0000e-04
# Epoch 38/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 38: val_loss did not improve from 0.00207
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0046 - val_loss: 0.0030 - lr: 4.0000e-04
# Epoch 39/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 39: val_loss did not improve from 0.00207
# 37/37 [==============================] - 5s 122ms/step - loss: 0.0047 - val_loss: 0.0032 - lr: 4.0000e-04
# Epoch 40/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 40: val_loss did not improve from 0.00207
# ...
# 37/37 [==============================] - 5s 123ms/step - loss: 0.0032 - val_loss: 0.0017 - lr: 3.6000e-04
# Epoch 135/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 135: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0032 - val_loss: 0.0018 - lr: 3.6000e-04
# Epoch 136/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 136: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0032 - val_loss: 0.0025 - lr: 3.6000e-04
# Epoch 137/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 137: val_loss did not improve from 0.00172
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0033 - val_loss: 0.0021 - lr: 3.6000e-04
# Epoch 138/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 138: val_loss improved from 0.00172 to 0.00172, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 5s 123ms/step - loss: 0.0033 - val_loss: 0.0017 - lr: 3.6000e-04
# Epoch 139/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 139: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0033 - val_loss: 0.0018 - lr: 3.6000e-04
# Epoch 140/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 140: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 122ms/step - loss: 0.0033 - val_loss: 0.0018 - lr: 3.6000e-04
# Epoch 141/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 141: val_loss did not improve from 0.00172
# 37/37 [==============================] - 4s 121ms/step - loss: 0.0035 - val_loss: 0.0020 - lr: 3.6000e-04
# Epoch 142/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 142: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 122ms/step - loss: 0.0034 - val_loss: 0.0022 - lr: 3.6000e-04
# Epoch 143/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 143: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0031 - val_loss: 0.0020 - lr: 3.6000e-04
# Epoch 144/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 144: val_loss did not improve from 0.00172
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0034 - val_loss: 0.0022 - lr: 3.6000e-04
# Epoch 145/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 145: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0032 - val_loss: 0.0020 - lr: 3.6000e-04
# Epoch 146/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 146: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0033 - val_loss: 0.0034 - lr: 3.6000e-04
# Epoch 147/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 147: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0033 - val_loss: 0.0019 - lr: 3.6000e-04
# Epoch 148/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 148: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0033 - val_loss: 0.0021 - lr: 3.6000e-04
# Epoch 149/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 149: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0032 - val_loss: 0.0019 - lr: 3.6000e-04
# Epoch 150/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 150: val_loss did not improve from 0.00172
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0033 - val_loss: 0.0020 - lr: 3.6000e-04
# Epoch 151/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 151: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0034 - val_loss: 0.0023 - lr: 3.6000e-04
# Epoch 152/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 152: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0034 - val_loss: 0.0018 - lr: 3.6000e-04
# Epoch 153/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 153: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 122ms/step - loss: 0.0032 - val_loss: 0.0018 - lr: 3.6000e-04
# Epoch 154/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 154: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0030 - val_loss: 0.0021 - lr: 3.6000e-04
# Epoch 155/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 155: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0033 - val_loss: 0.0022 - lr: 3.6000e-04
# Epoch 156/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 156: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0031 - val_loss: 0.0018 - lr: 3.6000e-04
# Epoch 157/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 157: val_loss did not improve from 0.00172
# 37/37 [==============================] - 5s 122ms/step - loss: 0.0032 - val_loss: 0.0024 - lr: 3.6000e-04
# Epoch 158/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 158: val_loss improved from 0.00172 to 0.00170, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 5s 123ms/step - loss: 0.0028 - val_loss: 0.0017 - lr: 3.6000e-04
# Epoch 159/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 159: val_loss improved from 0.00170 to 0.00167, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 5s 124ms/step - loss: 0.0032 - val_loss: 0.0017 - lr: 3.6000e-04
# Epoch 160/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 160: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0031 - val_loss: 0.0021 - lr: 3.6000e-04
# Epoch 161/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 161: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0033 - val_loss: 0.0021 - lr: 3.6000e-04
# Epoch 162/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 162: val_loss did not improve from 0.00167
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0034 - val_loss: 0.0021 - lr: 3.6000e-04
# Epoch 163/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 163: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0031 - val_loss: 0.0017 - lr: 3.6000e-04
# Epoch 164/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 164: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 122ms/step - loss: 0.0031 - val_loss: 0.0019 - lr: 3.6000e-04
# Epoch 165/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 165: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 122ms/step - loss: 0.0033 - val_loss: 0.0020 - lr: 3.6000e-04
# Epoch 166/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 166: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0033 - val_loss: 0.0020 - lr: 3.6000e-04
# Epoch 167/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 167: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0035 - val_loss: 0.0017 - lr: 3.6000e-04
# Epoch 168/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 168: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0030 - val_loss: 0.0020 - lr: 3.6000e-04
# Epoch 169/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 169: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0033 - val_loss: 0.0018 - lr: 3.6000e-04
# Epoch 170/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 170: val_loss did not improve from 0.00167
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0030 - val_loss: 0.0019 - lr: 3.6000e-04
# Epoch 171/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 171: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0032 - val_loss: 0.0017 - lr: 3.6000e-04
# Epoch 172/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 172: val_loss did not improve from 0.00167
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0030 - val_loss: 0.0018 - lr: 3.6000e-04
# Epoch 173/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 173: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0031 - val_loss: 0.0017 - lr: 3.6000e-04
# Epoch 174/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 174: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0030 - val_loss: 0.0021 - lr: 3.6000e-04
# Epoch 175/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 175: val_loss did not improve from 0.00167
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0030 - val_loss: 0.0022 - lr: 3.6000e-04
# Epoch 176/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 176: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0030 - val_loss: 0.0019 - lr: 3.6000e-04
# Epoch 177/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 177: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0030 - val_loss: 0.0020 - lr: 3.6000e-04
# Epoch 178/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 178: val_loss did not improve from 0.00167
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0033 - val_loss: 0.0019 - lr: 3.6000e-04
# Epoch 179/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 179: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 123ms/step - loss: 0.0031 - val_loss: 0.0019 - lr: 3.6000e-04
# Epoch 180/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 180: val_loss did not improve from 0.00167
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0032 - val_loss: 0.0019 - lr: 3.6000e-04
# Epoch 181/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 181: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0030 - val_loss: 0.0023 - lr: 3.6000e-04
# Epoch 182/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 182: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0032 - val_loss: 0.0021 - lr: 3.6000e-04
# Epoch 183/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 183: val_loss did not improve from 0.00167
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0030 - val_loss: 0.0029 - lr: 3.6000e-04
# Epoch 184/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 184: ReduceLROnPlateau reducing learning rate to 0.00032400000491179527.
#
# Epoch 184: val_loss did not improve from 0.00167
# 37/37 [==============================] - 5s 122ms/step - loss: 0.0035 - val_loss: 0.0021 - lr: 3.6000e-04
# Epoch 185/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 185: val_loss improved from 0.00167 to 0.00166, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 5s 126ms/step - loss: 0.0031 - val_loss: 0.0017 - lr: 3.2400e-04
# Epoch 186/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 186: val_loss did not improve from 0.00166
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0030 - val_loss: 0.0018 - lr: 3.2400e-04
# Epoch 187/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 187: val_loss did not improve from 0.00166
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0031 - val_loss: 0.0020 - lr: 3.2400e-04
# Epoch 188/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 188: val_loss did not improve from 0.00166
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0029 - val_loss: 0.0017 - lr: 3.2400e-04
# Epoch 189/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 189: val_loss did not improve from 0.00166
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0030 - val_loss: 0.0019 - lr: 3.2400e-04
# Epoch 190/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 190: val_loss did not improve from 0.00166
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0031 - val_loss: 0.0018 - lr: 3.2400e-04
# Epoch 191/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 191: val_loss did not improve from 0.00166
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0028 - val_loss: 0.0020 - lr: 3.2400e-04
# Epoch 192/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 192: val_loss did not improve from 0.00166
# 37/37 [==============================] - 4s 119ms/step - loss: 0.0027 - val_loss: 0.0018 - lr: 3.2400e-04
# Epoch 193/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 193: val_loss did not improve from 0.00166
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0031 - val_loss: 0.0018 - lr: 3.2400e-04
# Epoch 194/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 194: val_loss did not improve from 0.00166
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0030 - val_loss: 0.0018 - lr: 3.2400e-04
# Epoch 195/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 195: val_loss did not improve from 0.00166
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0033 - val_loss: 0.0023 - lr: 3.2400e-04
# Epoch 196/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 196: val_loss did not improve from 0.00166
# 37/37 [==============================] - 4s 119ms/step - loss: 0.0029 - val_loss: 0.0019 - lr: 3.2400e-04
# Epoch 197/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 197: val_loss did not improve from 0.00166
# 37/37 [==============================] - 4s 121ms/step - loss: 0.0030 - val_loss: 0.0017 - lr: 3.2400e-04
# Epoch 198/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 198: val_loss improved from 0.00166 to 0.00159, saving model to ../saved_models/ellipse1.model.h5
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0030 - val_loss: 0.0016 - lr: 3.2400e-04
# Epoch 199/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 199: val_loss did not improve from 0.00159
# 37/37 [==============================] - 5s 121ms/step - loss: 0.0028 - val_loss: 0.0018 - lr: 3.2400e-04
# Epoch 200/200
# 37/37 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 200: val_loss did not improve from 0.00159
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0028 - val_loss: 0.0018 - lr: 3.2400e-04
# BestEpochResult. Epoch: 198, val_loss: 0.00159, loss: 0.00300,

# %% [markdown]
# ## Plot the loss curves for training and validation

# %%
plt.figure(figsize=(15,10))
plot_loss(history.history,"model",plt)
plt.legend()
plt.grid()
plt.yscale("log")
plt.xlabel("epoch")
plt.ylabel("log loss")
plt.show()

# %% [markdown]
# ## Delete the existing model + Load the best one

# %%
# deletes the existing model
del model

# Load last saved model
model = load_model(model_filename)

# %%
# Predict for the whole Validation set
Y_val_pred = model.predict(X_val)
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %%
# Labels are vertices: x1, y1, x2, y2, x3, y3, y4, y4
# Where:
# - (0, 0) is the top left corner of the image
# - (1, 1) is the bottom right corner of the image
print("Y_val shape: ", Y_val.shape)
print("Y_val_pred shape: ", Y_val_pred.shape)
print("Real Label example: ", Y_val[0])
print("Prediction example: ", Y_val_pred[0])
# Out:
# Y_val shape:  (1446, 8)
# Y_val_pred shape:  (1446, 8)
# Real Label example:  [0.42 0.49 0.51 0.12 0.58 0.5  0.48 0.87]
# Prediction example:  [0.40582293 0.481262   0.5056963  0.096728   0.5789335  0.4961299
#  0.46583936 0.870698  ]

# %% [markdown]
# # Calculate Dice accuracy for the whole Validation set
# To get more information about Dice accuracy, see: https://github.com/frobertpixto/ml_dice_and_iou_accuracy

# %%
dice_val = calculate_Dice_for_set(Y_val, Y_val_pred, nb_vertices)
print(f"Validation Accuracy(Dice): {dice_val}.")
# Out:
# Validation Accuracy(Dice): 0.9082548169846619.

# %%
def plot_sample_with_pred(X, y, pred,axs):
    axs.imshow(X.reshape(image_size, image_size),cmap="gray") # Shape
    axs.scatter(image_size*y[0::2], image_size*y[1::2],c='orange') # Real Vertices
    axs.scatter(image_size*pred[0::2], image_size*pred[1::2],c='green') # Predicted Vertices

# %% [markdown]
# # Validation set predictions - Visualization
# - Orange dot: Real Vertex
# - Green dot: Predicted Vertex

# %%
fig = plt.figure(figsize=(13, 21))
fig.subplots_adjust(hspace=0.13, wspace=0.01,
                    left=0, right=1, bottom=0, top=1.2)
nb_pictures = 32
count = 1
for irow in range(nb_pictures):
    ipic = np.random.choice(X_val.shape[0])
    ax = fig.add_subplot(nb_pictures // 4, 4, count,xticks=[],yticks=[])        
    plot_sample_with_pred(X_val[ipic], Y_val[ipic], Y_val_pred[ipic], ax)
    try:
        dice = calculate_Dice(Y_val[ipic], Y_val_pred[ipic], nb_vertices=nb_vertices)
        ax.set_title("dice {:5.3f}".format(dice))
    except Exception as e:
        print(f"Cannot compute Dice for shape: {i}.")         
    count += 1
plt.show()

# %%
#TODO Display the 32 worst RMSE images

# %% [markdown]
# ## Predict for the test set

# %%
## Prepare the Test set
test_X = test_dict['test_data']
test_y = test_dict['test_labels']
print("test_X shape: ", test_X.shape)
print("test_y shape: ", test_y.shape)

X_test    = test_X.reshape(-1, image_size,image_size, 1)
Y_test    = test_y 
print("X_test shape: ", X_test.shape)
print("Y_test shape: ", Y_test.shape)
# Out:
# test_X shape:  (180, 70, 70)
# test_y shape:  (180, 8)
# X_test shape:  (180, 70, 70, 1)
# Y_test shape:  (180, 8)

# %%
# Show random images from the Test Set + superimposed vertices
indexes = np.arange(len(Y_test))
np.random.shuffle(indexes)
first_random_indexes = indexes[:100]

display_images_with_vertices(X_test[first_random_indexes], Y_test[first_random_indexes])

# %%
test_loss = model.evaluate(X_test, Y_test)
print("test_loss: ", test_loss)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0026
# test_loss:  0.002142581855878234

# %%
Y_test_pred = model.predict(X_test)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
print("Y_pred shape: ", Y_test_pred.shape)
Y_test_pred[0:2, :]
# Out:
# Y_pred shape:  (180, 8)
# array([[0.297093  , 0.73921895, 0.35614097, 0.30055422, 0.6898803 ,
#         0.267337  , 0.57606107, 0.6671991 ],
#        [0.13408631, 0.5974252 , 0.44985205, 0.3042388 , 0.85214853,
#         0.3725862 , 0.5606989 , 0.6677259 ]], dtype=float32)

# %% [markdown]
# # Calculate Dice accuracy for the whole Test set

# %%
dice_val = calculate_Dice_for_set(Y_test, Y_test_pred, nb_vertices)
print(f"Validation Accuracy(Dice): {dice_val}.")
# Out:
# Validation Accuracy(Dice): 0.9121157977097544.

# %% [markdown]
# # Test set predictions - Visualization
# - Orange dot: Real Vertex
# - Green dot: Predicted Vertex

# %%
fig = plt.figure(figsize=(13, 21))
fig.subplots_adjust(hspace=0.13, wspace=0.01,
                    left=0, right=1, bottom=0, top=1.2)
nb_pictures = 32
count = 1
for irow in range(nb_pictures):
    ipic = np.random.choice(X_test.shape[0])
    ax = fig.add_subplot(nb_pictures // 4, 4, count,xticks=[],yticks=[])        
    plot_sample_with_pred(X_test[ipic], Y_test[ipic], Y_test_pred[ipic], ax)
    
    try:
        dice = calculate_Dice(Y_test[ipic], Y_test_pred[ipic], nb_vertices=nb_vertices)
        ax.set_title("dice {:5.3f}".format(dice))
    except Exception as e:
        print(f"Cannot compute Dice for shape: {i}.")    
        
    count += 1
plt.show()

# %% [markdown]
# # Conclusions
# Accuracy is generally good. We see that:
# - Most are very close to the real labels.
# - Some are off and between to real labels. See the first of 32 images above. I describe that issue [here](https://github.com/frobertpixto/hand_drawn_shapes_dataset/blob/main/processing/find_vertices/README.md).
#
#
# Regarding the loss, training for 200 epoch, we have:
# - BestEpochResult. Epoch: 184, val_loss: **0.00165**
#
# For Mix on pix, when training for 1000 epoch, I had:
# - BestEpochResult. Epoch: 958, val_loss: **0.00132**
#
# The model was definitively useful in [Mix on Pix](https://apps.apple.com/us/app/mix-on-pix-text-on-photos/id633281586).
#
# ## TensorFlow Lite Notes
# When creating a TensorFlow Lite model with quantization, accuracy can be a tiny bit lower, but the model size is 25% of the original. That's super important when running **directly in a mobile app**.

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 6, 14, 21, 37, 7, 628183)
